# %% [markdown]
# # Library Module

# %% [markdown]
# Python is a programming language applied very frequently in data science. In the first part of this notebook, we will give a brief overview of Python syntax, functions.
#
#
# But first, let's go over how to navigate through this Jupyter Notebook.

# %% [markdown]
# ## Introduction to Jupyter Notebook

# %% [markdown]
# ### Create Cells

# %% [markdown]
# This notebook contains segments called "cells". To add a cell to the notebook, click the "+" in the top left area right under "File".
#
# Within a cell, you have the option to write code, create a heading, or write text. To select an option, click on the "Code" button, located on the same row as "+". You will see a menu of options to choose from.
#
#
# Markdown - use for text
# <br>
# Code - use for running code
# <br>
# Heading - use for titles

# %% [markdown]
# ### Delete Cells

# %% [markdown]
# To delete a cell, click on the cell, and click the **scissors** icon next to the "+"

# %% [markdown]
# ### Editing and Running Cells

# %% [markdown]
# **Running a cell** is equivalent to pressing **Enter** on a calculator once you've typed in the expression you want to evaluate: it produces an **output**. When you run a text cell, it outputs clean, organized writing. When you run a code cell, it **computes** all of the expressions you want to evaluate, and may **output** the result of the computation.
#
# To edit the content a cell, first click on that cell to activate it.  It'll be highlighted with a little green or blue rectangle. Next, double-click on it. For example, if you double-click the "Running Cells" heading, you will see **### Running Cells** in bold, blue font.
#
# To run a cell, either click "Run" in the panel below "File, Edit...", or press Shift + Enter on your laptop.

# %% [markdown]
# ### Saving Your Work

# %% [markdown]
# To save your work, click on "File", then "Save and Checkpoint". If you have a Mac, you can click **"Command + S"**.

# %% [markdown]
# For this notebook, you only need to know how to run, edit and create cells. However, for more assistance with navigating Jupyter Notebook, click on the **keyboard** icon next to the cell drop-down menu.
#
# For more help, here's a great cheat sheet: https://i.pinimg.com/originals/f5/7e/07/f57e074be4503a39f6d9d8d15f0e8aa5.png

# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ### Variables

# %% [markdown]
# A name that is used to denote something or a value is called a variable. In python, variables can be declared and values can be assigned to them. Values can include numbers and strings. Run the code below:

# %%
x = 5
y = 2
hi = "Hello World"

# %% [markdown]
# Because the above cell ran, we've now officially assigned the variables to values. Run the cell (Shift + Enter) below to see the output of "x", "hi", and "print (x+y)"

# %%
x
# Out:
# 5

# %%
hi
# Out:
# 'Hello World'

# %%
print (x + y)
# Out:
# 7

# %% [markdown]
# ## Introduction to Visualization

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib

# %% [markdown]
# # Intro to CrossRef

# %% [markdown]
# CrossRef is a non-profit organization that helps to provides access to scientific literature. According to their website itself, CrossRef "makes research outputs easy to find, cite, link, and assess".
#
# CrossRef data on scientific publications essentially consists of three elements:
# <br>
#     1) Metadata about a publication
#     <br>
#     2) A URL link to the article
#     <br>
#     3) A document identifier (doi)
#     <br>
#
# At present CrossRef contains information on 80 million scientific publications including articles, books and book chapters.

# %% [markdown]
# Data can be accessed using the python packages habanero, crossrefapi, and crossref-commons. In this module, we'll be focusing on the functionality of the **habanero** package.

# %% [markdown]
# ### Import CrossRef Package

# %% [markdown]
# When importing a package into Jupyter Notebook, we use the command "pip install ..." to download a package into Jupyter Notebook.
#
# We then use the command "import __(package name)__" to use our new package in our code.

# %%
# !pip install habanero
# Out:
# Requirement already satisfied: habanero in ./anaconda3/lib/python3.6/site-packages (0.6.2)
# Requirement already satisfied: requests>=2.7.0 in ./anaconda3/lib/python3.6/site-packages (from habanero) (2.18.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.6/site-packages (from requests>=2.7.0->habanero) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in ./anaconda3/lib/python3.6/site-packages (from requests>=2.7.0->habanero) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in ./anaconda3/lib/python3.6/site-packages (from requests>=2.7.0->habanero) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.6/site-packages (from requests>=2.7.0->habanero) (2018.4.16)

# %%
#To use CrossRef API in Python, we need to import the habanero package
import habanero
import pandas as pd
from habanero import Crossref

# %% [markdown]
# To create an object that takes on the Crossref identity, we assign it to the variable 'cr'.

# %%
cr = Crossref()

# %%
#main function is cr.works(), which takes in a query name
kenya = cr.works(query = "kenya")
kenya
# Out:
# {'status': 'ok',
#  'message-type': 'work-list',
#  'message-version': '1.0.0',
#  'message': {'facets': {},
#   'total-results': 40501,
#   'items': [{'indexed': {'date-parts': [[2019, 2, 14]],
#      'date-time': '2019-02-14T21:24:56Z',
#      'timestamp': 1550179496572},
#     'reference-count': 0,
#     'publisher': 'Centro Internacional de Agricultura Tropical',
#     'issue': '1',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['Trop Grass - Forr Trop'],
#     'DOI': '10.17138/tgft(2)100-102',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2015, 4, 1]],
#      'date-time': '2015-04-01T20:32:16Z',
#      'timestamp': 1427920336000},
#     'page': '100',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Production of giant Panicum in semi-arid Kenya'],
#     'prefix': '10.17138',
#     'volume': '2',
#     'author': [{'given': 'Donald M.G.',
#       'family': 'Njarui',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Mwangi',
#       'family': 'Gatheru',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'David M.',
#       'family': 'Mwangi',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'George A.',
#       'family': 'Keya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '6578',
#     'published-online': {'date-parts': [[2014]]},
#     'container-title': ['Tropical Grasslands - Forrajes Tropicales'],
#     'language': 'en',
#     'deposited': {'date-parts': [[2015, 4, 1]],
#      'date-time': '2015-04-01T20:32:45Z',
#      'timestamp': 1427920365000},
#     'score': 13.49067,
#     'issued': {'date-parts': [[2014]]},
#     'references-count': 0,
#     'journal-issue': {'published-online': {'date-parts': [[2014]]},
#      'issue': '1'},
#     'alternative-id': ['136/84'],
#     'URL': 'http://dx.doi.org/10.17138/tgft(2)100-102',
#     'ISSN': ['2346-3775'],
#     'issn-type': [{'value': '2346-3775', 'type': 'electronic'}]},
#    {'indexed': {'date-parts': [[2019, 2, 18]],
#      'date-time': '2019-02-18T01:48:14Z',
#      'timestamp': 1550454494058},
#     'reference-count': 0,
#     'publisher': 'International Journal Of Advanced Research',
#     'issue': '2',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['IJAR'],
#     'DOI': '10.21474/ijar01/6544',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2018, 3, 30]],
#      'date-time': '2018-03-30T10:49:35Z',
#      'timestamp': 1522406975000},
#     'page': '1195-1203',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['SOCIAL DETERMINANTS INFLUENCING TRANSITION RATE OF GIRLS FROM PRIMARY EDUCATION TO SECONDARY EDUCATION IN KOIBATEK SUB-COUNTY, KENYA.'],
#     'prefix': '10.21474',
#     'volume': '6',
#     'author': [{'given': 'GladysJerono',
#       'family': 'Koech',
#       'sequence': 'first',
#       'affiliation': []},
#      {'name': 'Mount Kenya University, Kenya',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'JoshuaOdhiambo',
#       'family': 'Ogal',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'Rachael',
#       'family': 'Koros',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Mount Kenya University, Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Mount Kenya University, Kenya',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '8913',
#     'published-online': {'date-parts': [[2018, 2, 28]]},
#     'container-title': ['International Journal of Advanced Research'],
#     'deposited': {'date-parts': [[2018, 3, 30]],
#      'date-time': '2018-03-30T10:49:35Z',
#      'timestamp': 1522406975000},
#     'score': 13.429121,
#     'issued': {'date-parts': [[2018, 2, 28]]},
#     'references-count': 0,
#     'journal-issue': {'published-online': {'date-parts': [[2018, 2, 28]]},
#      'issue': '2'},
#     'URL': 'http://dx.doi.org/10.21474/ijar01/6544',
#     'ISSN': ['2320-5407'],
#     'issn-type': [{'value': '2320-5407', 'type': 'electronic'}]},
#    {'indexed': {'date-parts': [[2019, 9, 17]],
#      'date-time': '2019-09-17T10:03:43Z',
#      'timestamp': 1568714623872},
#     'publisher-location': 'Nairobi :',
#     'reference-count': 0,
#     'publisher': 'Nature Kenya, East Africa Natural History Society,',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[1999]]},
#     'DOI': '10.5962/bhl.title.87589',
#     'type': 'monograph',
#     'created': {'date-parts': [[2014, 8, 24]],
#      'date-time': '2014-08-24T06:00:31Z',
#      'timestamp': 1408860031000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 74,
#     'title': ['Important bird areas in Kenya /'],
#     'prefix': '10.5962',
#     'author': [{'given': 'Leon A.',
#       'family': 'Bennun',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Peter.',
#       'family': 'Njoroge',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'National Museums of Kenya.',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Nature Kenya.', 'sequence': 'additional', 'affiliation': []}],
#     'member': '3444',
#     'deposited': {'date-parts': [[2014, 8, 24]],
#      'date-time': '2014-08-24T06:00:31Z',
#      'timestamp': 1408860031000},
#     'score': 13.4121685,
#     'issued': {'date-parts': [[1999]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.5962/bhl.title.87589'},
#    {'indexed': {'date-parts': [[2019, 2, 25]],
#      'date-time': '2019-02-25T09:42:41Z',
#      'timestamp': 1551087761542},
#     'publisher-location': 'Berlin, Boston',
#     'reference-count': 0,
#     'publisher': 'De Gruyter',
#     'isbn-type': [{'value': '9783110826050', 'type': 'electronic'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[1972, 12, 31]]},
#     'DOI': '10.1515/9783110826050-068',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2019, 2, 25]],
#      'date-time': '2019-02-25T09:01:06Z',
#      'timestamp': 1551085266000},
#     'page': '304-305',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya. Jamhuri ya Kenya; Republic of Kenya'],
#     'prefix': '10.1515',
#     'member': '374',
#     'container-title': ['Minerva. Internationales Verzeichnis Wissenschaftlicher Institutionen'],
#     'link': [{'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#       'content-type': 'text/html',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2019, 2, 25]],
#      'date-time': '2019-02-25T09:11:29Z',
#      'timestamp': 1551085889000},
#     'score': 13.4121685,
#     'editor': [{'given': 'Werner',
#       'family': 'Schuder',
#       'sequence': 'first',
#       'affiliation': []}],
#     'issued': {'date-parts': [[1972, 12, 31]]},
#     'ISBN': ['9783110826050'],
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1515/9783110826050-068'},
#    {'indexed': {'date-parts': [[2019, 2, 15]],
#      'date-time': '2019-02-15T19:33:11Z',
#      'timestamp': 1550259191789},
#     'reference-count': 0,
#     'publisher': 'Commonwealth Secretariat',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[1987, 12, 1]]},
#     'DOI': '10.14217/9781848594371-12-en',
#     'type': 'component',
#     'created': {'date-parts': [[2016, 1, 29]],
#      'date-time': '2016-01-29T06:18:13Z',
#      'timestamp': 1454048293000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya: Kenya Law Reform Commission'],
#     'prefix': '10.14217',
#     'author': [{'name': 'Commonwealth Secretariat',
#       'sequence': 'first',
#       'affiliation': []}],
#     'member': '5318',
#     'deposited': {'date-parts': [[2018, 10, 7]],
#      'date-time': '2018-10-07T08:05:04Z',
#      'timestamp': 1538899504000},
#     'score': 13.381683,
#     'issued': {'date-parts': [[1987, 12, 1]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.14217/9781848594371-12-en'},
#    {'indexed': {'date-parts': [[2019, 5, 11]],
#      'date-time': '2019-05-11T22:03:07Z',
#      'timestamp': 1557612187692},
#     'reference-count': 0,
#     'publisher': 'Commonwealth Secretariat',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[1992, 1, 1]]},
#     'DOI': '10.14217/9781848594920-13-en',
#     'type': 'component',
#     'created': {'date-parts': [[2016, 1, 29]],
#      'date-time': '2016-01-29T06:18:13Z',
#      'timestamp': 1454048293000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 1,
#     'title': ['Kenya: Kenya Law Reform Commission'],
#     'prefix': '10.14217',
#     'author': [{'name': 'Commonwealth Secretariat',
#       'sequence': 'first',
#       'affiliation': []}],
#     'member': '5318',
#     'deposited': {'date-parts': [[2018, 10, 8]],
#      'date-time': '2018-10-08T07:55:20Z',
#      'timestamp': 1538985320000},
#     'score': 13.381683,
#     'issued': {'date-parts': [[1992, 1, 1]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.14217/9781848594920-13-en'},
#    {'indexed': {'date-parts': [[2019, 2, 13]],
#      'date-time': '2019-02-13T19:33:11Z',
#      'timestamp': 1550086391566},
#     'reference-count': 0,
#     'publisher': 'Schweizerbart',
#     'issue': '2',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['phyto'],
#     'published-print': {'date-parts': [[1989, 5, 2]]},
#     'DOI': '10.1127/phyto/17/1989/287',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2014, 1, 29]],
#      'date-time': '2014-01-29T10:09:25Z',
#      'timestamp': 1390990165000},
#     'page': '287-288',
#     'source': 'Crossref',
#     'is-referenced-by-count': 1,
#     'title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#     'prefix': '10.1127',
#     'volume': '17',
#     'author': [{'given': 'H.',
#       'family': 'Rehder',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'E.',
#       'family': 'Beck',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'J. O.',
#       'family': 'Kokwaro',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '181',
#     'container-title': ['Phytocoenologia'],
#     'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#     'language': 'en',
#     'deposited': {'date-parts': [[2017, 4, 11]],
#      'date-time': '2017-04-11T09:00:28Z',
#      'timestamp': 1491901228000},
#     'score': 12.96174,
#     'issued': {'date-parts': [[1989, 5, 2]]},
#     'references-count': 0,
#     'journal-issue': {'published-print': {'date-parts': [[1989, 5, 2]]},
#      'issue': '2'},
#     'URL': 'http://dx.doi.org/10.1127/phyto/17/1989/287',
#     'ISSN': ['0340-269X'],
#     'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#    {'indexed': {'date-parts': [[2019, 5, 23]],
#      'date-time': '2019-05-23T14:43:08Z',
#      'timestamp': 1558622588993},
#     'reference-count': 0,
#     'publisher': 'African Journal of Food, Agriculture, Nutrition and Development',
#     'issue': '01',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['AJFAND'],
#     'DOI': '10.18697/ajfand.84.blfb1017',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2019, 2, 2]],
#      'date-time': '2019-02-02T09:05:42Z',
#      'timestamp': 1549098342000},
#     'page': '14010-14042',
#     'source': 'Crossref',
#     'is-referenced-by-count': 15,
#     'title': ['Climate Change Effects on Crop Production in Kenya: Farmer Perceptions and Adaptation Strategies'],
#     'prefix': '10.18697',
#     'volume': '19',
#     'author': [{'given': 'Beverly',
#       'family': 'Agesa',
#       'sequence': 'first',
#       'affiliation': []},
#      {'name': 'University  of Nairobi, Nairobi, Kenya',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'CM',
#       'family': 'Onyango',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'VM',
#       'family': 'Kathumo',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'RN',
#       'family': 'Onwonga',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'GN',
#       'family': 'Karuku',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'University  of  Nairobi, Nairobi, Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'University  of  Nairobi,  Nairobi, Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'University  of Nairobi, Nairobi, Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Univesity of Nairobi, Nairobi, Kenya',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '8080',
#     'published-online': {'date-parts': [[2019, 2, 1]]},
#     'container-title': ['African Journal of Food, Agriculture, Nutrition and Development'],
#     'link': [{'URL': 'https://www.ajfand.net/Volume19/No1/BLFB1017.pdf',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2019, 2, 2]],
#      'date-time': '2019-02-02T09:05:44Z',
#      'timestamp': 1549098344000},
#     'score': 12.96174,
#     'issued': {'date-parts': [[2019, 2, 1]]},
#     'references-count': 0,
#     'journal-issue': {'published-online': {'date-parts': [[2019, 2, 1]]},
#      'issue': '01'},
#     'URL': 'http://dx.doi.org/10.18697/ajfand.84.blfb1017',
#     'ISSN': ['1684-5374'],
#     'issn-type': [{'value': '1684-5374', 'type': 'electronic'}]},
#    {'indexed': {'date-parts': [[2019, 2, 14]],
#      'date-time': '2019-02-14T06:31:57Z',
#      'timestamp': 1550125917962},
#     'reference-count': 0,
#     'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1787/270604575355',
#     'type': 'component',
#     'created': {'date-parts': [[2008, 9, 30]],
#      'date-time': '2008-09-30T12:02:13Z',
#      'timestamp': 1222776133000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya'],
#     'prefix': '10.1787',
#     'member': '1963',
#     'deposited': {'date-parts': [[2014, 5, 27]],
#      'date-time': '2014-05-27T17:04:57Z',
#      'timestamp': 1401210297000},
#     'score': 12.928367,
#     'issued': {'date-parts': [[None]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1787/270604575355'},
#    {'indexed': {'date-parts': [[2019, 2, 14]],
#      'date-time': '2019-02-14T06:31:57Z',
#      'timestamp': 1550125917764},
#     'reference-count': 0,
#     'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1787/124030037050',
#     'type': 'component',
#     'created': {'date-parts': [[2008, 9, 30]],
#      'date-time': '2008-09-30T12:02:13Z',
#      'timestamp': 1222776133000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya'],
#     'prefix': '10.1787',
#     'member': '1963',
#     'deposited': {'date-parts': [[2014, 5, 27]],
#      'date-time': '2014-05-27T17:04:56Z',
#      'timestamp': 1401210296000},
#     'score': 12.928367,
#     'issued': {'date-parts': [[None]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1787/124030037050'},
#    {'indexed': {'date-parts': [[2019, 4, 1]],
#      'date-time': '2019-04-01T23:03:44Z',
#      'timestamp': 1554159824661},
#     'reference-count': 0,
#     'publisher': 'Schweizerbart',
#     'issue': '4',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['phyto'],
#     'published-print': {'date-parts': [[1995, 12, 14]]},
#     'DOI': '10.1127/phyto/25/1995/467',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2014, 1, 29]],
#      'date-time': '2014-01-29T11:02:59Z',
#      'timestamp': 1390993379000},
#     'page': '467-560',
#     'source': 'Crossref',
#     'is-referenced-by-count': 9,
#     'title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#     'prefix': '10.1127',
#     'volume': '25',
#     'author': [{'given': 'Rainer W.',
#       'family': 'Bussmann',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Erwin',
#       'family': 'Beck',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '181',
#     'container-title': ['Phytocoenologia'],
#     'original-title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#     'language': 'en',
#     'deposited': {'date-parts': [[2017, 4, 11]],
#      'date-time': '2017-04-11T09:04:27Z',
#      'timestamp': 1491901467000},
#     'score': 12.824807,
#     'issued': {'date-parts': [[1995, 12, 14]]},
#     'references-count': 0,
#     'journal-issue': {'published-print': {'date-parts': [[1995, 12, 14]]},
#      'issue': '4'},
#     'URL': 'http://dx.doi.org/10.1127/phyto/25/1995/467',
#     'ISSN': ['0340-269X'],
#     'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#    {'indexed': {'date-parts': [[2019, 5, 23]],
#      'date-time': '2019-05-23T10:11:30Z',
#      'timestamp': 1558606290666},
#     'reference-count': 0,
#     'publisher': 'Manchester University Press',
#     'isbn-type': [{'value': '9781526105813', 'type': 'print'},
#      {'value': '9781526135988', 'type': 'electronic'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[2019, 3, 1]]},
#     'abstract': '<p>Since the 1998 bombing of the US Embassy in Nairobi, the Government of Kenya’s response to terrorism has been multifaceted. Government efforts have primarily relied on civil authorities and the military, thus privileging the use of force over subtler means. The Kenyan Police have employed measures such as profiling, detention, and prosecution. The Kenyan military has conducted operations in Kenya and Somalia. These strategies have contributed to the apprehension of some terrorist suspects and checked Shabaab’s advance in Somalia. Yet, Kenya’s counterterrorism efforts have been hampered by limited coordination among agencies, the use of heavy-handed tactics, and insufficient engagement with civil society organizations. Two defining features of Kenyan counterterrorism efforts have emerged. First, counterterrorism in Kenya has clear sociocultural dimensions. Security forces have responded to the threat of terrorism by focusing intently on Kenya’s alienated Muslim communities both in the Somali-majority north and at the Swahili-speaking coast. As a result, the Government of Kenya’s response to terrorism reflects communal divisions and animosity within Kenyan society that precede contemporary counterterrorism. Second, Kenya’s invasion of neighboring Somalia created and blurred two fronts: one within Kenya and the other in southern Somalia. The actions of Kenyan policy-makers and al Shabaab therefore contributed to a more complete integration of the conflict in Somalia and internal tensions in Kenya..</p>',
#     'DOI': '10.7228/manchester/9781526105813.003.0016',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2019, 5, 23]],
#      'date-time': '2019-05-23T09:38:00Z',
#      'timestamp': 1558604280000},
#     'page': '386-409',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#     'prefix': '10.7228',
#     'author': [{'given': 'Jeremy',
#       'family': 'Prestholdt',
#       'sequence': 'first',
#       'affiliation': []}],
#     'member': '4230',
#     'published-online': {'date-parts': [[2019, 5, 23]]},
#     'container-title': ['Non-Western responses to terrorism'],
#     'original-title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#     'deposited': {'date-parts': [[2019, 5, 23]],
#      'date-time': '2019-05-23T09:38:00Z',
#      'timestamp': 1558604280000},
#     'score': 12.824807,
#     'issued': {'date-parts': [[2019, 3, 1]]},
#     'ISBN': ['9781526105813', '9781526135988'],
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.7228/manchester/9781526105813.003.0016'},
#    {'indexed': {'date-parts': [[2019, 10, 30]],
#      'date-time': '2019-10-30T21:03:37Z',
#      'timestamp': 1572469417577},
#     'reference-count': 0,
#     'publisher': 'Schweizerbart',
#     'issue': '4',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['phyto'],
#     'published-print': {'date-parts': [[1988, 12, 7]]},
#     'DOI': '10.1127/phyto/16/1988/433',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2014, 1, 29]],
#      'date-time': '2014-01-29T10:09:25Z',
#      'timestamp': 1390990165000},
#     'page': '433-463',
#     'source': 'Crossref',
#     'is-referenced-by-count': 9,
#     'title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#     'prefix': '10.1127',
#     'volume': '16',
#     'author': [{'given': 'H.',
#       'family': 'Rehder',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'E.',
#       'family': 'Beck',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'J. O.',
#       'family': 'Kokwaro',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '181',
#     'container-title': ['Phytocoenologia'],
#     'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#     'language': 'en',
#     'deposited': {'date-parts': [[2017, 4, 11]],
#      'date-time': '2017-04-11T10:26:22Z',
#      'timestamp': 1491906382000},
#     'score': 12.824807,
#     'issued': {'date-parts': [[1988, 12, 7]]},
#     'references-count': 0,
#     'journal-issue': {'published-print': {'date-parts': [[1988, 12, 7]]},
#      'issue': '4'},
#     'URL': 'http://dx.doi.org/10.1127/phyto/16/1988/433',
#     'ISSN': ['0340-269X'],
#     'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#    {'indexed': {'date-parts': [[2019, 2, 16]],
#      'date-time': '2019-02-16T06:30:16Z',
#      'timestamp': 1550298616836},
#     'reference-count': 0,
#     'publisher': 'Bloomsbury Publishing',
#     'isbn-type': [{'value': '9781408122549', 'type': 'print'},
#      {'value': '9781408189931', 'type': 'electronic'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.5040/9781472926944.0150',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2016, 6, 24]],
#      'date-time': '2016-06-24T17:27:36Z',
#      'timestamp': 1466789256000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Surdisorex polulus Mount Kenya Mole-shrew : Fr. Musaraigne du Mont Kenya; Ger. Mount Kenya Wühlspitzmaus'],
#     'prefix': '10.5040',
#     'member': '2984',
#     'container-title': ['Mammals of Africa : Hedgehogs, Shrews and Bats'],
#     'deposited': {'date-parts': [[2016, 7, 4]],
#      'date-time': '2016-07-04T13:54:23Z',
#      'timestamp': 1467640463000},
#     'score': 12.7708,
#     'issued': {'date-parts': [[None]]},
#     'ISBN': ['9781472926944', '9781408189931', '9781408122549'],
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.5040/9781472926944.0150'},
#    {'indexed': {'date-parts': [[2019, 4, 17]],
#      'date-time': '2019-04-17T11:11:31Z',
#      'timestamp': 1555499491401},
#     'publisher-location': 'London',
#     'reference-count': 0,
#     'publisher': 'Palgrave Macmillan UK',
#     'isbn-type': [{'value': '9781349958382', 'type': 'print'},
#      {'value': '9781349958399', 'type': 'electronic'}],
#     'license': [{'URL': 'http://www.springer.com/tdm',
#       'start': {'date-parts': [[2019, 1, 1]],
#        'date-time': '2019-01-01T00:00:00Z',
#        'timestamp': 1546300800000},
#       'delay-in-days': 0,
#       'content-version': 'tdm'}],
#     'content-domain': {'domain': ['link.springer.com'],
#      'crossmark-restriction': False},
#     'published-print': {'date-parts': [[2019]]},
#     'DOI': '10.1057/978-1-349-95839-9_1403',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2019, 4, 17]],
#      'date-time': '2019-04-17T10:48:42Z',
#      'timestamp': 1555498122000},
#     'page': '714-715',
#     'update-policy': 'http://dx.doi.org/10.1007/springer_crossmark_policy',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya'],
#     'prefix': '10.1057',
#     'member': '297',
#     'published-online': {'date-parts': [[2019, 4, 2]]},
#     'container-title': ['The Statesman’s Yearbook Companion'],
#     'link': [{'URL': 'http://link.springer.com/content/pdf/10.1057/978-1-349-95839-9_1403',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2019, 4, 17]],
#      'date-time': '2019-04-17T10:57:59Z',
#      'timestamp': 1555498679000},
#     'score': 12.7708,
#     'subtitle': ['Jamhuri ya Kenya (Republic of Kenya)'],
#     'issued': {'date-parts': [[2019]]},
#     'ISBN': ['9781349958382', '9781349958399'],
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1057/978-1-349-95839-9_1403',
#     'assertion': [{'value': '2 April 2019',
#       'order': 1,
#       'name': 'first_online',
#       'label': 'First Online',
#       'group': {'name': 'ChapterHistory', 'label': 'Chapter History'}}]},
#    {'indexed': {'date-parts': [[2019, 2, 16]],
#      'date-time': '2019-02-16T04:59:29Z',
#      'timestamp': 1550293169175},
#     'reference-count': 0,
#     'publisher': 'Kenya Meteorological Society',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['J. Meteorol. Related. Sci'],
#     'published-print': {'date-parts': [[2007, 9, 19]]},
#     'DOI': '10.20987/jmrs.08.2012.603',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2016, 5, 31]],
#      'date-time': '2016-05-31T07:04:14Z',
#      'timestamp': 1464678254000},
#     'page': '26-35',
#     'source': 'Crossref',
#     'is-referenced-by-count': 1,
#     'title': ['Use of Aquacrop Model to Predict Maize Yields under varying Rainfall and Temperature in a Semi-Arid Environment in Kenya'],
#     'prefix': '10.20987',
#     'volume': '6',
#     'author': [{'given': 'Joab',
#       'family': 'Wamari',
#       'sequence': 'first',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Sijali',
#       'family': 'Isaya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'Lee',
#       'family': 'Kheng',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'Joseph',
#       'family': 'Miriti',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'Esilaba',
#       'family': 'Obutiati',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Soil and Water management and Crop Nutrition Section',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'National Agricultural Research Centre -Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research institute',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '8610',
#     'container-title': ['Journal of Meteorology and Related Sciences'],
#     'deposited': {'date-parts': [[2017, 7, 26]],
#      'date-time': '2017-07-26T21:59:54Z',
#      'timestamp': 1501106394000},
#     'score': 12.717586,
#     'issued': {'date-parts': [[2007, 9, 19]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.20987/jmrs.08.2012.603',
#     'ISSN': ['1995-9834', '2412-3781'],
#     'issn-type': [{'value': '1995-9834', 'type': 'print'},
#      {'value': '2412-3781', 'type': 'electronic'}]},
#    {'indexed': {'date-parts': [[2019, 2, 13]],
#      'date-time': '2019-02-13T22:23:59Z',
#      'timestamp': 1550096639282},
#     'reference-count': 0,
#     'publisher': 'Geological Society of America',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1130/2014.dmch016.s1',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2014, 3, 14]],
#      'date-time': '2014-03-14T17:56:58Z',
#      'timestamp': 1394819818000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Geology of the Suswa Region, Kenya'],
#     'prefix': '10.1130',
#     'member': '257',
#     'published-online': {'date-parts': [[2014, 3, 14]]},
#     'container-title': ['Maps of the Southern Kenya Rift'],
#     'deposited': {'date-parts': [[2014, 3, 14]],
#      'date-time': '2014-03-14T17:56:59Z',
#      'timestamp': 1394819819000},
#     'score': 12.655651,
#     'issued': {'date-parts': [[2014, 3, 14]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s1'},
#    {'indexed': {'date-parts': [[2019, 2, 13]],
#      'date-time': '2019-02-13T22:23:59Z',
#      'timestamp': 1550096639288},
#     'reference-count': 0,
#     'publisher': 'Geological Society of America',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1130/2014.dmch016.s2',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2014, 3, 14]],
#      'date-time': '2014-03-14T17:56:58Z',
#      'timestamp': 1394819818000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Geology of the Nairobi Region, Kenya'],
#     'prefix': '10.1130',
#     'member': '257',
#     'published-online': {'date-parts': [[2014, 3, 14]]},
#     'container-title': ['Maps of the Southern Kenya Rift'],
#     'deposited': {'date-parts': [[2014, 3, 14]],
#      'date-time': '2014-03-14T17:56:59Z',
#      'timestamp': 1394819819000},
#     'score': 12.655651,
#     'issued': {'date-parts': [[2014, 3, 14]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s2'},
#    {'indexed': {'date-parts': [[2019, 2, 13]],
#      'date-time': '2019-02-13T22:23:59Z',
#      'timestamp': 1550096639297},
#     'reference-count': 0,
#     'publisher': 'Geological Society of America',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1130/2014.dmch016.s4',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2014, 3, 14]],
#      'date-time': '2014-03-14T17:56:58Z',
#      'timestamp': 1394819818000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Geology of the Kajiado Region, Kenya'],
#     'prefix': '10.1130',
#     'member': '257',
#     'published-online': {'date-parts': [[2014, 3, 14]]},
#     'container-title': ['Maps of the Southern Kenya Rift'],
#     'deposited': {'date-parts': [[2014, 3, 14]],
#      'date-time': '2014-03-14T17:56:59Z',
#      'timestamp': 1394819819000},
#     'score': 12.655651,
#     'issued': {'date-parts': [[2014, 3, 14]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s4'},
#    {'indexed': {'date-parts': [[2019, 2, 13]],
#      'date-time': '2019-02-13T22:23:59Z',
#      'timestamp': 1550096639297},
#     'reference-count': 0,
#     'publisher': 'Geological Society of America',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1130/2014.dmch016.s5',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2014, 3, 14]],
#      'date-time': '2014-03-14T17:56:58Z',
#      'timestamp': 1394819818000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Geology of the Area South of Magadi, Kenya'],
#     'prefix': '10.1130',
#     'member': '257',
#     'published-online': {'date-parts': [[2014, 3, 14]]},
#     'container-title': ['Maps of the Southern Kenya Rift'],
#     'deposited': {'date-parts': [[2014, 3, 14]],
#      'date-time': '2014-03-14T17:57:00Z',
#      'timestamp': 1394819820000},
#     'score': 12.655651,
#     'issued': {'date-parts': [[2014, 3, 14]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s5'}],
#   'items-per-page': 20,
#   'query': {'start-index': 0, 'search-terms': 'kenya'}}}

# %%
#kenya is a dictionary 
type(kenya)
# Out:
# dict

# %%
#keys of the kenya dictionary are listed below
for key, value in kenya.items() :
    print (key)
# Out:
# status
# message-type
# message-version
# message

# %%
#keys of the message component of the kenya dictionary are listed below
for key, value in kenya['message'].items():
    print (key)
# Out:
# facets
# total-results
# items
# items-per-page
# query

# %%
#Let us see what the values are for each of the dictionary keys
kenya['status']
# Out:
# 'ok'

# %%
kenya['message-type']
# Out:
# 'work-list'

# %%
kenya['message-version']
# Out:
# '1.0.0'

# %%
kenya['message']
# Out:
# {'facets': {},
#  'total-results': 40401,
#  'items': [{'indexed': {'date-parts': [[2019, 2, 14]],
#     'date-time': '2019-02-14T21:24:56Z',
#     'timestamp': 1550179496572},
#    'reference-count': 0,
#    'publisher': 'Centro Internacional de Agricultura Tropical',
#    'issue': '1',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['Trop Grass - Forr Trop'],
#    'DOI': '10.17138/tgft(2)100-102',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2015, 4, 1]],
#     'date-time': '2015-04-01T20:32:16Z',
#     'timestamp': 1427920336000},
#    'page': '100',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Production of giant Panicum in semi-arid Kenya'],
#    'prefix': '10.17138',
#    'volume': '2',
#    'author': [{'given': 'Donald M.G.',
#      'family': 'Njarui',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'Mwangi',
#      'family': 'Gatheru',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'David M.',
#      'family': 'Mwangi',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'George A.',
#      'family': 'Keya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '6578',
#    'published-online': {'date-parts': [[2014]]},
#    'container-title': ['Tropical Grasslands - Forrajes Tropicales'],
#    'language': 'en',
#    'deposited': {'date-parts': [[2015, 4, 1]],
#     'date-time': '2015-04-01T20:32:45Z',
#     'timestamp': 1427920365000},
#    'score': 13.489236,
#    'issued': {'date-parts': [[2014]]},
#    'references-count': 0,
#    'journal-issue': {'published-online': {'date-parts': [[2014]]},
#     'issue': '1'},
#    'alternative-id': ['136/84'],
#    'URL': 'http://dx.doi.org/10.17138/tgft(2)100-102',
#    'ISSN': ['2346-3775'],
#    'issn-type': [{'value': '2346-3775', 'type': 'electronic'}]},
#   {'indexed': {'date-parts': [[2019, 2, 18]],
#     'date-time': '2019-02-18T01:48:14Z',
#     'timestamp': 1550454494058},
#    'reference-count': 0,
#    'publisher': 'International Journal Of Advanced Research',
#    'issue': '2',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['IJAR'],
#    'DOI': '10.21474/ijar01/6544',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2018, 3, 30]],
#     'date-time': '2018-03-30T10:49:35Z',
#     'timestamp': 1522406975000},
#    'page': '1195-1203',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['SOCIAL DETERMINANTS INFLUENCING TRANSITION RATE OF GIRLS FROM PRIMARY EDUCATION TO SECONDARY EDUCATION IN KOIBATEK SUB-COUNTY, KENYA.'],
#    'prefix': '10.21474',
#    'volume': '6',
#    'author': [{'given': 'GladysJerono',
#      'family': 'Koech',
#      'sequence': 'first',
#      'affiliation': []},
#     {'name': 'Mount Kenya University, Kenya',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'JoshuaOdhiambo',
#      'family': 'Ogal',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'Rachael',
#      'family': 'Koros',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Mount Kenya University, Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Mount Kenya University, Kenya',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '8913',
#    'published-online': {'date-parts': [[2018, 2, 28]]},
#    'container-title': ['International Journal of Advanced Research'],
#    'deposited': {'date-parts': [[2018, 3, 30]],
#     'date-time': '2018-03-30T10:49:35Z',
#     'timestamp': 1522406975000},
#    'score': 13.427694,
#    'issued': {'date-parts': [[2018, 2, 28]]},
#    'references-count': 0,
#    'journal-issue': {'published-online': {'date-parts': [[2018, 2, 28]]},
#     'issue': '2'},
#    'URL': 'http://dx.doi.org/10.21474/ijar01/6544',
#    'ISSN': ['2320-5407'],
#    'issn-type': [{'value': '2320-5407', 'type': 'electronic'}]},
#   {'indexed': {'date-parts': [[2019, 9, 17]],
#     'date-time': '2019-09-17T10:03:43Z',
#     'timestamp': 1568714623872},
#    'publisher-location': 'Nairobi :',
#    'reference-count': 0,
#    'publisher': 'Nature Kenya, East Africa Natural History Society,',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[1999]]},
#    'DOI': '10.5962/bhl.title.87589',
#    'type': 'monograph',
#    'created': {'date-parts': [[2014, 8, 24]],
#     'date-time': '2014-08-24T06:00:31Z',
#     'timestamp': 1408860031000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 74,
#    'title': ['Important bird areas in Kenya /'],
#    'prefix': '10.5962',
#    'author': [{'given': 'Leon A.',
#      'family': 'Bennun',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'Peter.',
#      'family': 'Njoroge',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'National Museums of Kenya.',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Nature Kenya.', 'sequence': 'additional', 'affiliation': []}],
#    'member': '3444',
#    'deposited': {'date-parts': [[2014, 8, 24]],
#     'date-time': '2014-08-24T06:00:31Z',
#     'timestamp': 1408860031000},
#    'score': 13.410743,
#    'issued': {'date-parts': [[1999]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.5962/bhl.title.87589'},
#   {'indexed': {'date-parts': [[2019, 2, 25]],
#     'date-time': '2019-02-25T09:42:41Z',
#     'timestamp': 1551087761542},
#    'publisher-location': 'Berlin, Boston',
#    'reference-count': 0,
#    'publisher': 'De Gruyter',
#    'isbn-type': [{'value': '9783110826050', 'type': 'electronic'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[1972, 12, 31]]},
#    'DOI': '10.1515/9783110826050-068',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2019, 2, 25]],
#     'date-time': '2019-02-25T09:01:06Z',
#     'timestamp': 1551085266000},
#    'page': '304-305',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya. Jamhuri ya Kenya; Republic of Kenya'],
#    'prefix': '10.1515',
#    'member': '374',
#    'container-title': ['Minerva. Internationales Verzeichnis Wissenschaftlicher Institutionen'],
#    'link': [{'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#      'content-type': 'text/html',
#      'content-version': 'vor',
#      'intended-application': 'text-mining'},
#     {'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#      'content-type': 'unspecified',
#      'content-version': 'vor',
#      'intended-application': 'similarity-checking'}],
#    'deposited': {'date-parts': [[2019, 2, 25]],
#     'date-time': '2019-02-25T09:11:29Z',
#     'timestamp': 1551085889000},
#    'score': 13.410743,
#    'editor': [{'given': 'Werner',
#      'family': 'Schuder',
#      'sequence': 'first',
#      'affiliation': []}],
#    'issued': {'date-parts': [[1972, 12, 31]]},
#    'ISBN': ['9783110826050'],
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1515/9783110826050-068'},
#   {'indexed': {'date-parts': [[2019, 2, 15]],
#     'date-time': '2019-02-15T19:33:11Z',
#     'timestamp': 1550259191789},
#    'reference-count': 0,
#    'publisher': 'Commonwealth Secretariat',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[1987, 12, 1]]},
#    'DOI': '10.14217/9781848594371-12-en',
#    'type': 'component',
#    'created': {'date-parts': [[2016, 1, 29]],
#     'date-time': '2016-01-29T06:18:13Z',
#     'timestamp': 1454048293000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya: Kenya Law Reform Commission'],
#    'prefix': '10.14217',
#    'author': [{'name': 'Commonwealth Secretariat',
#      'sequence': 'first',
#      'affiliation': []}],
#    'member': '5318',
#    'deposited': {'date-parts': [[2018, 10, 7]],
#     'date-time': '2018-10-07T08:05:04Z',
#     'timestamp': 1538899504000},
#    'score': 13.38026,
#    'issued': {'date-parts': [[1987, 12, 1]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.14217/9781848594371-12-en'},
#   {'indexed': {'date-parts': [[2019, 5, 11]],
#     'date-time': '2019-05-11T22:03:07Z',
#     'timestamp': 1557612187692},
#    'reference-count': 0,
#    'publisher': 'Commonwealth Secretariat',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[1992, 1, 1]]},
#    'DOI': '10.14217/9781848594920-13-en',
#    'type': 'component',
#    'created': {'date-parts': [[2016, 1, 29]],
#     'date-time': '2016-01-29T06:18:13Z',
#     'timestamp': 1454048293000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 1,
#    'title': ['Kenya: Kenya Law Reform Commission'],
#    'prefix': '10.14217',
#    'author': [{'name': 'Commonwealth Secretariat',
#      'sequence': 'first',
#      'affiliation': []}],
#    'member': '5318',
#    'deposited': {'date-parts': [[2018, 10, 8]],
#     'date-time': '2018-10-08T07:55:20Z',
#     'timestamp': 1538985320000},
#    'score': 13.38026,
#    'issued': {'date-parts': [[1992, 1, 1]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.14217/9781848594920-13-en'},
#   {'indexed': {'date-parts': [[2019, 2, 13]],
#     'date-time': '2019-02-13T19:33:11Z',
#     'timestamp': 1550086391566},
#    'reference-count': 0,
#    'publisher': 'Schweizerbart',
#    'issue': '2',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['phyto'],
#    'published-print': {'date-parts': [[1989, 5, 2]]},
#    'DOI': '10.1127/phyto/17/1989/287',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2014, 1, 29]],
#     'date-time': '2014-01-29T10:09:25Z',
#     'timestamp': 1390990165000},
#    'page': '287-288',
#    'source': 'Crossref',
#    'is-referenced-by-count': 1,
#    'title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#    'prefix': '10.1127',
#    'volume': '17',
#    'author': [{'given': 'H.',
#      'family': 'Rehder',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'E.',
#      'family': 'Beck',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'J. O.',
#      'family': 'Kokwaro',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '181',
#    'container-title': ['Phytocoenologia'],
#    'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#    'language': 'en',
#    'deposited': {'date-parts': [[2017, 4, 11]],
#     'date-time': '2017-04-11T09:00:28Z',
#     'timestamp': 1491901228000},
#    'score': 12.960362,
#    'issued': {'date-parts': [[1989, 5, 2]]},
#    'references-count': 0,
#    'journal-issue': {'published-print': {'date-parts': [[1989, 5, 2]]},
#     'issue': '2'},
#    'URL': 'http://dx.doi.org/10.1127/phyto/17/1989/287',
#    'ISSN': ['0340-269X'],
#    'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#   {'indexed': {'date-parts': [[2019, 5, 23]],
#     'date-time': '2019-05-23T14:43:08Z',
#     'timestamp': 1558622588993},
#    'reference-count': 0,
#    'publisher': 'African Journal of Food, Agriculture, Nutrition and Development',
#    'issue': '01',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['AJFAND'],
#    'DOI': '10.18697/ajfand.84.blfb1017',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2019, 2, 2]],
#     'date-time': '2019-02-02T09:05:42Z',
#     'timestamp': 1549098342000},
#    'page': '14010-14042',
#    'source': 'Crossref',
#    'is-referenced-by-count': 15,
#    'title': ['Climate Change Effects on Crop Production in Kenya: Farmer Perceptions and Adaptation Strategies'],
#    'prefix': '10.18697',
#    'volume': '19',
#    'author': [{'given': 'Beverly',
#      'family': 'Agesa',
#      'sequence': 'first',
#      'affiliation': []},
#     {'name': 'University  of Nairobi, Nairobi, Kenya',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'CM',
#      'family': 'Onyango',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'VM',
#      'family': 'Kathumo',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'RN',
#      'family': 'Onwonga',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'GN',
#      'family': 'Karuku',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'University  of  Nairobi, Nairobi, Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'University  of  Nairobi,  Nairobi, Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'University  of Nairobi, Nairobi, Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Univesity of Nairobi, Nairobi, Kenya',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '8080',
#    'published-online': {'date-parts': [[2019, 2, 1]]},
#    'container-title': ['African Journal of Food, Agriculture, Nutrition and Development'],
#    'link': [{'URL': 'https://www.ajfand.net/Volume19/No1/BLFB1017.pdf',
#      'content-type': 'unspecified',
#      'content-version': 'vor',
#      'intended-application': 'similarity-checking'}],
#    'deposited': {'date-parts': [[2019, 2, 2]],
#     'date-time': '2019-02-02T09:05:44Z',
#     'timestamp': 1549098344000},
#    'score': 12.960362,
#    'issued': {'date-parts': [[2019, 2, 1]]},
#    'references-count': 0,
#    'journal-issue': {'published-online': {'date-parts': [[2019, 2, 1]]},
#     'issue': '01'},
#    'URL': 'http://dx.doi.org/10.18697/ajfand.84.blfb1017',
#    'ISSN': ['1684-5374'],
#    'issn-type': [{'value': '1684-5374', 'type': 'electronic'}]},
#   {'indexed': {'date-parts': [[2019, 2, 14]],
#     'date-time': '2019-02-14T06:31:57Z',
#     'timestamp': 1550125917962},
#    'reference-count': 0,
#    'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1787/270604575355',
#    'type': 'component',
#    'created': {'date-parts': [[2008, 9, 30]],
#     'date-time': '2008-09-30T12:02:13Z',
#     'timestamp': 1222776133000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya'],
#    'prefix': '10.1787',
#    'member': '1963',
#    'deposited': {'date-parts': [[2014, 5, 27]],
#     'date-time': '2014-05-27T17:04:57Z',
#     'timestamp': 1401210297000},
#    'score': 12.92699,
#    'issued': {'date-parts': [[None]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1787/270604575355'},
#   {'indexed': {'date-parts': [[2019, 2, 14]],
#     'date-time': '2019-02-14T06:31:57Z',
#     'timestamp': 1550125917764},
#    'reference-count': 0,
#    'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1787/124030037050',
#    'type': 'component',
#    'created': {'date-parts': [[2008, 9, 30]],
#     'date-time': '2008-09-30T12:02:13Z',
#     'timestamp': 1222776133000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya'],
#    'prefix': '10.1787',
#    'member': '1963',
#    'deposited': {'date-parts': [[2014, 5, 27]],
#     'date-time': '2014-05-27T17:04:56Z',
#     'timestamp': 1401210296000},
#    'score': 12.92699,
#    'issued': {'date-parts': [[None]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1787/124030037050'},
#   {'indexed': {'date-parts': [[2019, 4, 1]],
#     'date-time': '2019-04-01T23:03:44Z',
#     'timestamp': 1554159824661},
#    'reference-count': 0,
#    'publisher': 'Schweizerbart',
#    'issue': '4',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['phyto'],
#    'published-print': {'date-parts': [[1995, 12, 14]]},
#    'DOI': '10.1127/phyto/25/1995/467',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2014, 1, 29]],
#     'date-time': '2014-01-29T11:02:59Z',
#     'timestamp': 1390993379000},
#    'page': '467-560',
#    'source': 'Crossref',
#    'is-referenced-by-count': 9,
#    'title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#    'prefix': '10.1127',
#    'volume': '25',
#    'author': [{'given': 'Rainer W.',
#      'family': 'Bussmann',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'Erwin',
#      'family': 'Beck',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '181',
#    'container-title': ['Phytocoenologia'],
#    'original-title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#    'language': 'en',
#    'deposited': {'date-parts': [[2017, 4, 11]],
#     'date-time': '2017-04-11T09:04:27Z',
#     'timestamp': 1491901467000},
#    'score': 12.823445,
#    'issued': {'date-parts': [[1995, 12, 14]]},
#    'references-count': 0,
#    'journal-issue': {'published-print': {'date-parts': [[1995, 12, 14]]},
#     'issue': '4'},
#    'URL': 'http://dx.doi.org/10.1127/phyto/25/1995/467',
#    'ISSN': ['0340-269X'],
#    'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#   {'indexed': {'date-parts': [[2019, 5, 23]],
#     'date-time': '2019-05-23T10:11:30Z',
#     'timestamp': 1558606290666},
#    'reference-count': 0,
#    'publisher': 'Manchester University Press',
#    'isbn-type': [{'value': '9781526105813', 'type': 'print'},
#     {'value': '9781526135988', 'type': 'electronic'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[2019, 3, 1]]},
#    'abstract': '<p>Since the 1998 bombing of the US Embassy in Nairobi, the Government of Kenya’s response to terrorism has been multifaceted. Government efforts have primarily relied on civil authorities and the military, thus privileging the use of force over subtler means. The Kenyan Police have employed measures such as profiling, detention, and prosecution. The Kenyan military has conducted operations in Kenya and Somalia. These strategies have contributed to the apprehension of some terrorist suspects and checked Shabaab’s advance in Somalia. Yet, Kenya’s counterterrorism efforts have been hampered by limited coordination among agencies, the use of heavy-handed tactics, and insufficient engagement with civil society organizations. Two defining features of Kenyan counterterrorism efforts have emerged. First, counterterrorism in Kenya has clear sociocultural dimensions. Security forces have responded to the threat of terrorism by focusing intently on Kenya’s alienated Muslim communities both in the Somali-majority north and at the Swahili-speaking coast. As a result, the Government of Kenya’s response to terrorism reflects communal divisions and animosity within Kenyan society that precede contemporary counterterrorism. Second, Kenya’s invasion of neighboring Somalia created and blurred two fronts: one within Kenya and the other in southern Somalia. The actions of Kenyan policy-makers and al Shabaab therefore contributed to a more complete integration of the conflict in Somalia and internal tensions in Kenya..</p>',
#    'DOI': '10.7228/manchester/9781526105813.003.0016',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2019, 5, 23]],
#     'date-time': '2019-05-23T09:38:00Z',
#     'timestamp': 1558604280000},
#    'page': '386-409',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#    'prefix': '10.7228',
#    'author': [{'given': 'Jeremy',
#      'family': 'Prestholdt',
#      'sequence': 'first',
#      'affiliation': []}],
#    'member': '4230',
#    'published-online': {'date-parts': [[2019, 5, 23]]},
#    'container-title': ['Non-Western responses to terrorism'],
#    'original-title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#    'deposited': {'date-parts': [[2019, 5, 23]],
#     'date-time': '2019-05-23T09:38:00Z',
#     'timestamp': 1558604280000},
#    'score': 12.823445,
#    'issued': {'date-parts': [[2019, 3, 1]]},
#    'ISBN': ['9781526105813', '9781526135988'],
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.7228/manchester/9781526105813.003.0016'},
#   {'indexed': {'date-parts': [[2019, 10, 30]],
#     'date-time': '2019-10-30T21:03:37Z',
#     'timestamp': 1572469417577},
#    'reference-count': 0,
#    'publisher': 'Schweizerbart',
#    'issue': '4',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['phyto'],
#    'published-print': {'date-parts': [[1988, 12, 7]]},
#    'DOI': '10.1127/phyto/16/1988/433',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2014, 1, 29]],
#     'date-time': '2014-01-29T10:09:25Z',
#     'timestamp': 1390990165000},
#    'page': '433-463',
#    'source': 'Crossref',
#    'is-referenced-by-count': 9,
#    'title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#    'prefix': '10.1127',
#    'volume': '16',
#    'author': [{'given': 'H.',
#      'family': 'Rehder',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'E.',
#      'family': 'Beck',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'J. O.',
#      'family': 'Kokwaro',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '181',
#    'container-title': ['Phytocoenologia'],
#    'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#    'language': 'en',
#    'deposited': {'date-parts': [[2017, 4, 11]],
#     'date-time': '2017-04-11T10:26:22Z',
#     'timestamp': 1491906382000},
#    'score': 12.823445,
#    'issued': {'date-parts': [[1988, 12, 7]]},
#    'references-count': 0,
#    'journal-issue': {'published-print': {'date-parts': [[1988, 12, 7]]},
#     'issue': '4'},
#    'URL': 'http://dx.doi.org/10.1127/phyto/16/1988/433',
#    'ISSN': ['0340-269X'],
#    'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#   {'indexed': {'date-parts': [[2019, 2, 16]],
#     'date-time': '2019-02-16T06:30:16Z',
#     'timestamp': 1550298616836},
#    'reference-count': 0,
#    'publisher': 'Bloomsbury Publishing',
#    'isbn-type': [{'value': '9781408122549', 'type': 'print'},
#     {'value': '9781408189931', 'type': 'electronic'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.5040/9781472926944.0150',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2016, 6, 24]],
#     'date-time': '2016-06-24T17:27:36Z',
#     'timestamp': 1466789256000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Surdisorex polulus Mount Kenya Mole-shrew : Fr. Musaraigne du Mont Kenya; Ger. Mount Kenya Wühlspitzmaus'],
#    'prefix': '10.5040',
#    'member': '2984',
#    'container-title': ['Mammals of Africa : Hedgehogs, Shrews and Bats'],
#    'deposited': {'date-parts': [[2016, 7, 4]],
#     'date-time': '2016-07-04T13:54:23Z',
#     'timestamp': 1467640463000},
#    'score': 12.769443,
#    'issued': {'date-parts': [[None]]},
#    'ISBN': ['9781472926944', '9781408189931', '9781408122549'],
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.5040/9781472926944.0150'},
#   {'indexed': {'date-parts': [[2019, 4, 17]],
#     'date-time': '2019-04-17T11:11:31Z',
#     'timestamp': 1555499491401},
#    'publisher-location': 'London',
#    'reference-count': 0,
#    'publisher': 'Palgrave Macmillan UK',
#    'isbn-type': [{'value': '9781349958382', 'type': 'print'},
#     {'value': '9781349958399', 'type': 'electronic'}],
#    'license': [{'URL': 'http://www.springer.com/tdm',
#      'start': {'date-parts': [[2019, 1, 1]],
#       'date-time': '2019-01-01T00:00:00Z',
#       'timestamp': 1546300800000},
#      'delay-in-days': 0,
#      'content-version': 'tdm'}],
#    'content-domain': {'domain': ['link.springer.com'],
#     'crossmark-restriction': False},
#    'published-print': {'date-parts': [[2019]]},
#    'DOI': '10.1057/978-1-349-95839-9_1403',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2019, 4, 17]],
#     'date-time': '2019-04-17T10:48:42Z',
#     'timestamp': 1555498122000},
#    'page': '714-715',
#    'update-policy': 'http://dx.doi.org/10.1007/springer_crossmark_policy',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya'],
#    'prefix': '10.1057',
#    'member': '297',
#    'published-online': {'date-parts': [[2019, 4, 2]]},
#    'container-title': ['The Statesman’s Yearbook Companion'],
#    'link': [{'URL': 'http://link.springer.com/content/pdf/10.1057/978-1-349-95839-9_1403',
#      'content-type': 'unspecified',
#      'content-version': 'vor',
#      'intended-application': 'similarity-checking'}],
#    'deposited': {'date-parts': [[2019, 4, 17]],
#     'date-time': '2019-04-17T10:57:59Z',
#     'timestamp': 1555498679000},
#    'score': 12.769443,
#    'subtitle': ['Jamhuri ya Kenya (Republic of Kenya)'],
#    'issued': {'date-parts': [[2019]]},
#    'ISBN': ['9781349958382', '9781349958399'],
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1057/978-1-349-95839-9_1403',
#    'assertion': [{'value': '2 April 2019',
#      'order': 1,
#      'name': 'first_online',
#      'label': 'First Online',
#      'group': {'name': 'ChapterHistory', 'label': 'Chapter History'}}]},
#   {'indexed': {'date-parts': [[2019, 2, 16]],
#     'date-time': '2019-02-16T04:59:29Z',
#     'timestamp': 1550293169175},
#    'reference-count': 0,
#    'publisher': 'Kenya Meteorological Society',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['J. Meteorol. Related. Sci'],
#    'published-print': {'date-parts': [[2007, 9, 19]]},
#    'DOI': '10.20987/jmrs.08.2012.603',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2016, 5, 31]],
#     'date-time': '2016-05-31T07:04:14Z',
#     'timestamp': 1464678254000},
#    'page': '26-35',
#    'source': 'Crossref',
#    'is-referenced-by-count': 1,
#    'title': ['Use of Aquacrop Model to Predict Maize Yields under varying Rainfall and Temperature in a Semi-Arid Environment in Kenya'],
#    'prefix': '10.20987',
#    'volume': '6',
#    'author': [{'given': 'Joab',
#      'family': 'Wamari',
#      'sequence': 'first',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'Sijali',
#      'family': 'Isaya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'Lee',
#      'family': 'Kheng',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'Joseph',
#      'family': 'Miriti',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'Esilaba',
#      'family': 'Obutiati',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Soil and Water management and Crop Nutrition Section',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'National Agricultural Research Centre -Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research institute',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '8610',
#    'container-title': ['Journal of Meteorology and Related Sciences'],
#    'deposited': {'date-parts': [[2017, 7, 26]],
#     'date-time': '2017-07-26T21:59:54Z',
#     'timestamp': 1501106394000},
#    'score': 12.716235,
#    'issued': {'date-parts': [[2007, 9, 19]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.20987/jmrs.08.2012.603',
#    'ISSN': ['1995-9834', '2412-3781'],
#    'issn-type': [{'value': '1995-9834', 'type': 'print'},
#     {'value': '2412-3781', 'type': 'electronic'}]},
#   {'indexed': {'date-parts': [[2019, 2, 13]],
#     'date-time': '2019-02-13T22:23:59Z',
#     'timestamp': 1550096639282},
#    'reference-count': 0,
#    'publisher': 'Geological Society of America',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1130/2014.dmch016.s1',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2014, 3, 14]],
#     'date-time': '2014-03-14T17:56:58Z',
#     'timestamp': 1394819818000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Geology of the Suswa Region, Kenya'],
#    'prefix': '10.1130',
#    'member': '257',
#    'published-online': {'date-parts': [[2014, 3, 14]]},
#    'container-title': ['Maps of the Southern Kenya Rift'],
#    'deposited': {'date-parts': [[2014, 3, 14]],
#     'date-time': '2014-03-14T17:56:59Z',
#     'timestamp': 1394819819000},
#    'score': 12.654307,
#    'issued': {'date-parts': [[2014, 3, 14]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s1'},
#   {'indexed': {'date-parts': [[2019, 2, 13]],
#     'date-time': '2019-02-13T22:23:59Z',
#     'timestamp': 1550096639288},
#    'reference-count': 0,
#    'publisher': 'Geological Society of America',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1130/2014.dmch016.s2',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2014, 3, 14]],
#     'date-time': '2014-03-14T17:56:58Z',
#     'timestamp': 1394819818000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Geology of the Nairobi Region, Kenya'],
#    'prefix': '10.1130',
#    'member': '257',
#    'published-online': {'date-parts': [[2014, 3, 14]]},
#    'container-title': ['Maps of the Southern Kenya Rift'],
#    'deposited': {'date-parts': [[2014, 3, 14]],
#     'date-time': '2014-03-14T17:56:59Z',
#     'timestamp': 1394819819000},
#    'score': 12.654307,
#    'issued': {'date-parts': [[2014, 3, 14]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s2'},
#   {'indexed': {'date-parts': [[2019, 2, 13]],
#     'date-time': '2019-02-13T22:23:59Z',
#     'timestamp': 1550096639297},
#    'reference-count': 0,
#    'publisher': 'Geological Society of America',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1130/2014.dmch016.s4',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2014, 3, 14]],
#     'date-time': '2014-03-14T17:56:58Z',
#     'timestamp': 1394819818000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Geology of the Kajiado Region, Kenya'],
#    'prefix': '10.1130',
#    'member': '257',
#    'published-online': {'date-parts': [[2014, 3, 14]]},
#    'container-title': ['Maps of the Southern Kenya Rift'],
#    'deposited': {'date-parts': [[2014, 3, 14]],
#     'date-time': '2014-03-14T17:56:59Z',
#     'timestamp': 1394819819000},
#    'score': 12.654307,
#    'issued': {'date-parts': [[2014, 3, 14]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s4'},
#   {'indexed': {'date-parts': [[2019, 2, 13]],
#     'date-time': '2019-02-13T22:23:59Z',
#     'timestamp': 1550096639297},
#    'reference-count': 0,
#    'publisher': 'Geological Society of America',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1130/2014.dmch016.s5',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2014, 3, 14]],
#     'date-time': '2014-03-14T17:56:58Z',
#     'timestamp': 1394819818000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Geology of the Area South of Magadi, Kenya'],
#    'prefix': '10.1130',
#    'member': '257',
#    'published-online': {'date-parts': [[2014, 3, 14]]},
#    'container-title': ['Maps of the Southern Kenya Rift'],
#    'deposited': {'date-parts': [[2014, 3, 14]],
#     'date-time': '2014-03-14T17:57:00Z',
#     'timestamp': 1394819820000},
#    'score': 12.654307,
#    'issued': {'date-parts': [[2014, 3, 14]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s5'}],
#  'items-per-page': 20,
#  'query': {'start-index': 0, 'search-terms': 'kenya'}}

# %%
kenya['message']['facets']
# Out:
# {}

# %%
# This tells us that the total number of results referencing Kenya correspond with a web based query.
kenya['message']['total-results']
# Out:
# 40401

# %%
kenya['message']['items-per-page']
# Out:
# 20

# %%
kenya['message']['query']
# Out:
# {'start-index': 0, 'search-terms': 'kenya'}

# %%
kenya['message']['items']
# Out:
# [{'indexed': {'date-parts': [[2019, 2, 14]],
#    'date-time': '2019-02-14T21:24:56Z',
#    'timestamp': 1550179496572},
#   'reference-count': 0,
#   'publisher': 'Centro Internacional de Agricultura Tropical',
#   'issue': '1',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Trop Grass - Forr Trop'],
#   'DOI': '10.17138/tgft(2)100-102',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2015, 4, 1]],
#    'date-time': '2015-04-01T20:32:16Z',
#    'timestamp': 1427920336000},
#   'page': '100',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Production of giant Panicum in semi-arid Kenya'],
#   'prefix': '10.17138',
#   'volume': '2',
#   'author': [{'given': 'Donald M.G.',
#     'family': 'Njarui',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Mwangi',
#     'family': 'Gatheru',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'David M.',
#     'family': 'Mwangi',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'George A.',
#     'family': 'Keya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '6578',
#   'published-online': {'date-parts': [[2014]]},
#   'container-title': ['Tropical Grasslands - Forrajes Tropicales'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2015, 4, 1]],
#    'date-time': '2015-04-01T20:32:45Z',
#    'timestamp': 1427920365000},
#   'score': 13.489236,
#   'issued': {'date-parts': [[2014]]},
#   'references-count': 0,
#   'journal-issue': {'published-online': {'date-parts': [[2014]]},
#    'issue': '1'},
#   'alternative-id': ['136/84'],
#   'URL': 'http://dx.doi.org/10.17138/tgft(2)100-102',
#   'ISSN': ['2346-3775'],
#   'issn-type': [{'value': '2346-3775', 'type': 'electronic'}]},
#  {'indexed': {'date-parts': [[2019, 2, 18]],
#    'date-time': '2019-02-18T01:48:14Z',
#    'timestamp': 1550454494058},
#   'reference-count': 0,
#   'publisher': 'International Journal Of Advanced Research',
#   'issue': '2',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['IJAR'],
#   'DOI': '10.21474/ijar01/6544',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2018, 3, 30]],
#    'date-time': '2018-03-30T10:49:35Z',
#    'timestamp': 1522406975000},
#   'page': '1195-1203',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['SOCIAL DETERMINANTS INFLUENCING TRANSITION RATE OF GIRLS FROM PRIMARY EDUCATION TO SECONDARY EDUCATION IN KOIBATEK SUB-COUNTY, KENYA.'],
#   'prefix': '10.21474',
#   'volume': '6',
#   'author': [{'given': 'GladysJerono',
#     'family': 'Koech',
#     'sequence': 'first',
#     'affiliation': []},
#    {'name': 'Mount Kenya University, Kenya',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'JoshuaOdhiambo',
#     'family': 'Ogal',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Rachael',
#     'family': 'Koros',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Mount Kenya University, Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Mount Kenya University, Kenya',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '8913',
#   'published-online': {'date-parts': [[2018, 2, 28]]},
#   'container-title': ['International Journal of Advanced Research'],
#   'deposited': {'date-parts': [[2018, 3, 30]],
#    'date-time': '2018-03-30T10:49:35Z',
#    'timestamp': 1522406975000},
#   'score': 13.427694,
#   'issued': {'date-parts': [[2018, 2, 28]]},
#   'references-count': 0,
#   'journal-issue': {'published-online': {'date-parts': [[2018, 2, 28]]},
#    'issue': '2'},
#   'URL': 'http://dx.doi.org/10.21474/ijar01/6544',
#   'ISSN': ['2320-5407'],
#   'issn-type': [{'value': '2320-5407', 'type': 'electronic'}]},
#  {'indexed': {'date-parts': [[2019, 9, 17]],
#    'date-time': '2019-09-17T10:03:43Z',
#    'timestamp': 1568714623872},
#   'publisher-location': 'Nairobi :',
#   'reference-count': 0,
#   'publisher': 'Nature Kenya, East Africa Natural History Society,',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[1999]]},
#   'DOI': '10.5962/bhl.title.87589',
#   'type': 'monograph',
#   'created': {'date-parts': [[2014, 8, 24]],
#    'date-time': '2014-08-24T06:00:31Z',
#    'timestamp': 1408860031000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 74,
#   'title': ['Important bird areas in Kenya /'],
#   'prefix': '10.5962',
#   'author': [{'given': 'Leon A.',
#     'family': 'Bennun',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Peter.',
#     'family': 'Njoroge',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'National Museums of Kenya.',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Nature Kenya.', 'sequence': 'additional', 'affiliation': []}],
#   'member': '3444',
#   'deposited': {'date-parts': [[2014, 8, 24]],
#    'date-time': '2014-08-24T06:00:31Z',
#    'timestamp': 1408860031000},
#   'score': 13.410743,
#   'issued': {'date-parts': [[1999]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.5962/bhl.title.87589'},
#  {'indexed': {'date-parts': [[2019, 2, 25]],
#    'date-time': '2019-02-25T09:42:41Z',
#    'timestamp': 1551087761542},
#   'publisher-location': 'Berlin, Boston',
#   'reference-count': 0,
#   'publisher': 'De Gruyter',
#   'isbn-type': [{'value': '9783110826050', 'type': 'electronic'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[1972, 12, 31]]},
#   'DOI': '10.1515/9783110826050-068',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2019, 2, 25]],
#    'date-time': '2019-02-25T09:01:06Z',
#    'timestamp': 1551085266000},
#   'page': '304-305',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya. Jamhuri ya Kenya; Republic of Kenya'],
#   'prefix': '10.1515',
#   'member': '374',
#   'container-title': ['Minerva. Internationales Verzeichnis Wissenschaftlicher Institutionen'],
#   'link': [{'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#     'content-type': 'text/html',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#     'content-type': 'unspecified',
#     'content-version': 'vor',
#     'intended-application': 'similarity-checking'}],
#   'deposited': {'date-parts': [[2019, 2, 25]],
#    'date-time': '2019-02-25T09:11:29Z',
#    'timestamp': 1551085889000},
#   'score': 13.410743,
#   'editor': [{'given': 'Werner',
#     'family': 'Schuder',
#     'sequence': 'first',
#     'affiliation': []}],
#   'issued': {'date-parts': [[1972, 12, 31]]},
#   'ISBN': ['9783110826050'],
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1515/9783110826050-068'},
#  {'indexed': {'date-parts': [[2019, 2, 15]],
#    'date-time': '2019-02-15T19:33:11Z',
#    'timestamp': 1550259191789},
#   'reference-count': 0,
#   'publisher': 'Commonwealth Secretariat',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[1987, 12, 1]]},
#   'DOI': '10.14217/9781848594371-12-en',
#   'type': 'component',
#   'created': {'date-parts': [[2016, 1, 29]],
#    'date-time': '2016-01-29T06:18:13Z',
#    'timestamp': 1454048293000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya: Kenya Law Reform Commission'],
#   'prefix': '10.14217',
#   'author': [{'name': 'Commonwealth Secretariat',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '5318',
#   'deposited': {'date-parts': [[2018, 10, 7]],
#    'date-time': '2018-10-07T08:05:04Z',
#    'timestamp': 1538899504000},
#   'score': 13.38026,
#   'issued': {'date-parts': [[1987, 12, 1]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.14217/9781848594371-12-en'},
#  {'indexed': {'date-parts': [[2019, 5, 11]],
#    'date-time': '2019-05-11T22:03:07Z',
#    'timestamp': 1557612187692},
#   'reference-count': 0,
#   'publisher': 'Commonwealth Secretariat',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[1992, 1, 1]]},
#   'DOI': '10.14217/9781848594920-13-en',
#   'type': 'component',
#   'created': {'date-parts': [[2016, 1, 29]],
#    'date-time': '2016-01-29T06:18:13Z',
#    'timestamp': 1454048293000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Kenya: Kenya Law Reform Commission'],
#   'prefix': '10.14217',
#   'author': [{'name': 'Commonwealth Secretariat',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '5318',
#   'deposited': {'date-parts': [[2018, 10, 8]],
#    'date-time': '2018-10-08T07:55:20Z',
#    'timestamp': 1538985320000},
#   'score': 13.38026,
#   'issued': {'date-parts': [[1992, 1, 1]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.14217/9781848594920-13-en'},
#  {'indexed': {'date-parts': [[2019, 2, 13]],
#    'date-time': '2019-02-13T19:33:11Z',
#    'timestamp': 1550086391566},
#   'reference-count': 0,
#   'publisher': 'Schweizerbart',
#   'issue': '2',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['phyto'],
#   'published-print': {'date-parts': [[1989, 5, 2]]},
#   'DOI': '10.1127/phyto/17/1989/287',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2014, 1, 29]],
#    'date-time': '2014-01-29T10:09:25Z',
#    'timestamp': 1390990165000},
#   'page': '287-288',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#   'prefix': '10.1127',
#   'volume': '17',
#   'author': [{'given': 'H.',
#     'family': 'Rehder',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'E.',
#     'family': 'Beck',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'J. O.',
#     'family': 'Kokwaro',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '181',
#   'container-title': ['Phytocoenologia'],
#   'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2017, 4, 11]],
#    'date-time': '2017-04-11T09:00:28Z',
#    'timestamp': 1491901228000},
#   'score': 12.960362,
#   'issued': {'date-parts': [[1989, 5, 2]]},
#   'references-count': 0,
#   'journal-issue': {'published-print': {'date-parts': [[1989, 5, 2]]},
#    'issue': '2'},
#   'URL': 'http://dx.doi.org/10.1127/phyto/17/1989/287',
#   'ISSN': ['0340-269X'],
#   'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#  {'indexed': {'date-parts': [[2019, 5, 23]],
#    'date-time': '2019-05-23T14:43:08Z',
#    'timestamp': 1558622588993},
#   'reference-count': 0,
#   'publisher': 'African Journal of Food, Agriculture, Nutrition and Development',
#   'issue': '01',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['AJFAND'],
#   'DOI': '10.18697/ajfand.84.blfb1017',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2019, 2, 2]],
#    'date-time': '2019-02-02T09:05:42Z',
#    'timestamp': 1549098342000},
#   'page': '14010-14042',
#   'source': 'Crossref',
#   'is-referenced-by-count': 15,
#   'title': ['Climate Change Effects on Crop Production in Kenya: Farmer Perceptions and Adaptation Strategies'],
#   'prefix': '10.18697',
#   'volume': '19',
#   'author': [{'given': 'Beverly',
#     'family': 'Agesa',
#     'sequence': 'first',
#     'affiliation': []},
#    {'name': 'University  of Nairobi, Nairobi, Kenya',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'CM',
#     'family': 'Onyango',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'VM',
#     'family': 'Kathumo',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'RN',
#     'family': 'Onwonga',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'GN',
#     'family': 'Karuku',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'University  of  Nairobi, Nairobi, Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'University  of  Nairobi,  Nairobi, Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'University  of Nairobi, Nairobi, Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Univesity of Nairobi, Nairobi, Kenya',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '8080',
#   'published-online': {'date-parts': [[2019, 2, 1]]},
#   'container-title': ['African Journal of Food, Agriculture, Nutrition and Development'],
#   'link': [{'URL': 'https://www.ajfand.net/Volume19/No1/BLFB1017.pdf',
#     'content-type': 'unspecified',
#     'content-version': 'vor',
#     'intended-application': 'similarity-checking'}],
#   'deposited': {'date-parts': [[2019, 2, 2]],
#    'date-time': '2019-02-02T09:05:44Z',
#    'timestamp': 1549098344000},
#   'score': 12.960362,
#   'issued': {'date-parts': [[2019, 2, 1]]},
#   'references-count': 0,
#   'journal-issue': {'published-online': {'date-parts': [[2019, 2, 1]]},
#    'issue': '01'},
#   'URL': 'http://dx.doi.org/10.18697/ajfand.84.blfb1017',
#   'ISSN': ['1684-5374'],
#   'issn-type': [{'value': '1684-5374', 'type': 'electronic'}]},
#  {'indexed': {'date-parts': [[2019, 2, 14]],
#    'date-time': '2019-02-14T06:31:57Z',
#    'timestamp': 1550125917962},
#   'reference-count': 0,
#   'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1787/270604575355',
#   'type': 'component',
#   'created': {'date-parts': [[2008, 9, 30]],
#    'date-time': '2008-09-30T12:02:13Z',
#    'timestamp': 1222776133000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya'],
#   'prefix': '10.1787',
#   'member': '1963',
#   'deposited': {'date-parts': [[2014, 5, 27]],
#    'date-time': '2014-05-27T17:04:57Z',
#    'timestamp': 1401210297000},
#   'score': 12.92699,
#   'issued': {'date-parts': [[None]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1787/270604575355'},
#  {'indexed': {'date-parts': [[2019, 2, 14]],
#    'date-time': '2019-02-14T06:31:57Z',
#    'timestamp': 1550125917764},
#   'reference-count': 0,
#   'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1787/124030037050',
#   'type': 'component',
#   'created': {'date-parts': [[2008, 9, 30]],
#    'date-time': '2008-09-30T12:02:13Z',
#    'timestamp': 1222776133000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya'],
#   'prefix': '10.1787',
#   'member': '1963',
#   'deposited': {'date-parts': [[2014, 5, 27]],
#    'date-time': '2014-05-27T17:04:56Z',
#    'timestamp': 1401210296000},
#   'score': 12.92699,
#   'issued': {'date-parts': [[None]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1787/124030037050'},
#  {'indexed': {'date-parts': [[2019, 4, 1]],
#    'date-time': '2019-04-01T23:03:44Z',
#    'timestamp': 1554159824661},
#   'reference-count': 0,
#   'publisher': 'Schweizerbart',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['phyto'],
#   'published-print': {'date-parts': [[1995, 12, 14]]},
#   'DOI': '10.1127/phyto/25/1995/467',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2014, 1, 29]],
#    'date-time': '2014-01-29T11:02:59Z',
#    'timestamp': 1390993379000},
#   'page': '467-560',
#   'source': 'Crossref',
#   'is-referenced-by-count': 9,
#   'title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#   'prefix': '10.1127',
#   'volume': '25',
#   'author': [{'given': 'Rainer W.',
#     'family': 'Bussmann',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Erwin',
#     'family': 'Beck',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '181',
#   'container-title': ['Phytocoenologia'],
#   'original-title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2017, 4, 11]],
#    'date-time': '2017-04-11T09:04:27Z',
#    'timestamp': 1491901467000},
#   'score': 12.823445,
#   'issued': {'date-parts': [[1995, 12, 14]]},
#   'references-count': 0,
#   'journal-issue': {'published-print': {'date-parts': [[1995, 12, 14]]},
#    'issue': '4'},
#   'URL': 'http://dx.doi.org/10.1127/phyto/25/1995/467',
#   'ISSN': ['0340-269X'],
#   'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#  {'indexed': {'date-parts': [[2019, 5, 23]],
#    'date-time': '2019-05-23T10:11:30Z',
#    'timestamp': 1558606290666},
#   'reference-count': 0,
#   'publisher': 'Manchester University Press',
#   'isbn-type': [{'value': '9781526105813', 'type': 'print'},
#    {'value': '9781526135988', 'type': 'electronic'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[2019, 3, 1]]},
#   'abstract': '<p>Since the 1998 bombing of the US Embassy in Nairobi, the Government of Kenya’s response to terrorism has been multifaceted. Government efforts have primarily relied on civil authorities and the military, thus privileging the use of force over subtler means. The Kenyan Police have employed measures such as profiling, detention, and prosecution. The Kenyan military has conducted operations in Kenya and Somalia. These strategies have contributed to the apprehension of some terrorist suspects and checked Shabaab’s advance in Somalia. Yet, Kenya’s counterterrorism efforts have been hampered by limited coordination among agencies, the use of heavy-handed tactics, and insufficient engagement with civil society organizations. Two defining features of Kenyan counterterrorism efforts have emerged. First, counterterrorism in Kenya has clear sociocultural dimensions. Security forces have responded to the threat of terrorism by focusing intently on Kenya’s alienated Muslim communities both in the Somali-majority north and at the Swahili-speaking coast. As a result, the Government of Kenya’s response to terrorism reflects communal divisions and animosity within Kenyan society that precede contemporary counterterrorism. Second, Kenya’s invasion of neighboring Somalia created and blurred two fronts: one within Kenya and the other in southern Somalia. The actions of Kenyan policy-makers and al Shabaab therefore contributed to a more complete integration of the conflict in Somalia and internal tensions in Kenya..</p>',
#   'DOI': '10.7228/manchester/9781526105813.003.0016',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2019, 5, 23]],
#    'date-time': '2019-05-23T09:38:00Z',
#    'timestamp': 1558604280000},
#   'page': '386-409',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#   'prefix': '10.7228',
#   'author': [{'given': 'Jeremy',
#     'family': 'Prestholdt',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '4230',
#   'published-online': {'date-parts': [[2019, 5, 23]]},
#   'container-title': ['Non-Western responses to terrorism'],
#   'original-title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#   'deposited': {'date-parts': [[2019, 5, 23]],
#    'date-time': '2019-05-23T09:38:00Z',
#    'timestamp': 1558604280000},
#   'score': 12.823445,
#   'issued': {'date-parts': [[2019, 3, 1]]},
#   'ISBN': ['9781526105813', '9781526135988'],
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.7228/manchester/9781526105813.003.0016'},
#  {'indexed': {'date-parts': [[2019, 10, 30]],
#    'date-time': '2019-10-30T21:03:37Z',
#    'timestamp': 1572469417577},
#   'reference-count': 0,
#   'publisher': 'Schweizerbart',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['phyto'],
#   'published-print': {'date-parts': [[1988, 12, 7]]},
#   'DOI': '10.1127/phyto/16/1988/433',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2014, 1, 29]],
#    'date-time': '2014-01-29T10:09:25Z',
#    'timestamp': 1390990165000},
#   'page': '433-463',
#   'source': 'Crossref',
#   'is-referenced-by-count': 9,
#   'title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#   'prefix': '10.1127',
#   'volume': '16',
#   'author': [{'given': 'H.',
#     'family': 'Rehder',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'E.',
#     'family': 'Beck',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'J. O.',
#     'family': 'Kokwaro',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '181',
#   'container-title': ['Phytocoenologia'],
#   'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2017, 4, 11]],
#    'date-time': '2017-04-11T10:26:22Z',
#    'timestamp': 1491906382000},
#   'score': 12.823445,
#   'issued': {'date-parts': [[1988, 12, 7]]},
#   'references-count': 0,
#   'journal-issue': {'published-print': {'date-parts': [[1988, 12, 7]]},
#    'issue': '4'},
#   'URL': 'http://dx.doi.org/10.1127/phyto/16/1988/433',
#   'ISSN': ['0340-269X'],
#   'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#  {'indexed': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T06:30:16Z',
#    'timestamp': 1550298616836},
#   'reference-count': 0,
#   'publisher': 'Bloomsbury Publishing',
#   'isbn-type': [{'value': '9781408122549', 'type': 'print'},
#    {'value': '9781408189931', 'type': 'electronic'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.5040/9781472926944.0150',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2016, 6, 24]],
#    'date-time': '2016-06-24T17:27:36Z',
#    'timestamp': 1466789256000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Surdisorex polulus Mount Kenya Mole-shrew : Fr. Musaraigne du Mont Kenya; Ger. Mount Kenya Wühlspitzmaus'],
#   'prefix': '10.5040',
#   'member': '2984',
#   'container-title': ['Mammals of Africa : Hedgehogs, Shrews and Bats'],
#   'deposited': {'date-parts': [[2016, 7, 4]],
#    'date-time': '2016-07-04T13:54:23Z',
#    'timestamp': 1467640463000},
#   'score': 12.769443,
#   'issued': {'date-parts': [[None]]},
#   'ISBN': ['9781472926944', '9781408189931', '9781408122549'],
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.5040/9781472926944.0150'},
#  {'indexed': {'date-parts': [[2019, 4, 17]],
#    'date-time': '2019-04-17T11:11:31Z',
#    'timestamp': 1555499491401},
#   'publisher-location': 'London',
#   'reference-count': 0,
#   'publisher': 'Palgrave Macmillan UK',
#   'isbn-type': [{'value': '9781349958382', 'type': 'print'},
#    {'value': '9781349958399', 'type': 'electronic'}],
#   'license': [{'URL': 'http://www.springer.com/tdm',
#     'start': {'date-parts': [[2019, 1, 1]],
#      'date-time': '2019-01-01T00:00:00Z',
#      'timestamp': 1546300800000},
#     'delay-in-days': 0,
#     'content-version': 'tdm'}],
#   'content-domain': {'domain': ['link.springer.com'],
#    'crossmark-restriction': False},
#   'published-print': {'date-parts': [[2019]]},
#   'DOI': '10.1057/978-1-349-95839-9_1403',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2019, 4, 17]],
#    'date-time': '2019-04-17T10:48:42Z',
#    'timestamp': 1555498122000},
#   'page': '714-715',
#   'update-policy': 'http://dx.doi.org/10.1007/springer_crossmark_policy',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya'],
#   'prefix': '10.1057',
#   'member': '297',
#   'published-online': {'date-parts': [[2019, 4, 2]]},
#   'container-title': ['The Statesman’s Yearbook Companion'],
#   'link': [{'URL': 'http://link.springer.com/content/pdf/10.1057/978-1-349-95839-9_1403',
#     'content-type': 'unspecified',
#     'content-version': 'vor',
#     'intended-application': 'similarity-checking'}],
#   'deposited': {'date-parts': [[2019, 4, 17]],
#    'date-time': '2019-04-17T10:57:59Z',
#    'timestamp': 1555498679000},
#   'score': 12.769443,
#   'subtitle': ['Jamhuri ya Kenya (Republic of Kenya)'],
#   'issued': {'date-parts': [[2019]]},
#   'ISBN': ['9781349958382', '9781349958399'],
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1057/978-1-349-95839-9_1403',
#   'assertion': [{'value': '2 April 2019',
#     'order': 1,
#     'name': 'first_online',
#     'label': 'First Online',
#     'group': {'name': 'ChapterHistory', 'label': 'Chapter History'}}]},
#  {'indexed': {'date-parts': [[2019, 2, 16]],
#    'date-time': '2019-02-16T04:59:29Z',
#    'timestamp': 1550293169175},
#   'reference-count': 0,
#   'publisher': 'Kenya Meteorological Society',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['J. Meteorol. Related. Sci'],
#   'published-print': {'date-parts': [[2007, 9, 19]]},
#   'DOI': '10.20987/jmrs.08.2012.603',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2016, 5, 31]],
#    'date-time': '2016-05-31T07:04:14Z',
#    'timestamp': 1464678254000},
#   'page': '26-35',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Use of Aquacrop Model to Predict Maize Yields under varying Rainfall and Temperature in a Semi-Arid Environment in Kenya'],
#   'prefix': '10.20987',
#   'volume': '6',
#   'author': [{'given': 'Joab',
#     'family': 'Wamari',
#     'sequence': 'first',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Sijali',
#     'family': 'Isaya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Lee',
#     'family': 'Kheng',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Joseph',
#     'family': 'Miriti',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Esilaba',
#     'family': 'Obutiati',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Soil and Water management and Crop Nutrition Section',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'National Agricultural Research Centre -Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research institute',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '8610',
#   'container-title': ['Journal of Meteorology and Related Sciences'],
#   'deposited': {'date-parts': [[2017, 7, 26]],
#    'date-time': '2017-07-26T21:59:54Z',
#    'timestamp': 1501106394000},
#   'score': 12.716235,
#   'issued': {'date-parts': [[2007, 9, 19]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.20987/jmrs.08.2012.603',
#   'ISSN': ['1995-9834', '2412-3781'],
#   'issn-type': [{'value': '1995-9834', 'type': 'print'},
#    {'value': '2412-3781', 'type': 'electronic'}]},
#  {'indexed': {'date-parts': [[2019, 2, 13]],
#    'date-time': '2019-02-13T22:23:59Z',
#    'timestamp': 1550096639282},
#   'reference-count': 0,
#   'publisher': 'Geological Society of America',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1130/2014.dmch016.s1',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2014, 3, 14]],
#    'date-time': '2014-03-14T17:56:58Z',
#    'timestamp': 1394819818000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Geology of the Suswa Region, Kenya'],
#   'prefix': '10.1130',
#   'member': '257',
#   'published-online': {'date-parts': [[2014, 3, 14]]},
#   'container-title': ['Maps of the Southern Kenya Rift'],
#   'deposited': {'date-parts': [[2014, 3, 14]],
#    'date-time': '2014-03-14T17:56:59Z',
#    'timestamp': 1394819819000},
#   'score': 12.654307,
#   'issued': {'date-parts': [[2014, 3, 14]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s1'},
#  {'indexed': {'date-parts': [[2019, 2, 13]],
#    'date-time': '2019-02-13T22:23:59Z',
#    'timestamp': 1550096639288},
#   'reference-count': 0,
#   'publisher': 'Geological Society of America',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1130/2014.dmch016.s2',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2014, 3, 14]],
#    'date-time': '2014-03-14T17:56:58Z',
#    'timestamp': 1394819818000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Geology of the Nairobi Region, Kenya'],
#   'prefix': '10.1130',
#   'member': '257',
#   'published-online': {'date-parts': [[2014, 3, 14]]},
#   'container-title': ['Maps of the Southern Kenya Rift'],
#   'deposited': {'date-parts': [[2014, 3, 14]],
#    'date-time': '2014-03-14T17:56:59Z',
#    'timestamp': 1394819819000},
#   'score': 12.654307,
#   'issued': {'date-parts': [[2014, 3, 14]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s2'},
#  {'indexed': {'date-parts': [[2019, 2, 13]],
#    'date-time': '2019-02-13T22:23:59Z',
#    'timestamp': 1550096639297},
#   'reference-count': 0,
#   'publisher': 'Geological Society of America',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1130/2014.dmch016.s4',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2014, 3, 14]],
#    'date-time': '2014-03-14T17:56:58Z',
#    'timestamp': 1394819818000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Geology of the Kajiado Region, Kenya'],
#   'prefix': '10.1130',
#   'member': '257',
#   'published-online': {'date-parts': [[2014, 3, 14]]},
#   'container-title': ['Maps of the Southern Kenya Rift'],
#   'deposited': {'date-parts': [[2014, 3, 14]],
#    'date-time': '2014-03-14T17:56:59Z',
#    'timestamp': 1394819819000},
#   'score': 12.654307,
#   'issued': {'date-parts': [[2014, 3, 14]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s4'},
#  {'indexed': {'date-parts': [[2019, 2, 13]],
#    'date-time': '2019-02-13T22:23:59Z',
#    'timestamp': 1550096639297},
#   'reference-count': 0,
#   'publisher': 'Geological Society of America',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1130/2014.dmch016.s5',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2014, 3, 14]],
#    'date-time': '2014-03-14T17:56:58Z',
#    'timestamp': 1394819818000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Geology of the Area South of Magadi, Kenya'],
#   'prefix': '10.1130',
#   'member': '257',
#   'published-online': {'date-parts': [[2014, 3, 14]]},
#   'container-title': ['Maps of the Southern Kenya Rift'],
#   'deposited': {'date-parts': [[2014, 3, 14]],
#    'date-time': '2014-03-14T17:57:00Z',
#    'timestamp': 1394819820000},
#   'score': 12.654307,
#   'issued': {'date-parts': [[2014, 3, 14]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1130/2014.dmch016.s5'}]

# %%
df_kenya = pd.DataFrame(kenya['message']['items'])

# %%
#get the column names of the dataframe
df_kenya.columns
# Out:
# Index(['DOI', 'ISBN', 'ISSN', 'URL', 'abstract', 'alternative-id', 'assertion',
#        'author', 'container-title', 'content-domain', 'created', 'deposited',
#        'editor', 'indexed', 'is-referenced-by-count', 'isbn-type', 'issn-type',
#        'issue', 'issued', 'journal-issue', 'language', 'license', 'link',
#        'member', 'original-title', 'page', 'prefix', 'published-online',
#        'published-print', 'publisher', 'publisher-location', 'reference-count',
#        'references-count', 'score', 'short-container-title', 'source',
#        'subtitle', 'title', 'type', 'update-policy', 'volume'],
#       dtype='object')

# %%
cr_kenya = cr.works(query="kenya", cursor = "*", cursor_max = 2000)

# %%
sum([len(k['message']['items']) for k in cr_kenya])
# Out:
# 2000

# %%
items = [k['message']['items'] for k in cr_kenya]
items = [ item for sublist in items for item in sublist]
items[0]['reference']
# Out:
# [{'key': 'BIB1',
#   'author': 'Andrews',
#   'volume': '69',
#   'first-page': '167',
#   'year': '1984',
#   'journal-title': 'Courier Forschungsinstitut Senckenberg'},
#  {'key': 'BIB2',
#   'author': 'Behrensmeyer',
#   'volume': '2',
#   'first-page': '150',
#   'year': '1978',
#   'journal-title': 'Paleobiology',
#   'DOI': '10.1017/S0094837300005820',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB3',
#   'author': 'Binford',
#   'volume': '37',
#   'first-page': '195',
#   'year': '1981',
#   'journal-title': 'Journal of Anthropological Research',
#   'DOI': '10.1086/jar.37.3.3629723',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB4',
#   'author': 'Blumenschine',
#   'volume': '21',
#   'first-page': '451',
#   'year': '1991',
#   'journal-title': 'Journal of Human Evolution',
#   'DOI': '10.1016/0047-2484(91)90095-D',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB5',
#   'author': 'Bonnefille',
#   'first-page': '299',
#   'year': '1995',
#   'unstructured': '( 1995). A reassessment of the Plio-Pleistocene pollen record of East Africa. In & (Eds.), Paleoclimate and evolution, with emphasis on human origins (pp. 299-310). New Haven, CT: Yale University Press.',
#   'volume-title': 'Paleoclimate and evolution, with emphasis on human origins'},
#  {'key': 'BIB6',
#   'author': 'Brauer',
#   'volume': '9',
#   'first-page': '352',
#   'year': '1990',
#   'journal-title': 'Acta Anthropologica Sinica'},
#  {'key': 'BIB7',
#   'author': 'Brown',
#   'volume': '316',
#   'first-page': '794',
#   'year': '1985',
#   'journal-title': 'Nature',
#   'DOI': '10.1038/316794a0',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB8',
#   'author': 'Brown',
#   'volume': '143',
#   'first-page': '297',
#   'year': '1986',
#   'journal-title': 'Journal of the Geological Society',
#   'DOI': '10.1144/gsjgs.143.2.0297',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB9',
#   'author': 'Brown',
#   'first-page': '325',
#   'year': '1988',
#   'unstructured': '& ( 1988). ?Robust? hominids and Plio-Pleistocene palaeogeography of the Turkana basin, Kenya and Ethiopia. In (Ed.), Evolutionary history of the ?Robust? Australopithecines (pp. 325-341). New York: Aldine de Gruyter.',
#   'volume-title': 'Evolutionary history of the ?Robust? Australopithecines'},
#  {'key': 'BIB10',
#   'author': 'Brown',
#   'first-page': '1',
#   'year': '1991',
#   'unstructured': '& ( 1991). Stratigraphy, depositional environments, and palaeogeography of the Koobi Fora Formation. In (Ed.), Koobi Fora research project, Volume 3, Artiodactyls and palaeoenvironments (pp. 1-30). Oxford: Clarendon Press.',
#   'volume-title': 'Koobi Fora research project, Volume 3, Artiodactyls and palaeoenvironments'},
#  {'key': 'BIB11',
#   'author': 'Bunn',
#   'first-page': '402',
#   'year': '1997',
#   'unstructured': '( 1997). The bone assemblages from the excavated sites. In (Ed.), Koobi Fora research project, Volume 5, The archaeology (pp. 402-444). Oxford: Clarendon Press.',
#   'volume-title': 'Koobi Fora research project, Volume 5, The archaeology'},
#  {'key': 'BIB12',
#   'author': 'Cebula',
#   'volume': '6',
#   'first-page': '139',
#   'year': '1986',
#   'journal-title': 'Terra Cognita Abstracts'},
#  {'key': 'BIB13',
#   'author': 'Cerling',
#   'volume': '97',
#   'first-page': '241',
#   'year': '1992',
#   'journal-title': 'Palaeogeography, Palaeoclimatology, Palaeoecology',
#   'DOI': '10.1016/0031-0182(92)90211-M',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB14',
#   'author': 'Conard',
#   'volume': '35',
#   'first-page': '281',
#   'year': '1994',
#   'journal-title': 'Current Anthropology',
#   'DOI': '10.1086/204273',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB15',
#   'author': 'Coppens',
#   'year': '1976',
#   'unstructured': '& Eds., ( 1976). Earliest man and environments in the Lake Rudolf Basin. Chicago: University of Chicago Press.',
#   'volume-title': 'Earliest man and environments in the Lake Rudolf Basin'},
#  {'key': 'BIB16',
#   'author': 'Feibel',
#   'year': '1988',
#   'unstructured': '( 1988). Palaeoenvironments of the Koobi Fora Formation, Turkana Basin, Northern Kenya. Unpublished doctoral dissertation, University of Utah, Salt Lake City.'},
#  {'key': 'BIB17',
#   'author': 'Feibel',
#   'first-page': '21',
#   'year': '1993',
#   'unstructured': '& ( 1993). Microstratigraphy and paleoenvironments. In & (Eds.), The Nariokotome Homo erectus skeleton (pp. 21-39). Cambridge, MA: Harvard University Press.',
#   'volume-title': 'The Nariokotome Homo erectus skeleton',
#   'DOI': '10.1007/978-3-662-10382-1_3',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB18',
#   'author': 'Feibel',
#   'first-page': '321',
#   'year': '1991',
#   'unstructured': '& ( 1991). Palaeoenvironmental context for the late Neogene of the Turkana Basin. In (Ed.), Koobi Fora research project, Volume 3, Artiodactyls and palaeoenvironments (pp. 321-370). Oxford: Clarendon Press.',
#   'volume-title': 'Koobi Fora research project, Volume 3, Artiodactyls and palaeoenvironments'},
#  {'key': 'BIB19',
#   'author': 'Frostick',
#   'first-page': '89',
#   'year': '1994',
#   'unstructured': '& ( 1994). Fluvial sediment transport and deposition. In (Ed.), Sediment transport and depositional processes (pp. 89-155). Oxford: Blackwell Scientific Publications.',
#   'volume-title': 'Sediment transport and depositional processes'},
#  {'key': 'BIB20',
#   'author': 'Harris',
#   'year': '1991',
#   'unstructured': 'Ed., ( 1991). Koobi Fora research project, Volume 3, Artiodactyls and Palaeoenvironments. Oxford: Clarendon Press.',
#   'volume-title': 'Koobi Fora research project, Volume 3, Artiodactyls and Palaeoenvironments'},
#  {'key': 'BIB21',
#   'author': 'Harris',
#   'volume': '399',
#   'first-page': '1',
#   'year': '1988',
#   'journal-title': 'Contributions in Science'},
#  {'key': 'BIB22',
#   'author': 'Howell',
#   'volume': '16',
#   'first-page': '665',
#   'year': '1987',
#   'journal-title': 'Journal of Human Evolution',
#   'DOI': '10.1016/0047-2484(87)90019-4',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB23',
#   'author': 'Isaac',
#   'first-page': '131',
#   'year': '1981',
#   'unstructured': '( 1981). Stone Age visiting cards: Approaches to the study of early land-use patterns. In & (Eds.), Pattern of the past (pp. 131-155). Cambridge: Cambridge University Press.',
#   'volume-title': 'Pattern of the past'},
#  {'key': 'BIB24',
#   'author': 'Isaac',
#   'year': '1997',
#   'unstructured': 'Ed., ( 1997). Koobi Fora research project, Volume 5, The archaeology. Oxford: Clarendon Press.',
#   'volume-title': 'Koobi Fora research project, Volume 5, The archaeology'},
#  {'key': 'BIB25',
#   'author': 'Kaufulu',
#   'first-page': '238',
#   'year': '1997',
#   'unstructured': '( 1997). The implications of sedimentology. In (Ed.), Koobi Fora research project, Volume 5, The archaeology (pp. 238-244). Oxford: Clarendon Press.',
#   'volume-title': 'Koobi Fora research project, Volume 5, The archaeology'},
#  {'key': 'BIB26',
#   'author': 'Kroll',
#   'first-page': '459',
#   'year': '1997',
#   'unstructured': '( 1997). Lithic and faunal distributions at eight archaeological excavations. In (Ed.), Koobi Fora research project, Volume 5, The archaeology (pp. 459-525). Oxford: Clarendon Press.',
#   'volume-title': 'Koobi Fora research project, Volume 5, The archaeology'},
#  {'key': 'BIB27',
#   'author': 'Leakey',
#   'year': '1978',
#   'unstructured': '& Eds., ( 1978). Koobi Fora Research Project, Volume 3, The fossil hominids and an introduction to their context. Oxford: Clarendon Press.',
#   'volume-title': 'Koobi Fora Research Project, Volume 3, The fossil hominids and an introduction to their context'},
#  {'key': 'BIB28',
#   'author': 'Loughran',
#   'first-page': '87',
#   'year': '1988',
#   'unstructured': '& ( 1988). Determination of erosion and accretion rates using Caesium-137. In (Ed.), Fluvial geomorphology in Australia (pp. 87-103). Sydney: Academic Press.',
#   'volume-title': 'Fluvial geomorphology in Australia'},
#  {'key': 'BIB29',
#   'author': 'McDougall',
#   'volume': '96',
#   'first-page': '169',
#   'year': '1985',
#   'journal-title': 'Bulletin of the Geological Society of America',
#   'DOI': '10.1130/0016-7606(1985)96<159:KAADOT>2.0.CO;2',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB30',
#   'author': 'McDougall',
#   'volume': '318',
#   'first-page': '175',
#   'year': '1985',
#   'journal-title': 'Nature',
#   'DOI': '10.1038/318175a0',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB31',
#   'author': 'McDougall',
#   'year': '1999',
#   'unstructured': '& ( 1999). Geochronology and thermochronology by the 40Ar/39Ar method ( 2nd edition). New York: Oxford University Press.',
#   'volume-title': 'Geochronology and thermochronology by the 40Ar/39Ar method'},
#  {'key': 'BIB32',
#   'author': 'Potts',
#   'volume': '12',
#   'first-page': '25',
#   'year': '1986',
#   'journal-title': 'Paleobiology',
#   'DOI': '10.1017/S0094837300002955',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB33',
#   'author': 'Potts',
#   'volume': '37',
#   'first-page': '747',
#   'year': '1999',
#   'journal-title': 'Journal of Human Evolution',
#   'DOI': '10.1006/jhev.1999.0344',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB34',
#   'author': 'Reed',
#   'volume': '32',
#   'first-page': '289',
#   'year': '1997',
#   'journal-title': 'Journal of Human Evolution',
#   'DOI': '10.1006/jhev.1996.0106',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB35',
#   'author': 'Rightmire',
#   'first-page': '483',
#   'year': '1995',
#   'unstructured': '( 1995). Diversity within the Genus Homo. In & (Eds.), Paleoclimate and evolution, with emphasis on human origins (pp. 483-492). New Haven, CT: Yale University Press.',
#   'volume-title': 'Paleoclimate and evolution, with emphasis on human origins'},
#  {'key': 'BIB36',
#   'author': 'Rogers',
#   'volume': '27',
#   'first-page': '139',
#   'year': '1994',
#   'journal-title': 'Journal of Human Evolution',
#   'DOI': '10.1006/jhev.1994.1039',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB37',
#   'author': 'Schiffer',
#   'year': '1976',
#   'unstructured': '( 1976). Behavioral archeology. New York: Academic Press.',
#   'volume-title': 'Behavioral archeology'},
#  {'key': 'BIB38',
#   'author': 'Schiffer',
#   'volume': '48',
#   'first-page': '675',
#   'year': '1983',
#   'journal-title': 'American Antiquity',
#   'DOI': '10.2307/279771',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB39',
#   'author': 'Sept',
#   'volume': '27',
#   'first-page': '295',
#   'year': '1994',
#   'journal-title': 'Journal of Human Evolution',
#   'DOI': '10.1006/jhev.1994.1047',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB40',
#   'author': 'Sikes',
#   'volume': '27',
#   'first-page': '25',
#   'year': '1994',
#   'journal-title': 'Journal of Human Evolution',
#   'DOI': '10.1006/jhev.1994.1034',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB41',
#   'author': 'Spencer',
#   'volume': '32',
#   'first-page': '201',
#   'year': '1997',
#   'journal-title': 'Journal of Human Evolution',
#   'DOI': '10.1006/jhev.1996.0102',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB42',
#   'author': 'Stern',
#   'year': '1991',
#   'unstructured': '( 1991). The scatters-between-the-patches: A study of early hominin land-use patterns in the Turkana Basin, Kenya. Unpublished doctoral dissertation, Harvard University, Cambridge, MA.'},
#  {'key': 'BIB43',
#   'author': 'Stern',
#   'year': '1993a',
#   'unstructured': '( 1993a). Geological and archaeological fieldwork at the ?blue? tuff locality, Okote Member of the Koobi Fora Formation, east of Lake Turkana, June-July, 1993. Unpublished report to the National Museums of Kenya, Nairobi.'},
#  {'key': 'BIB44',
#   'author': 'Stern',
#   'volume': '34',
#   'first-page': '201',
#   'year': '1993b',
#   'journal-title': 'Current Anthropology',
#   'DOI': '10.1086/204164',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB45',
#   'author': 'Stern',
#   'year': '1994a',
#   'unstructured': '( 1994a). Geological and archaeological fieldwork at the ?blue? tuff locality, Okote Member of the Koobi Fora Formation, east of Lake Turkana, June-July, 1994. Unpublished report to the National Museums of Kenya, Nairobi.'},
#  {'key': 'BIB46',
#   'author': 'Stern',
#   'volume': '27',
#   'first-page': '89',
#   'year': '1994b',
#   'journal-title': 'Journal of Human Evolution',
#   'DOI': '10.1006/jhev.1994.1037',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB47',
#   'author': 'Stringer',
#   'volume': '69',
#   'first-page': '131',
#   'year': '1984',
#   'journal-title': 'Courier Forschungsinstitut Senckenberg'},
#  {'key': 'BIB48',
#   'author': 'Tattersal',
#   'year': '1995',
#   'unstructured': '( 1995). The fossil trail. New York: Oxford University Press.',
#   'volume-title': 'The fossil trail'},
#  {'key': 'BIB49',
#   'author': 'Walker',
#   'first-page': '411',
#   'year': '1993',
#   'unstructured': '( 1993). Perspectives on the Nariokotome discovery. In & (Eds.), The Nariokotome Homo erectus skeleton (pp. 411-430). Cambridge, MA: Harvard University Press.',
#   'volume-title': 'The Nariokotome Homo erectus skeleton',
#   'DOI': '10.1007/978-3-662-10382-1_17',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB50',
#   'author': 'Walker',
#   'year': '1993',
#   'unstructured': '& Eds., ( 1993). The Nariokotome Homo erectus skeleton. Cambridge, MA: Harvard University Press.',
#   'volume-title': 'The Nariokotome Homo erectus skeleton',
#   'DOI': '10.1007/978-3-662-10382-1',
#   'doi-asserted-by': 'crossref'},
#  {'key': 'BIB51',
#   'author': 'Wesselman',
#   'first-page': '356',
#   'year': '1995',
#   'unstructured': '( 1995). Of mice and almost-men: Regional paleoecology and human evolution in the Turkana Basin. In & (Eds.), Paleoclimate and evolution, with emphasis on human origins (pp. 356-368). New Haven, CT: Yale University Press.',
#   'volume-title': 'Paleoclimate and evolution, with emphasis on human origins'},
#  {'key': 'BIB52',
#   'author': 'Wood',
#   'year': '1992',
#   'unstructured': '( 1992). Koobi Fora research project, Volume 4, Hominid cranial remains.Oxford: Clarendon Press.',
#   'volume-title': 'Koobi Fora research project, Volume 4, Hominid cranial remains'}]

# %%
df_kenya.columns
# Out:
# Index(['DOI', 'ISBN', 'ISSN', 'URL', 'abstract', 'alternative-id', 'assertion',
#        'author', 'container-title', 'content-domain', 'created', 'deposited',
#        'editor', 'indexed', 'is-referenced-by-count', 'isbn-type', 'issn-type',
#        'issue', 'issued', 'journal-issue', 'language', 'license', 'link',
#        'member', 'original-title', 'page', 'prefix', 'published-online',
#        'published-print', 'publisher', 'publisher-location', 'reference-count',
#        'references-count', 'score', 'short-container-title', 'source',
#        'subtitle', 'title', 'type', 'update-policy', 'volume'],
#       dtype='object')

# %%
df_kenya['issued']
# Out:
# 0             {'date-parts': [[2014]]}
# 1      {'date-parts': [[2018, 2, 28]]}
# 2             {'date-parts': [[1999]]}
# 3     {'date-parts': [[1972, 12, 31]]}
# 4      {'date-parts': [[1987, 12, 1]]}
# 5       {'date-parts': [[1992, 1, 1]]}
# 6       {'date-parts': [[1989, 5, 2]]}
# 7       {'date-parts': [[2019, 2, 1]]}
# 8             {'date-parts': [[None]]}
# 9             {'date-parts': [[None]]}
# 10    {'date-parts': [[1995, 12, 14]]}
# 11      {'date-parts': [[2019, 3, 1]]}
# 12     {'date-parts': [[1988, 12, 7]]}
# 13            {'date-parts': [[None]]}
# 14            {'date-parts': [[2019]]}
# 15     {'date-parts': [[2007, 9, 19]]}
# 16     {'date-parts': [[2014, 3, 14]]}
# 17     {'date-parts': [[2014, 3, 14]]}
# 18     {'date-parts': [[2014, 3, 14]]}
# 19     {'date-parts': [[2014, 3, 14]]}
# Name: issued, dtype: object

# %% [markdown]
# #

# %%
import numpy as np
import matplotlib as plt

# %%
publishers = np.array([k['publisher'] for k in items])

# %%
unique_elements, counts_elements = np.unique(publishers, return_counts=True)
publish = pd.DataFrame({'publisher': unique_elements, 'count': counts_elements})

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(30,10)) 
plt.bar(publish['publisher'], publish['count'])
plt.xticks(publish['publisher'], rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x111855c88>,
#   <matplotlib.axis.XTick at 0x111855588>,
#   <matplotlib.axis.XTick at 0x1118553c8>,
#   <matplotlib.axis.XTick at 0x11201ecc0>,
#   <matplotlib.axis.XTick at 0x11200a128>,
#   <matplotlib.axis.XTick at 0x11200a6a0>,
#   <matplotlib.axis.XTick at 0x11200a940>,
#   <matplotlib.axis.XTick at 0x112012160>,
#   <matplotlib.axis.XTick at 0x112012630>,
#   <matplotlib.axis.XTick at 0x112012b38>,
#   <matplotlib.axis.XTick at 0x11201a0f0>,
#   <matplotlib.axis.XTick at 0x112012940>,
#   <matplotlib.axis.XTick at 0x11200a4e0>,
#   <matplotlib.axis.XTick at 0x11201a518>,
#   <matplotlib.axis.XTick at 0x11201aa20>,
#   <matplotlib.axis.XTick at 0x11201af28>,
#   <matplotlib.axis.XTick at 0x112035470>,
#   <matplotlib.axis.XTick at 0x112035978>,
#   <matplotlib.axis.XTick at 0x112035e80>,
#   <matplotlib.axis.XTick at 0x11202b3c8>,
#   <matplotlib.axis.XTick at 0x1120357f0>,
#   <matplotlib.axis.XTick at 0x11201a978>,
#   <matplotlib.axis.XTick at 0x11202b780>,
#   <matplotlib.axis.XTick at 0x11202bc88>,
#   <matplotlib.axis.XTick at 0x1120341d0>,
#   <matplotlib.axis.XTick at 0x1120346d8>,
#   <matplotlib.axis.XTick at 0x112034be0>,
#   <matplotlib.axis.XTick at 0x112054160>,
#   <matplotlib.axis.XTick at 0x112054630>,
#   <matplotlib.axis.XTick at 0x112034f60>,
#   <matplotlib.axis.XTick at 0x112034128>,
#   <matplotlib.axis.XTick at 0x11201a898>,
#   <matplotlib.axis.XTick at 0x112054a20>,
#   <matplotlib.axis.XTick at 0x112040278>,
#   <matplotlib.axis.XTick at 0x112040780>,
#   <matplotlib.axis.XTick at 0x112040c88>,
#   <matplotlib.axis.XTick at 0x11204f1d0>,
#   <matplotlib.axis.XTick at 0x11204f6d8>,
#   <matplotlib.axis.XTick at 0x11204fbe0>,
#   <matplotlib.axis.XTick at 0x112040828>,
#   <matplotlib.axis.XTick at 0x112034550>,
#   <matplotlib.axis.XTick at 0x11204f048>,
#   <matplotlib.axis.XTick at 0x112053470>,
#   <matplotlib.axis.XTick at 0x112053978>,
#   <matplotlib.axis.XTick at 0x112053e80>,
#   <matplotlib.axis.XTick at 0x11205d3c8>,
#   <matplotlib.axis.XTick at 0x11205d8d0>,
#   <matplotlib.axis.XTick at 0x11205ddd8>,
#   <matplotlib.axis.XTick at 0x11205d470>,
#   <matplotlib.axis.XTick at 0x112053940>,
#   <matplotlib.axis.XTick at 0x112012710>,
#   <matplotlib.axis.XTick at 0x1120716d8>,
#   <matplotlib.axis.XTick at 0x112071be0>,
#   <matplotlib.axis.XTick at 0x112077160>,
#   <matplotlib.axis.XTick at 0x112077630>,
#   <matplotlib.axis.XTick at 0x112077b38>,
#   <matplotlib.axis.XTick at 0x11207b0f0>,
#   <matplotlib.axis.XTick at 0x1120776d8>,
#   <matplotlib.axis.XTick at 0x1120719e8>,
#   <matplotlib.axis.XTick at 0x11207b470>,
#   <matplotlib.axis.XTick at 0x11207ba20>,
#   <matplotlib.axis.XTick at 0x11207bf28>,
#   <matplotlib.axis.XTick at 0x1120a8470>,
#   <matplotlib.axis.XTick at 0x1120a8978>,
#   <matplotlib.axis.XTick at 0x1120a8e80>,
#   <matplotlib.axis.XTick at 0x1120863c8>,
#   <matplotlib.axis.XTick at 0x1120868d0>,
#   <matplotlib.axis.XTick at 0x1120a8518>,
#   <matplotlib.axis.XTick at 0x112053550>,
#   <matplotlib.axis.XTick at 0x112086c18>,
#   <matplotlib.axis.XTick at 0x11208e198>,
#   <matplotlib.axis.XTick at 0x11208e668>,
#   <matplotlib.axis.XTick at 0x11208eb70>,
#   <matplotlib.axis.XTick at 0x112093128>,
#   <matplotlib.axis.XTick at 0x1120935c0>,
#   <matplotlib.axis.XTick at 0x112093ac8>,
#   <matplotlib.axis.XTick at 0x11208ee80>,
#   <matplotlib.axis.XTick at 0x11207b5c0>,
#   <matplotlib.axis.XTick at 0x1120936a0>,
#   <matplotlib.axis.XTick at 0x1120a0358>,
#   <matplotlib.axis.XTick at 0x1120a0860>,
#   <matplotlib.axis.XTick at 0x1120a0d68>,
#   <matplotlib.axis.XTick at 0x1120b02b0>,
#   <matplotlib.axis.XTick at 0x1120b07b8>,
#   <matplotlib.axis.XTick at 0x1120b0cc0>,
#   <matplotlib.axis.XTick at 0x1120b0898>,
#   <matplotlib.axis.XTick at 0x1120a0be0>,
#   <matplotlib.axis.XTick at 0x112053dd8>,
#   <matplotlib.axis.XTick at 0x1120b45f8>,
#   <matplotlib.axis.XTick at 0x1120b4cf8>,
#   <matplotlib.axis.XTick at 0x1120be0f0>,
#   <matplotlib.axis.XTick at 0x1120be588>,
#   <matplotlib.axis.XTick at 0x1120bea90>,
#   <matplotlib.axis.XTick at 0x1120bee80>,
#   <matplotlib.axis.XTick at 0x1120ee4e0>,
#   <matplotlib.axis.XTick at 0x1120be390>,
#   <matplotlib.axis.XTick at 0x112071c88>,
#   <matplotlib.axis.XTick at 0x1120ee828>,
#   <matplotlib.axis.XTick at 0x1120eed30>,
#   <matplotlib.axis.XTick at 0x1120c3278>,
#   <matplotlib.axis.XTick at 0x1120c3780>,
#   <matplotlib.axis.XTick at 0x1120c3c88>,
#   <matplotlib.axis.XTick at 0x1120d01d0>,
#   <matplotlib.axis.XTick at 0x1120d06d8>,
#   <matplotlib.axis.XTick at 0x1120c3d30>,
#   <matplotlib.axis.XTick at 0x1120ee0b8>,
#   <matplotlib.axis.XTick at 0x1120d06a0>,
#   <matplotlib.axis.XTick at 0x1120d0f28>,
#   <matplotlib.axis.XTick at 0x1120d1748>,
#   <matplotlib.axis.XTick at 0x1120d1c50>,
#   <matplotlib.axis.XTick at 0x1120d1208>,
#   <matplotlib.axis.XTick at 0x1120e23c8>,
#   <matplotlib.axis.XTick at 0x1120e28d0>,
#   <matplotlib.axis.XTick at 0x1120e2dd8>,
#   <matplotlib.axis.XTick at 0x1120d11d0>,
#   <matplotlib.axis.XTick at 0x1120d0278>,
#   <matplotlib.axis.XTick at 0x1120ed240>,
#   <matplotlib.axis.XTick at 0x1120ed748>,
#   <matplotlib.axis.XTick at 0x1120edc50>,
#   <matplotlib.axis.XTick at 0x1120fa198>,
#   <matplotlib.axis.XTick at 0x1120fa6a0>,
#   <matplotlib.axis.XTick at 0x1120faba8>,
#   <matplotlib.axis.XTick at 0x111801160>,
#   <matplotlib.axis.XTick at 0x1120fa240>,
#   <matplotlib.axis.XTick at 0x1120ed0b8>,
#   <matplotlib.axis.XTick at 0x111801438>,
#   <matplotlib.axis.XTick at 0x111801940>,
#   <matplotlib.axis.XTick at 0x111801e48>,
#   <matplotlib.axis.XTick at 0x111809390>,
#   <matplotlib.axis.XTick at 0x111809898>,
#   <matplotlib.axis.XTick at 0x111809da0>,
#   <matplotlib.axis.XTick at 0x1118112e8>,
#   <matplotlib.axis.XTick at 0x111809e80>,
#   <matplotlib.axis.XTick at 0x1118014e0>,
#   <matplotlib.axis.XTick at 0x111811780>,
#   <matplotlib.axis.XTick at 0x111811b38>,
#   <matplotlib.axis.XTick at 0x1118190f0>,
#   <matplotlib.axis.XTick at 0x111819588>,
#   <matplotlib.axis.XTick at 0x111819a90>,
#   <matplotlib.axis.XTick at 0x111819e80>,
#   <matplotlib.axis.XTick at 0x1118224e0>,
#   <matplotlib.axis.XTick at 0x111819630>,
#   <matplotlib.axis.XTick at 0x111801e10>,
#   <matplotlib.axis.XTick at 0x1120e2d30>,
#   <matplotlib.axis.XTick at 0x11207b400>,
#   <matplotlib.axis.XTick at 0x111822438>,
#   <matplotlib.axis.XTick at 0x111822cf8>,
#   <matplotlib.axis.XTick at 0x11182a518>,
#   <matplotlib.axis.XTick at 0x11182aa20>,
#   <matplotlib.axis.XTick at 0x11182af28>,
#   <matplotlib.axis.XTick at 0x111832470>,
#   <matplotlib.axis.XTick at 0x11182a978>,
#   <matplotlib.axis.XTick at 0x112093f28>,
#   <matplotlib.axis.XTick at 0x1118322e8>,
#   <matplotlib.axis.XTick at 0x111832cc0>,
#   <matplotlib.axis.XTick at 0x11183b208>,
#   <matplotlib.axis.XTick at 0x11183b710>,
#   <matplotlib.axis.XTick at 0x11183bc18>,
#   <matplotlib.axis.XTick at 0x110fb3198>,
#   <matplotlib.axis.XTick at 0x110fb3668>,
#   <matplotlib.axis.XTick at 0x11183b518>,
#   <matplotlib.axis.XTick at 0x111832898>,
#   <matplotlib.axis.XTick at 0x110fb3908>,
#   <matplotlib.axis.XTick at 0x110fb3f28>,
#   <matplotlib.axis.XTick at 0x110fbb470>,
#   <matplotlib.axis.XTick at 0x110fbb978>,
#   <matplotlib.axis.XTick at 0x110fbbe80>,
#   <matplotlib.axis.XTick at 0x110fc23c8>,
#   <matplotlib.axis.XTick at 0x110fc28d0>,
#   <matplotlib.axis.XTick at 0x110fc2dd8>,
#   <matplotlib.axis.XTick at 0x110fbbdd8>,
#   <matplotlib.axis.XTick at 0x110fb3d30>,
#   <matplotlib.axis.XTick at 0x110fc92b0>,
#   <matplotlib.axis.XTick at 0x110fc97b8>,
#   <matplotlib.axis.XTick at 0x110fc9cc0>,
#   <matplotlib.axis.XTick at 0x110fd3208>,
#   <matplotlib.axis.XTick at 0x110fd3710>,
#   <matplotlib.axis.XTick at 0x110fd3c18>,
#   <matplotlib.axis.XTick at 0x110fdb198>,
#   <matplotlib.axis.XTick at 0x110fd3518>,
#   <matplotlib.axis.XTick at 0x110fc9278>,
#   <matplotlib.axis.XTick at 0x110fdb4a8>,
#   <matplotlib.axis.XTick at 0x110fdb9b0>,
#   <matplotlib.axis.XTick at 0x110fdbeb8>,
#   <matplotlib.axis.XTick at 0x110fe4400>,
#   <matplotlib.axis.XTick at 0x110fe4908>,
#   <matplotlib.axis.XTick at 0x110fe4e10>,
#   <matplotlib.axis.XTick at 0x110fec358>,
#   <matplotlib.axis.XTick at 0x110fe4ef0>,
#   <matplotlib.axis.XTick at 0x110fdb828>,
#   <matplotlib.axis.XTick at 0x110fec400>,
#   <matplotlib.axis.XTick at 0x110fecba8>,
#   <matplotlib.axis.XTick at 0x111ac6160>,
#   <matplotlib.axis.XTick at 0x111ac65f8>,
#   <matplotlib.axis.XTick at 0x111ac6b00>,
#   <matplotlib.axis.XTick at 0x111acd0b8>,
#   <matplotlib.axis.XTick at 0x111acd550>,
#   <matplotlib.axis.XTick at 0x111ac66a0>,
#   <matplotlib.axis.XTick at 0x110fecb70>,
#   <matplotlib.axis.XTick at 0x111acd710>,
#   <matplotlib.axis.XTick at 0x111acde80>,
#   <matplotlib.axis.XTick at 0x111ad63c8>,
#   <matplotlib.axis.XTick at 0x111ad68d0>,
#   <matplotlib.axis.XTick at 0x111ad6dd8>,
#   <matplotlib.axis.XTick at 0x111ade320>,
#   <matplotlib.axis.XTick at 0x111ade828>,
#   <matplotlib.axis.XTick at 0x111aded30>,
#   <matplotlib.axis.XTick at 0x111ad6320>,
#   <matplotlib.axis.XTick at 0x111adecf8>,
#   <matplotlib.axis.XTick at 0x111ae5128>,
#   <matplotlib.axis.XTick at 0x111ae55c0>,
#   <matplotlib.axis.XTick at 0x111ae5ac8>,
#   <matplotlib.axis.XTick at 0x111ae5cf8>,
#   <matplotlib.axis.XTick at 0x111aef518>,
#   <matplotlib.axis.XTick at 0x111aefa20>,
#   <matplotlib.axis.XTick at 0x111aeff28>,
#   <matplotlib.axis.XTick at 0x111aefe80>,
#   <matplotlib.axis.XTick at 0x111ae56a0>,
#   <matplotlib.axis.XTick at 0x111af7320>,
#   <matplotlib.axis.XTick at 0x111af77b8>],
#  <a list of 220 Text xticklabel objects>)

# %%
more_than_10 = publish[publish['count'] >= 10]
plt.figure(figsize=(30,10)) 
plt.bar(more_than_10['publisher'], more_than_10['count'])
plt.xticks(more_than_10['publisher'], rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x1183f9f98>,
#   <matplotlib.axis.XTick at 0x1183cb588>,
#   <matplotlib.axis.XTick at 0x11212a390>,
#   <matplotlib.axis.XTick at 0x118bc6320>,
#   <matplotlib.axis.XTick at 0x118bc67f0>,
#   <matplotlib.axis.XTick at 0x118bc6cf8>,
#   <matplotlib.axis.XTick at 0x118bce240>,
#   <matplotlib.axis.XTick at 0x118bce748>,
#   <matplotlib.axis.XTick at 0x118bcec50>,
#   <matplotlib.axis.XTick at 0x118bd4198>,
#   <matplotlib.axis.XTick at 0x118bd46a0>,
#   <matplotlib.axis.XTick at 0x118bd4ba8>,
#   <matplotlib.axis.XTick at 0x118bd4c88>,
#   <matplotlib.axis.XTick at 0x118bce7f0>,
#   <matplotlib.axis.XTick at 0x118bce198>,
#   <matplotlib.axis.XTick at 0x118bda588>,
#   <matplotlib.axis.XTick at 0x118bdaa90>,
#   <matplotlib.axis.XTick at 0x118bdae80>,
#   <matplotlib.axis.XTick at 0x118be14e0>,
#   <matplotlib.axis.XTick at 0x118be19e8>,
#   <matplotlib.axis.XTick at 0x118be1ef0>,
#   <matplotlib.axis.XTick at 0x118be17f0>,
#   <matplotlib.axis.XTick at 0x118bda9e8>,
#   <matplotlib.axis.XTick at 0x118bce550>,
#   <matplotlib.axis.XTick at 0x118beb860>,
#   <matplotlib.axis.XTick at 0x118bebd68>,
#   <matplotlib.axis.XTick at 0x118bf12b0>,
#   <matplotlib.axis.XTick at 0x118bf17b8>,
#   <matplotlib.axis.XTick at 0x118bf1cc0>,
#   <matplotlib.axis.XTick at 0x118bf9208>,
#   <matplotlib.axis.XTick at 0x118bf9710>,
#   <matplotlib.axis.XTick at 0x118bf1390>,
#   <matplotlib.axis.XTick at 0x118bda898>],
#  <a list of 33 Text xticklabel objects>)

# %%
#Count types
types = np.array([k['type'] for k in items])
unique_elements_type, counts_elements_type = np.unique(types, return_counts=True)
type_df = pd.DataFrame({'type': unique_elements_type, 'count': counts_elements_type})
type_df
# Out:
#                    type  count
# 0                  book      7
# 1          book-chapter    226
# 2             component     15
# 3               dataset     58
# 4          dissertation      3
# 5       journal-article   1608
# 6             monograph      2
# 7                 other     19
# 8   proceedings-article     48
# 9        reference-book      1
# 10      reference-entry      9
# 11               report      4

# %%
plt.figure(figsize=(30,10)) 
plt.bar(type_df['type'], type_df['count'])
plt.xticks(type_df['type'], rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x118b90048>,
#   <matplotlib.axis.XTick at 0x118c54940>,
#   <matplotlib.axis.XTick at 0x118c546a0>,
#   <matplotlib.axis.XTick at 0x119285ba8>,
#   <matplotlib.axis.XTick at 0x11928d128>,
#   <matplotlib.axis.XTick at 0x11928d588>,
#   <matplotlib.axis.XTick at 0x11928da90>,
#   <matplotlib.axis.XTick at 0x11928de80>,
#   <matplotlib.axis.XTick at 0x1192964e0>,
#   <matplotlib.axis.XTick at 0x1192969e8>,
#   <matplotlib.axis.XTick at 0x119296ef0>,
#   <matplotlib.axis.XTick at 0x11929d438>],
#  <a list of 12 Text xticklabel objects>)

# %%
kenya_progress = cr.works(query = "kenya", cursor = "*", limit = 500, progress_bar = True)

# %%
items[0]['created']['date-parts'][0][0]
# Out:
# 2002

# %%
len(kenya_progress[0]['message']['items'][0]['reference'])
# Out:
# 52

# %%
years = [items[i]['created']['date-parts'][0][0] for i in range(len(items))]
years
# Out:
# [2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2013,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2013,
#  2002,
#  2013,
#  2002,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2002,
#  2002,
#  2003,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2003,
#  2002,
#  2013,
#  2013,
#  2002,
#  2002,
#  2013,
#  2013,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2003,
#  2013,
#  2013,
#  2013,
#  2003,
#  2003,
#  2003,
#  2013,
#  2013,
#  2003,
#  2013,
#  2013,
#  2003,
#  2003,
#  2002,
#  2003,
#  2003,
#  2003,
#  2003,
#  2003,
#  2003,
#  2003,
#  2013,
#  2013,
#  2003,
#  2003,
#  2003,
#  2003,
#  2002,
#  2003,
#  2013,
#  2003,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2002,
#  2013,
#  2002,
#  2002,
#  2003,
#  2013,
#  2002,
#  2002,
#  2002,
#  2013,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2013,
#  2002,
#  2013,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2002,
#  2002,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2003,
#  2003,
#  2003,
#  2003,
#  2003,
#  2003,
#  2003,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2003,
#  2003,
#  2003,
#  2003,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2002,
#  2002,
#  2002,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2002,
#  2002,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2003,
#  2013,
#  2013,
#  2013,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2003,
#  2003,
#  2013,
#  2013,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2002,
#  2003,
#  2013,
#  2013,
#  2013,
#  2013,
#  2003,
#  2003,
#  2013,
#  2013,
#  2003,
#  2003,
#  2013,
#  2013,
#  2013,
#  2013,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2003,
#  2003,
#  2002,
#  2002,
#  2002,
#  2002,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2007,
#  2007,
#  2007,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2007,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2007,
#  2013,
#  2013,
#  2007,
#  2013,
#  2007,
#  2013,
#  2002,
#  2013,
#  2007,
#  2007,
#  2013,
#  2013,
#  2007,
#  2013,
#  2013,
#  2007,
#  2003,
#  2007,
#  2013,
#  2007,
#  2013,
#  2013,
#  2013,
#  2007,
#  2007,
#  2013,
#  2002,
#  2013,
#  2013,
#  2007,
#  2007,
#  2007,
#  2013,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2013,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2007,
#  2013,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2013,
#  2013,
#  2013,
#  2013,
#  2007,
#  2007,
#  2007,
#  2007,
#  2007,
#  2003,
#  2013,
#  2013,
#  2007,
#  2013,
#  2013,
#  2013,
#  2013,
#  2007,
#  2013,
#  2007,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2013,
#  2007,
#  2013,
#  2013,
#  2013,
#  ...]

# %%
#author stuff
#year/time stuff 
    #by year, look at 'created' column of first query search which year columns to look at specifically
from collections import Counter

# %%
d = dict(Counter(years))
plt.plot(list(d.keys()),list(d.values()))

# %%
kenya_progress[0]['message']['items'][0]
# Out:
# {'indexed': {'date-parts': [[2019, 2, 12]],
#   'date-time': '2019-02-12T21:03:20Z',
#   'timestamp': 1550005400188},
#  'reference-count': 52,
#  'publisher': 'Wiley',
#  'issue': '4',
#  'license': [{'URL': 'http://doi.wiley.com/10.1002/tdm_license_1.1',
#    'start': {'date-parts': [[2015, 9, 1]],
#     'date-time': '2015-09-01T00:00:00Z',
#     'timestamp': 1441065600000},
#    'delay-in-days': 4922,
#    'content-version': 'tdm'}],
#  'content-domain': {'domain': [], 'crossmark-restriction': False},
#  'short-container-title': ['Geoarchaeology'],
#  'published-print': {'date-parts': [[2002, 4]]},
#  'DOI': '10.1002/gea.10018',
#  'type': 'journal-article',
#  'created': {'date-parts': [[2002, 8, 25]],
#   'date-time': '2002-08-25T23:12:15Z',
#   'timestamp': 1030317135000},
#  'page': '349-392',
#  'source': 'Crossref',
#  'is-referenced-by-count': 7,
#  'title': ['FxJj43: A window into a 1.5-million-year-old palaeolandscape in the Okote Member of the Koobi Fora Formation, northern Kenya'],
#  'prefix': '10.1002',
#  'volume': '17',
#  'author': [{'given': 'Nicola',
#    'family': 'Stern',
#    'sequence': 'first',
#    'affiliation': []},
#   {'given': 'Nicholas',
#    'family': 'Porch',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Ian',
#    'family': 'McDougall',
#    'sequence': 'additional',
#    'affiliation': []}],
#  'member': '311',
#  'published-online': {'date-parts': [[2002, 3, 11]]},
#  'reference': [{'key': 'BIB1',
#    'author': 'Andrews',
#    'volume': '69',
#    'first-page': '167',
#    'year': '1984',
#    'journal-title': 'Courier Forschungsinstitut Senckenberg'},
#   {'key': 'BIB2',
#    'author': 'Behrensmeyer',
#    'volume': '2',
#    'first-page': '150',
#    'year': '1978',
#    'journal-title': 'Paleobiology',
#    'DOI': '10.1017/S0094837300005820',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB3',
#    'author': 'Binford',
#    'volume': '37',
#    'first-page': '195',
#    'year': '1981',
#    'journal-title': 'Journal of Anthropological Research',
#    'DOI': '10.1086/jar.37.3.3629723',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB4',
#    'author': 'Blumenschine',
#    'volume': '21',
#    'first-page': '451',
#    'year': '1991',
#    'journal-title': 'Journal of Human Evolution',
#    'DOI': '10.1016/0047-2484(91)90095-D',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB5',
#    'author': 'Bonnefille',
#    'first-page': '299',
#    'year': '1995',
#    'unstructured': '( 1995). A reassessment of the Plio-Pleistocene pollen record of East Africa. In & (Eds.), Paleoclimate and evolution, with emphasis on human origins (pp. 299-310). New Haven, CT: Yale University Press.',
#    'volume-title': 'Paleoclimate and evolution, with emphasis on human origins'},
#   {'key': 'BIB6',
#    'author': 'Brauer',
#    'volume': '9',
#    'first-page': '352',
#    'year': '1990',
#    'journal-title': 'Acta Anthropologica Sinica'},
#   {'key': 'BIB7',
#    'author': 'Brown',
#    'volume': '316',
#    'first-page': '794',
#    'year': '1985',
#    'journal-title': 'Nature',
#    'DOI': '10.1038/316794a0',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB8',
#    'author': 'Brown',
#    'volume': '143',
#    'first-page': '297',
#    'year': '1986',
#    'journal-title': 'Journal of the Geological Society',
#    'DOI': '10.1144/gsjgs.143.2.0297',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB9',
#    'author': 'Brown',
#    'first-page': '325',
#    'year': '1988',
#    'unstructured': '& ( 1988). ?Robust? hominids and Plio-Pleistocene palaeogeography of the Turkana basin, Kenya and Ethiopia. In (Ed.), Evolutionary history of the ?Robust? Australopithecines (pp. 325-341). New York: Aldine de Gruyter.',
#    'volume-title': 'Evolutionary history of the ?Robust? Australopithecines'},
#   {'key': 'BIB10',
#    'author': 'Brown',
#    'first-page': '1',
#    'year': '1991',
#    'unstructured': '& ( 1991). Stratigraphy, depositional environments, and palaeogeography of the Koobi Fora Formation. In (Ed.), Koobi Fora research project, Volume 3, Artiodactyls and palaeoenvironments (pp. 1-30). Oxford: Clarendon Press.',
#    'volume-title': 'Koobi Fora research project, Volume 3, Artiodactyls and palaeoenvironments'},
#   {'key': 'BIB11',
#    'author': 'Bunn',
#    'first-page': '402',
#    'year': '1997',
#    'unstructured': '( 1997). The bone assemblages from the excavated sites. In (Ed.), Koobi Fora research project, Volume 5, The archaeology (pp. 402-444). Oxford: Clarendon Press.',
#    'volume-title': 'Koobi Fora research project, Volume 5, The archaeology'},
#   {'key': 'BIB12',
#    'author': 'Cebula',
#    'volume': '6',
#    'first-page': '139',
#    'year': '1986',
#    'journal-title': 'Terra Cognita Abstracts'},
#   {'key': 'BIB13',
#    'author': 'Cerling',
#    'volume': '97',
#    'first-page': '241',
#    'year': '1992',
#    'journal-title': 'Palaeogeography, Palaeoclimatology, Palaeoecology',
#    'DOI': '10.1016/0031-0182(92)90211-M',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB14',
#    'author': 'Conard',
#    'volume': '35',
#    'first-page': '281',
#    'year': '1994',
#    'journal-title': 'Current Anthropology',
#    'DOI': '10.1086/204273',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB15',
#    'author': 'Coppens',
#    'year': '1976',
#    'unstructured': '& Eds., ( 1976). Earliest man and environments in the Lake Rudolf Basin. Chicago: University of Chicago Press.',
#    'volume-title': 'Earliest man and environments in the Lake Rudolf Basin'},
#   {'key': 'BIB16',
#    'author': 'Feibel',
#    'year': '1988',
#    'unstructured': '( 1988). Palaeoenvironments of the Koobi Fora Formation, Turkana Basin, Northern Kenya. Unpublished doctoral dissertation, University of Utah, Salt Lake City.'},
#   {'key': 'BIB17',
#    'author': 'Feibel',
#    'first-page': '21',
#    'year': '1993',
#    'unstructured': '& ( 1993). Microstratigraphy and paleoenvironments. In & (Eds.), The Nariokotome Homo erectus skeleton (pp. 21-39). Cambridge, MA: Harvard University Press.',
#    'volume-title': 'The Nariokotome Homo erectus skeleton',
#    'DOI': '10.1007/978-3-662-10382-1_3',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB18',
#    'author': 'Feibel',
#    'first-page': '321',
#    'year': '1991',
#    'unstructured': '& ( 1991). Palaeoenvironmental context for the late Neogene of the Turkana Basin. In (Ed.), Koobi Fora research project, Volume 3, Artiodactyls and palaeoenvironments (pp. 321-370). Oxford: Clarendon Press.',
#    'volume-title': 'Koobi Fora research project, Volume 3, Artiodactyls and palaeoenvironments'},
#   {'key': 'BIB19',
#    'author': 'Frostick',
#    'first-page': '89',
#    'year': '1994',
#    'unstructured': '& ( 1994). Fluvial sediment transport and deposition. In (Ed.), Sediment transport and depositional processes (pp. 89-155). Oxford: Blackwell Scientific Publications.',
#    'volume-title': 'Sediment transport and depositional processes'},
#   {'key': 'BIB20',
#    'author': 'Harris',
#    'year': '1991',
#    'unstructured': 'Ed., ( 1991). Koobi Fora research project, Volume 3, Artiodactyls and Palaeoenvironments. Oxford: Clarendon Press.',
#    'volume-title': 'Koobi Fora research project, Volume 3, Artiodactyls and Palaeoenvironments'},
#   {'key': 'BIB21',
#    'author': 'Harris',
#    'volume': '399',
#    'first-page': '1',
#    'year': '1988',
#    'journal-title': 'Contributions in Science'},
#   {'key': 'BIB22',
#    'author': 'Howell',
#    'volume': '16',
#    'first-page': '665',
#    'year': '1987',
#    'journal-title': 'Journal of Human Evolution',
#    'DOI': '10.1016/0047-2484(87)90019-4',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB23',
#    'author': 'Isaac',
#    'first-page': '131',
#    'year': '1981',
#    'unstructured': '( 1981). Stone Age visiting cards: Approaches to the study of early land-use patterns. In & (Eds.), Pattern of the past (pp. 131-155). Cambridge: Cambridge University Press.',
#    'volume-title': 'Pattern of the past'},
#   {'key': 'BIB24',
#    'author': 'Isaac',
#    'year': '1997',
#    'unstructured': 'Ed., ( 1997). Koobi Fora research project, Volume 5, The archaeology. Oxford: Clarendon Press.',
#    'volume-title': 'Koobi Fora research project, Volume 5, The archaeology'},
#   {'key': 'BIB25',
#    'author': 'Kaufulu',
#    'first-page': '238',
#    'year': '1997',
#    'unstructured': '( 1997). The implications of sedimentology. In (Ed.), Koobi Fora research project, Volume 5, The archaeology (pp. 238-244). Oxford: Clarendon Press.',
#    'volume-title': 'Koobi Fora research project, Volume 5, The archaeology'},
#   {'key': 'BIB26',
#    'author': 'Kroll',
#    'first-page': '459',
#    'year': '1997',
#    'unstructured': '( 1997). Lithic and faunal distributions at eight archaeological excavations. In (Ed.), Koobi Fora research project, Volume 5, The archaeology (pp. 459-525). Oxford: Clarendon Press.',
#    'volume-title': 'Koobi Fora research project, Volume 5, The archaeology'},
#   {'key': 'BIB27',
#    'author': 'Leakey',
#    'year': '1978',
#    'unstructured': '& Eds., ( 1978). Koobi Fora Research Project, Volume 3, The fossil hominids and an introduction to their context. Oxford: Clarendon Press.',
#    'volume-title': 'Koobi Fora Research Project, Volume 3, The fossil hominids and an introduction to their context'},
#   {'key': 'BIB28',
#    'author': 'Loughran',
#    'first-page': '87',
#    'year': '1988',
#    'unstructured': '& ( 1988). Determination of erosion and accretion rates using Caesium-137. In (Ed.), Fluvial geomorphology in Australia (pp. 87-103). Sydney: Academic Press.',
#    'volume-title': 'Fluvial geomorphology in Australia'},
#   {'key': 'BIB29',
#    'author': 'McDougall',
#    'volume': '96',
#    'first-page': '169',
#    'year': '1985',
#    'journal-title': 'Bulletin of the Geological Society of America',
#    'DOI': '10.1130/0016-7606(1985)96<159:KAADOT>2.0.CO;2',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB30',
#    'author': 'McDougall',
#    'volume': '318',
#    'first-page': '175',
#    'year': '1985',
#    'journal-title': 'Nature',
#    'DOI': '10.1038/318175a0',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB31',
#    'author': 'McDougall',
#    'year': '1999',
#    'unstructured': '& ( 1999). Geochronology and thermochronology by the 40Ar/39Ar method ( 2nd edition). New York: Oxford University Press.',
#    'volume-title': 'Geochronology and thermochronology by the 40Ar/39Ar method'},
#   {'key': 'BIB32',
#    'author': 'Potts',
#    'volume': '12',
#    'first-page': '25',
#    'year': '1986',
#    'journal-title': 'Paleobiology',
#    'DOI': '10.1017/S0094837300002955',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB33',
#    'author': 'Potts',
#    'volume': '37',
#    'first-page': '747',
#    'year': '1999',
#    'journal-title': 'Journal of Human Evolution',
#    'DOI': '10.1006/jhev.1999.0344',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB34',
#    'author': 'Reed',
#    'volume': '32',
#    'first-page': '289',
#    'year': '1997',
#    'journal-title': 'Journal of Human Evolution',
#    'DOI': '10.1006/jhev.1996.0106',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB35',
#    'author': 'Rightmire',
#    'first-page': '483',
#    'year': '1995',
#    'unstructured': '( 1995). Diversity within the Genus Homo. In & (Eds.), Paleoclimate and evolution, with emphasis on human origins (pp. 483-492). New Haven, CT: Yale University Press.',
#    'volume-title': 'Paleoclimate and evolution, with emphasis on human origins'},
#   {'key': 'BIB36',
#    'author': 'Rogers',
#    'volume': '27',
#    'first-page': '139',
#    'year': '1994',
#    'journal-title': 'Journal of Human Evolution',
#    'DOI': '10.1006/jhev.1994.1039',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB37',
#    'author': 'Schiffer',
#    'year': '1976',
#    'unstructured': '( 1976). Behavioral archeology. New York: Academic Press.',
#    'volume-title': 'Behavioral archeology'},
#   {'key': 'BIB38',
#    'author': 'Schiffer',
#    'volume': '48',
#    'first-page': '675',
#    'year': '1983',
#    'journal-title': 'American Antiquity',
#    'DOI': '10.2307/279771',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB39',
#    'author': 'Sept',
#    'volume': '27',
#    'first-page': '295',
#    'year': '1994',
#    'journal-title': 'Journal of Human Evolution',
#    'DOI': '10.1006/jhev.1994.1047',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB40',
#    'author': 'Sikes',
#    'volume': '27',
#    'first-page': '25',
#    'year': '1994',
#    'journal-title': 'Journal of Human Evolution',
#    'DOI': '10.1006/jhev.1994.1034',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB41',
#    'author': 'Spencer',
#    'volume': '32',
#    'first-page': '201',
#    'year': '1997',
#    'journal-title': 'Journal of Human Evolution',
#    'DOI': '10.1006/jhev.1996.0102',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB42',
#    'author': 'Stern',
#    'year': '1991',
#    'unstructured': '( 1991). The scatters-between-the-patches: A study of early hominin land-use patterns in the Turkana Basin, Kenya. Unpublished doctoral dissertation, Harvard University, Cambridge, MA.'},
#   {'key': 'BIB43',
#    'author': 'Stern',
#    'year': '1993a',
#    'unstructured': '( 1993a). Geological and archaeological fieldwork at the ?blue? tuff locality, Okote Member of the Koobi Fora Formation, east of Lake Turkana, June-July, 1993. Unpublished report to the National Museums of Kenya, Nairobi.'},
#   {'key': 'BIB44',
#    'author': 'Stern',
#    'volume': '34',
#    'first-page': '201',
#    'year': '1993b',
#    'journal-title': 'Current Anthropology',
#    'DOI': '10.1086/204164',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB45',
#    'author': 'Stern',
#    'year': '1994a',
#    'unstructured': '( 1994a). Geological and archaeological fieldwork at the ?blue? tuff locality, Okote Member of the Koobi Fora Formation, east of Lake Turkana, June-July, 1994. Unpublished report to the National Museums of Kenya, Nairobi.'},
#   {'key': 'BIB46',
#    'author': 'Stern',
#    'volume': '27',
#    'first-page': '89',
#    'year': '1994b',
#    'journal-title': 'Journal of Human Evolution',
#    'DOI': '10.1006/jhev.1994.1037',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB47',
#    'author': 'Stringer',
#    'volume': '69',
#    'first-page': '131',
#    'year': '1984',
#    'journal-title': 'Courier Forschungsinstitut Senckenberg'},
#   {'key': 'BIB48',
#    'author': 'Tattersal',
#    'year': '1995',
#    'unstructured': '( 1995). The fossil trail. New York: Oxford University Press.',
#    'volume-title': 'The fossil trail'},
#   {'key': 'BIB49',
#    'author': 'Walker',
#    'first-page': '411',
#    'year': '1993',
#    'unstructured': '( 1993). Perspectives on the Nariokotome discovery. In & (Eds.), The Nariokotome Homo erectus skeleton (pp. 411-430). Cambridge, MA: Harvard University Press.',
#    'volume-title': 'The Nariokotome Homo erectus skeleton',
#    'DOI': '10.1007/978-3-662-10382-1_17',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB50',
#    'author': 'Walker',
#    'year': '1993',
#    'unstructured': '& Eds., ( 1993). The Nariokotome Homo erectus skeleton. Cambridge, MA: Harvard University Press.',
#    'volume-title': 'The Nariokotome Homo erectus skeleton',
#    'DOI': '10.1007/978-3-662-10382-1',
#    'doi-asserted-by': 'crossref'},
#   {'key': 'BIB51',
#    'author': 'Wesselman',
#    'first-page': '356',
#    'year': '1995',
#    'unstructured': '( 1995). Of mice and almost-men: Regional paleoecology and human evolution in the Turkana Basin. In & (Eds.), Paleoclimate and evolution, with emphasis on human origins (pp. 356-368). New Haven, CT: Yale University Press.',
#    'volume-title': 'Paleoclimate and evolution, with emphasis on human origins'},
#   {'key': 'BIB52',
#    'author': 'Wood',
#    'year': '1992',
#    'unstructured': '( 1992). Koobi Fora research project, Volume 4, Hominid cranial remains.Oxford: Clarendon Press.',
#    'volume-title': 'Koobi Fora research project, Volume 4, Hominid cranial remains'}],
#  'container-title': ['Geoarchaeology'],
#  'language': 'en',
#  'link': [{'URL': 'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fgea.10018',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'text-mining'},
#   {'URL': 'https://onlinelibrary.wiley.com/doi/full/10.1002/gea.10018',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'deposited': {'date-parts': [[2018, 8, 2]],
#   'date-time': '2018-08-02T02:03:21Z',
#   'timestamp': 1533175401000},
#  'score': 7.3078027,
#  'issued': {'date-parts': [[2002, 3, 11]]},
#  'references-count': 52,
#  'journal-issue': {'published-print': {'date-parts': [[2002, 4]]},
#   'issue': '4'},
#  'URL': 'http://dx.doi.org/10.1002/gea.10018',
#  'relation': {'cites': []},
#  'ISSN': ['0883-6353', '1520-6548'],
#  'issn-type': [{'value': '0883-6353', 'type': 'print'},
#   {'value': '1520-6548', 'type': 'electronic'}]}

# %%
authors_no_null = df_kenya[~df_kenya["author"].isnull()]
authors_no_null
# Out:
#                                           DOI                            ISBN  \
# 0                     10.17138/tgft(2)100-102                             NaN
# 1                        10.21474/ijar01/6544                             NaN
# 2                     10.5962/bhl.title.87589                             NaN
# 4                10.14217/9781848594371-12-en                             NaN
# 5                10.14217/9781848594920-13-en                             NaN
# 6                   10.1127/phyto/17/1989/287                             NaN
# 7                 10.18697/ajfand.84.blfb1017                             NaN
# 10                  10.1127/phyto/25/1995/467                             NaN
# 11  10.7228/manchester/9781526105813.003.0016  [9781526105813, 9781526135988]
# 12                  10.1127/phyto/16/1988/433                             NaN
# 15                  10.20987/jmrs.08.2012.603                             NaN
#
#                       ISSN                                                URL  \
# 0              [2346-3775]          http://dx.doi.org/10.17138/tgft(2)100-102
# 1              [2320-5407]             http://dx.doi.org/10.21474/ijar01/6544
# 2                      NaN          http://dx.doi.org/10.5962/bhl.title.87589
# 4                      NaN     http://dx.doi.org/10.14217/9781848594371-12-en
# 5                      NaN     http://dx.doi.org/10.14217/9781848594920-13-en
# 6              [0340-269X]        http://dx.doi.org/10.1127/phyto/17/1989/287
# 7              [1684-5374]      http://dx.doi.org/10.18697/ajfand.84.blfb1017
# 10             [0340-269X]        http://dx.doi.org/10.1127/phyto/25/1995/467
# 11                     NaN  http://dx.doi.org/10.7228/manchester/978152610...
# 12             [0340-269X]        http://dx.doi.org/10.1127/phyto/16/1988/433
# 15  [1995-9834, 2412-3781]        http://dx.doi.org/10.20987/jmrs.08.2012.603
#
#                                              abstract alternative-id  \
# 0                                                 NaN       [136/84]
# 1                                                 NaN            NaN
# 2                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7                                                 NaN            NaN
# 10                                                NaN            NaN
# 11  <p>Since the 1998 bombing of the US Embassy in...            NaN
# 12                                                NaN            NaN
# 15                                                NaN            NaN
#
#    assertion                                             author  \
# 0        NaN  [{'given': 'Donald M.G.', 'family': 'Njarui', ...
# 1        NaN  [{'given': 'GladysJerono', 'family': 'Koech', ...
# 2        NaN  [{'given': 'Leon A.', 'family': 'Bennun', 'seq...
# 4        NaN  [{'name': 'Commonwealth Secretariat', 'sequenc...
# 5        NaN  [{'name': 'Commonwealth Secretariat', 'sequenc...
# 6        NaN  [{'given': 'H.', 'family': 'Rehder', 'sequence...
# 7        NaN  [{'given': 'Beverly', 'family': 'Agesa', 'sequ...
# 10       NaN  [{'given': 'Rainer W.', 'family': 'Bussmann', ...
# 11       NaN  [{'given': 'Jeremy', 'family': 'Prestholdt', '...
# 12       NaN  [{'given': 'H.', 'family': 'Rehder', 'sequence...
# 15       NaN  [{'given': 'Joab', 'family': 'Wamari', 'sequen...
#
#                                       container-title  \
# 0         [Tropical Grasslands - Forrajes Tropicales]
# 1        [International Journal of Advanced Research]
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                   [Phytocoenologia]
# 7   [African Journal of Food, Agriculture, Nutriti...
# 10                                  [Phytocoenologia]
# 11               [Non-Western responses to terrorism]
# 12                                  [Phytocoenologia]
# 15      [Journal of Meteorology and Related Sciences]
#
#                                     content-domain  ...   reference-count  \
# 0   {'domain': [], 'crossmark-restriction': False}  ...                 0
# 1   {'domain': [], 'crossmark-restriction': False}  ...                 0
# 2   {'domain': [], 'crossmark-restriction': False}  ...                 0
# 4   {'domain': [], 'crossmark-restriction': False}  ...                 0
# 5   {'domain': [], 'crossmark-restriction': False}  ...                 0
# 6   {'domain': [], 'crossmark-restriction': False}  ...                 0
# 7   {'domain': [], 'crossmark-restriction': False}  ...                 0
# 10  {'domain': [], 'crossmark-restriction': False}  ...                 0
# 11  {'domain': [], 'crossmark-restriction': False}  ...                 0
# 12  {'domain': [], 'crossmark-restriction': False}  ...                 0
# 15  {'domain': [], 'crossmark-restriction': False}  ...                 0
#
#    references-count      score        short-container-title    source  \
# 0                 0  13.490670     [Trop Grass - Forr Trop]  Crossref
# 1                 0  13.429121                       [IJAR]  Crossref
# 2                 0  13.412168                          NaN  Crossref
# 4                 0  13.381683                          NaN  Crossref
# 5                 0  13.381683                          NaN  Crossref
# 6                 0  12.961740                      [phyto]  Crossref
# 7                 0  12.961740                     [AJFAND]  Crossref
# 10                0  12.824807                      [phyto]  Crossref
# 11                0  12.824807                          NaN  Crossref
# 12                0  12.824807                      [phyto]  Crossref
# 15                0  12.717586  [J. Meteorol. Related. Sci]  Crossref
#
#    subtitle                                              title  \
# 0       NaN   [Production of giant Panicum in semi-arid Kenya]
# 1       NaN  [SOCIAL DETERMINANTS INFLUENCING TRANSITION RA...
# 2       NaN                  [Important bird areas in Kenya /]
# 4       NaN               [Kenya: Kenya Law Reform Commission]
# 5       NaN               [Kenya: Kenya Law Reform Commission]
# 6       NaN  [The afroalpine plant communities of Mt. Kenya...
# 7       NaN  [Climate Change Effects on Crop Production in ...
# 10      NaN  [The forests of Mt. Kenya (Kenya), a phytosoci...
# 11      NaN  [Kenya: Counterterrorism in Kenya: Security ai...
# 12      NaN  [The afroalpine plant communities of Mt. Kenya...
# 15      NaN  [Use of Aquacrop Model to Predict Maize Yields...
#
#                type update-policy volume
# 0   journal-article           NaN      2
# 1   journal-article           NaN      6
# 2         monograph           NaN    NaN
# 4         component           NaN    NaN
# 5         component           NaN    NaN
# 6   journal-article           NaN     17
# 7   journal-article           NaN     19
# 10  journal-article           NaN     25
# 11     book-chapter           NaN    NaN
# 12  journal-article           NaN     16
# 15  journal-article           NaN      6
#
# [11 rows x 41 columns]

# %%
df_kenya
# Out:
#                                           DOI  \
# 0                     10.17138/tgft(2)100-102
# 1                        10.21474/ijar01/6544
# 2                     10.5962/bhl.title.87589
# 3                   10.1515/9783110826050-068
# 4                10.14217/9781848594371-12-en
# 5                10.14217/9781848594920-13-en
# 6                   10.1127/phyto/17/1989/287
# 7                 10.18697/ajfand.84.blfb1017
# 8                        10.1787/270604575355
# 9                        10.1787/124030037050
# 10                  10.1127/phyto/25/1995/467
# 11  10.7228/manchester/9781526105813.003.0016
# 12                  10.1127/phyto/16/1988/433
# 13                 10.5040/9781472926944.0150
# 14             10.1057/978-1-349-95839-9_1403
# 15                  10.20987/jmrs.08.2012.603
# 16                    10.1130/2014.dmch016.s1
# 17                    10.1130/2014.dmch016.s2
# 18                    10.1130/2014.dmch016.s4
# 19                    10.1130/2014.dmch016.s5
#
#                                              ISBN                    ISSN  \
# 0                                             NaN             [2346-3775]
# 1                                             NaN             [2320-5407]
# 2                                             NaN                     NaN
# 3                                 [9783110826050]                     NaN
# 4                                             NaN                     NaN
# 5                                             NaN                     NaN
# 6                                             NaN             [0340-269X]
# 7                                             NaN             [1684-5374]
# 8                                             NaN                     NaN
# 9                                             NaN                     NaN
# 10                                            NaN             [0340-269X]
# 11                 [9781526105813, 9781526135988]                     NaN
# 12                                            NaN             [0340-269X]
# 13  [9781472926944, 9781408189931, 9781408122549]                     NaN
# 14                 [9781349958382, 9781349958399]                     NaN
# 15                                            NaN  [1995-9834, 2412-3781]
# 16                                            NaN                     NaN
# 17                                            NaN                     NaN
# 18                                            NaN                     NaN
# 19                                            NaN                     NaN
#
#                                                   URL  \
# 0           http://dx.doi.org/10.17138/tgft(2)100-102
# 1              http://dx.doi.org/10.21474/ijar01/6544
# 2           http://dx.doi.org/10.5962/bhl.title.87589
# 3         http://dx.doi.org/10.1515/9783110826050-068
# 4      http://dx.doi.org/10.14217/9781848594371-12-en
# 5      http://dx.doi.org/10.14217/9781848594920-13-en
# 6         http://dx.doi.org/10.1127/phyto/17/1989/287
# 7       http://dx.doi.org/10.18697/ajfand.84.blfb1017
# 8              http://dx.doi.org/10.1787/270604575355
# 9              http://dx.doi.org/10.1787/124030037050
# 10        http://dx.doi.org/10.1127/phyto/25/1995/467
# 11  http://dx.doi.org/10.7228/manchester/978152610...
# 12        http://dx.doi.org/10.1127/phyto/16/1988/433
# 13       http://dx.doi.org/10.5040/9781472926944.0150
# 14   http://dx.doi.org/10.1057/978-1-349-95839-9_1403
# 15        http://dx.doi.org/10.20987/jmrs.08.2012.603
# 16          http://dx.doi.org/10.1130/2014.dmch016.s1
# 17          http://dx.doi.org/10.1130/2014.dmch016.s2
# 18          http://dx.doi.org/10.1130/2014.dmch016.s4
# 19          http://dx.doi.org/10.1130/2014.dmch016.s5
#
#                                              abstract alternative-id  \
# 0                                                 NaN       [136/84]
# 1                                                 NaN            NaN
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7                                                 NaN            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN            NaN
# 10                                                NaN            NaN
# 11  <p>Since the 1998 bombing of the US Embassy in...            NaN
# 12                                                NaN            NaN
# 13                                                NaN            NaN
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19                                                NaN            NaN
#
#                                             assertion  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  [{'value': '2 April 2019', 'order': 1, 'name':...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                                author  \
# 0   [{'given': 'Donald M.G.', 'family': 'Njarui', ...
# 1   [{'given': 'GladysJerono', 'family': 'Koech', ...
# 2   [{'given': 'Leon A.', 'family': 'Bennun', 'seq...
# 3                                                 NaN
# 4   [{'name': 'Commonwealth Secretariat', 'sequenc...
# 5   [{'name': 'Commonwealth Secretariat', 'sequenc...
# 6   [{'given': 'H.', 'family': 'Rehder', 'sequence...
# 7   [{'given': 'Beverly', 'family': 'Agesa', 'sequ...
# 8                                                 NaN
# 9                                                 NaN
# 10  [{'given': 'Rainer W.', 'family': 'Bussmann', ...
# 11  [{'given': 'Jeremy', 'family': 'Prestholdt', '...
# 12  [{'given': 'H.', 'family': 'Rehder', 'sequence...
# 13                                                NaN
# 14                                                NaN
# 15  [{'given': 'Joab', 'family': 'Wamari', 'sequen...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                       container-title  \
# 0         [Tropical Grasslands - Forrajes Tropicales]
# 1        [International Journal of Advanced Research]
# 2                                                 NaN
# 3   [Minerva. Internationales Verzeichnis Wissensc...
# 4                                                 NaN
# 5                                                 NaN
# 6                                   [Phytocoenologia]
# 7   [African Journal of Food, Agriculture, Nutriti...
# 8                                                 NaN
# 9                                                 NaN
# 10                                  [Phytocoenologia]
# 11               [Non-Western responses to terrorism]
# 12                                  [Phytocoenologia]
# 13   [Mammals of Africa : Hedgehogs, Shrews and Bats]
# 14               [The Statesman’s Yearbook Companion]
# 15      [Journal of Meteorology and Related Sciences]
# 16                  [Maps of the Southern Kenya Rift]
# 17                  [Maps of the Southern Kenya Rift]
# 18                  [Maps of the Southern Kenya Rift]
# 19                  [Maps of the Southern Kenya Rift]
#
#                                        content-domain  ...   reference-count  \
# 0      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 1      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 2      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 3      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 4      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 5      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 6      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 7      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 8      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 9      {'domain': [], 'crossmark-restriction': False}  ...                 0
# 10     {'domain': [], 'crossmark-restriction': False}  ...                 0
# 11     {'domain': [], 'crossmark-restriction': False}  ...                 0
# 12     {'domain': [], 'crossmark-restriction': False}  ...                 0
# 13     {'domain': [], 'crossmark-restriction': False}  ...                 0
# 14  {'domain': ['link.springer.com'], 'crossmark-r...  ...                 0
# 15     {'domain': [], 'crossmark-restriction': False}  ...                 0
# 16     {'domain': [], 'crossmark-restriction': False}  ...                 0
# 17     {'domain': [], 'crossmark-restriction': False}  ...                 0
# 18     {'domain': [], 'crossmark-restriction': False}  ...                 0
# 19     {'domain': [], 'crossmark-restriction': False}  ...                 0
#
#    references-count      score        short-container-title    source  \
# 0                 0  13.490670     [Trop Grass - Forr Trop]  Crossref
# 1                 0  13.429121                       [IJAR]  Crossref
# 2                 0  13.412168                          NaN  Crossref
# 3                 0  13.412168                          NaN  Crossref
# 4                 0  13.381683                          NaN  Crossref
# 5                 0  13.381683                          NaN  Crossref
# 6                 0  12.961740                      [phyto]  Crossref
# 7                 0  12.961740                     [AJFAND]  Crossref
# 8                 0  12.928367                          NaN  Crossref
# 9                 0  12.928367                          NaN  Crossref
# 10                0  12.824807                      [phyto]  Crossref
# 11                0  12.824807                          NaN  Crossref
# 12                0  12.824807                      [phyto]  Crossref
# 13                0  12.770800                          NaN  Crossref
# 14                0  12.770800                          NaN  Crossref
# 15                0  12.717586  [J. Meteorol. Related. Sci]  Crossref
# 16                0  12.655651                          NaN  Crossref
# 17                0  12.655651                          NaN  Crossref
# 18                0  12.655651                          NaN  Crossref
# 19                0  12.655651                          NaN  Crossref
#
#                                   subtitle  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14  [Jamhuri ya Kenya (Republic of Kenya)]
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
#
#                                                 title             type  \
# 0    [Production of giant Panicum in semi-arid Kenya]  journal-article
# 1   [SOCIAL DETERMINANTS INFLUENCING TRANSITION RA...  journal-article
# 2                   [Important bird areas in Kenya /]        monograph
# 3        [Kenya. Jamhuri ya Kenya; Republic of Kenya]     book-chapter
# 4                [Kenya: Kenya Law Reform Commission]        component
# 5                [Kenya: Kenya Law Reform Commission]        component
# 6   [The afroalpine plant communities of Mt. Kenya...  journal-article
# 7   [Climate Change Effects on Crop Production in ...  journal-article
# 8                                             [Kenya]        component
# 9                                             [Kenya]        component
# 10  [The forests of Mt. Kenya (Kenya), a phytosoci...  journal-article
# 11  [Kenya: Counterterrorism in Kenya: Security ai...     book-chapter
# 12  [The afroalpine plant communities of Mt. Kenya...  journal-article
# 13  [Surdisorex polulus Mount Kenya Mole-shrew : F...     book-chapter
# 14                                            [Kenya]     book-chapter
# 15  [Use of Aquacrop Model to Predict Maize Yields...  journal-article
# 16               [Geology of the Suswa Region, Kenya]     book-chapter
# 17             [Geology of the Nairobi Region, Kenya]     book-chapter
# 18             [Geology of the Kajiado Region, Kenya]     book-chapter
# 19       [Geology of the Area South of Magadi, Kenya]     book-chapter
#
#                                         update-policy volume
# 0                                                 NaN      2
# 1                                                 NaN      6
# 2                                                 NaN    NaN
# 3                                                 NaN    NaN
# 4                                                 NaN    NaN
# 5                                                 NaN    NaN
# 6                                                 NaN     17
# 7                                                 NaN     19
# 8                                                 NaN    NaN
# 9                                                 NaN    NaN
# 10                                                NaN     25
# 11                                                NaN    NaN
# 12                                                NaN     16
# 13                                                NaN    NaN
# 14  http://dx.doi.org/10.1007/springer_crossmark_p...    NaN
# 15                                                NaN      6
# 16                                                NaN    NaN
# 17                                                NaN    NaN
# 18                                                NaN    NaN
# 19                                                NaN    NaN
#
# [20 rows x 41 columns]
