# %% [markdown]
# # Library Module - Crossref API
#
# Welcome! In this module, we'll be introducing you to the online computing environment of Jupyter Notebooks, and giving an introduction to the Crossref API.
#
#
# ## Table of Contents
# [1. Introduction](#1)
#    - [1.1 Installing Packages](#1.1)
#    - [1.2 Introduction to Jupyter Notebook](#1.2)
#        - running cells, editing the notebook
#    - [1.3 Introduction to Python](#1.3)
#
# [2. Analysis using Crossref API](#2)
#    - [2.1 What is Crossref?](#2.1)
#    - [2.2 Packages for Crossref](#2.2)
#    - [2.3 Exploring the Data](#2.3)
#    - [2.4 Keys, Indexes, Metadata](#2.4)
#    - [2.5 Creating tables](#2.5)
#    - [2.6 Searches](#2.6)
#
# [3. Visualization](#3)
#    - [3.1 Journal Title](#3.1)
#    - [3.2 Publisher Topics](#3.2)
#    - [3.3 Grouping and Sorting by Journal](#3.3)
#         - this is 3,4 in outline
#    - [3.4 Citations](#3.4)
#         - 5, 6, 7, 8 in outline
#    - [3.5 Queries over Time](#3.5)
#
# [Bibliography](#4)

# %% [markdown]
# # Introduction <a id = '1'></a>
#
# Welcome to the notebook! This notebook is an introduction to Python and the CrossRef API, giving us access to over 80 million journal articles.
#
# # Learning Outcomes
# **By the end of this notebook, students should be able to:**
# - Use scaffolded Python code in the provided Jupyter notebook template to make Crossref subject and author queries
# - Extract reference information from Crossref query results
# - Visualize Crossref query results in bar plots and line plots. Interpret distributions and trends over time found in results
# - Compare results from two different keyword queries
# - Explore/Discover new research directions

# %% [markdown]
# # 1.1 Installing Packages <a id = '1.1'></a>
#
# There is a lot of code that exists out there that other people have written, and packages are a way for us to use their code without having to rewrite it. In the cell below, we install some packages that will be useful to us as we expore the Crossref API.

# %%
# just run this cell

# !pip install habanero
import habanero
from habanero import Crossref # our Crossref API
from collections import Counter # for easy counting
import pandas as pd # for data manipulation
import numpy as np # for array manipulation
import matplotlib.pyplot as plt # for data visualization
# %matplotlib inline

# %% [markdown]
# # 1.2 Introduction to Jupyter Notebook <a id = '1.2'></a>
# Running Cells, Editing the Notebook
#
# Jyputer notebooks are a type of online interactive computing environment composed of code and text cells. Notebooks contain a mixture of markdown and code cells to break down the activity into more manageable pieces.
#
#
# ### Creating Cells
# To add a cell to the notebook, click the "+" in the top left area right under "File".
#
# Within a cell, you have the option to write code, create a heading, or write text. To select an option, click on the "Code" button, located on the same row as "+". You will see a menu of options to choose from.
#
#
# Markdown - use for text
# <br>
# Code - use for running code
# <br>
# Heading - use for titles
#
# ### Deleting Cells
# To delete a cell, click on the cell, and click the **scissors** icon to the right of the "+".
#
# ### Saving Your Work
# To save your work, click on "File", then "Save and Checkpoint". If you have a Mac, you can click **"Command + S"**.
#
# For this notebook, you only need to know how to run, edit and create cells. However, for more assistance with navigating Jupyter Notebook, click on the **keyboard** icon next to the cell drop-down menu.
#
# For more help, here's a great cheat sheet: https://i.pinimg.com/originals/f5/7e/07/f57e074be4503a39f6d9d8d15f0e8aa5.png

# %% [markdown]
# # Introduction to Python <a id = '1.3'></a>
# Python is a programming language applied very frequently in data science. In the first part of this notebook, we will give a brief overview of Python.
#
# ### Variables
# A name that is used to denote something or a value is called a `variable`. In python, variables can be declared and values can be assigned to them. Values can include numbers and strings. Run the code below:

# %%
x = 5
y = 2
hi = "Hello World"

# %% [markdown]
# Because the above cell ran, we've now officially assigned the variables to values. Run the cell (Shift + Enter) below to see the output of `x`, `hi`, and `print (x+y)`. Running the cell tells our computer to treat those symbols as the given values. If you didn't run the cell above, python wouldn't recognize the variables below.

# %%
x
# Out:
# 5

# %%
hi
# Out:
# 'Hello World'

# %%
print (x + y)
# Out:
# 7

# %% [markdown]
# # 2. Analysis using Crossref API <a id = '2'></a>
# The main goal of this notebook is to give an introduction to Crossref. In the sections below, we walk through the basics of Crossref

# %% [markdown]
# # 2.1 What is Crossref? <a id = '2.1'></a>
#
# Crossref is a non-profit organization that helps to provides access to scientific literature. According to their [website itself](https://www.crossref.org/), Crossref "makes research outputs easy to find, cite, link, and assess".
#
# Crossref data on scientific publications essentially consists of three elements:
# <br>
#     1) Metadata about a publication
#     <br>
#     2) A URL link to the article
#     <br>
#     3) A document identifier (doi)
#     <br>
#
# At present Crossref contains information on 80 million scientific publications including articles, books and book chapters.

# %% [markdown]
# Data can be accessed using the python packages `habanero`, `crossrefapi`, and `crossref-commons`. In this module, we'll be focusing on the functionality of the **habanero** package.

# %% [markdown]
# # 2.2 Packages for Crossref <a id = '2.2'></a>

# %% [markdown]
# When importing a package into Jupyter Notebook, we use the command `pip install ...` to download a package into Jupyter Notebook.
#
# We then use the command `import (package name)` to use our new package in our code.

# %%
# !pip install habanero
# Out:
# Requirement already satisfied: habanero in c:\users\keily\appdata\local\continuum\anaconda3\lib\site-packages (0.7.2)
# Requirement already satisfied: tqdm in c:\users\keily\appdata\local\continuum\anaconda3\lib\site-packages (from habanero) (4.36.1)
# Requirement already satisfied: requests>=2.7.0 in c:\users\keily\appdata\local\continuum\anaconda3\lib\site-packages (from habanero) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\keily\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.7.0->habanero) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\keily\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.7.0->habanero) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\keily\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.7.0->habanero) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\keily\appdata\local\continuum\anaconda3\lib\site-packages (from requests>=2.7.0->habanero) (3.0.4)

# %%
#To use Crossref API in Python, we need to import the habanero package
import habanero
from habanero import Crossref

# %% [markdown]
# # 2.3 Exploring the Data <a id = '2.3'></a>
# In the cells below, we walk through using Crossref and exploring the data it gives us. To create an object that takes on the Crossref identity, we assign it to the variable `cr`.

# %%
cr = Crossref() # create a crossref object

# %% [markdown]
# The main function we will use is called `cr.works()`. This function takes in a query name. As an example, we'll use the search term "kenya". In order to save this output, we'll assign it to the variable name `kenya`.

# %%
# query for the term "kenya"
kenya = cr.works(query = "kenya")

# %% [markdown]
# If we inpspect `kenya`, we can see that it is a dictionary.

# %%
type(kenya)
# Out:
# dict

# %%
kenya
# Out:
# {'status': 'ok',
#  'message-type': 'work-list',
#  'message-version': '1.0.0',
#  'message': {'facets': {},
#   'total-results': 42232,
#   'items': [{'indexed': {'date-parts': [[2019, 11, 24]],
#      'date-time': '2019-11-24T10:48:27Z',
#      'timestamp': 1574592507823},
#     'reference-count': 0,
#     'publisher': 'Centro Internacional de Agricultura Tropical',
#     'issue': '1',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['Trop Grass - Forr Trop'],
#     'DOI': '10.17138/tgft(2)100-102',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2015, 4, 1]],
#      'date-time': '2015-04-01T20:32:16Z',
#      'timestamp': 1427920336000},
#     'page': '100',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Production of giant Panicum in semi-arid Kenya'],
#     'prefix': '10.17138',
#     'volume': '2',
#     'author': [{'given': 'Donald M.G.',
#       'family': 'Njarui',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Mwangi',
#       'family': 'Gatheru',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'David M.',
#       'family': 'Mwangi',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'George A.',
#       'family': 'Keya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '6578',
#     'published-online': {'date-parts': [[2014]]},
#     'container-title': ['Tropical Grasslands - Forrajes Tropicales'],
#     'language': 'en',
#     'deposited': {'date-parts': [[2015, 4, 1]],
#      'date-time': '2015-04-01T20:32:45Z',
#      'timestamp': 1427920365000},
#     'score': 13.5145,
#     'issued': {'date-parts': [[2014]]},
#     'references-count': 0,
#     'journal-issue': {'published-online': {'date-parts': [[2014]]},
#      'issue': '1'},
#     'alternative-id': ['136/84'],
#     'URL': 'http://dx.doi.org/10.17138/tgft(2)100-102',
#     'ISSN': ['2346-3775'],
#     'issn-type': [{'value': '2346-3775', 'type': 'electronic'}]},
#    {'indexed': {'date-parts': [[2019, 11, 23]],
#      'date-time': '2019-11-23T20:37:06Z',
#      'timestamp': 1574541426012},
#     'publisher-location': 'Nairobi :',
#     'reference-count': 0,
#     'publisher': 'Nature Kenya, East Africa Natural History Society,',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[1999]]},
#     'DOI': '10.5962/bhl.title.87589',
#     'type': 'monograph',
#     'created': {'date-parts': [[2014, 8, 24]],
#      'date-time': '2014-08-24T06:00:31Z',
#      'timestamp': 1408860031000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 74,
#     'title': ['Important bird areas in Kenya /'],
#     'prefix': '10.5962',
#     'author': [{'given': 'Leon A.',
#       'family': 'Bennun',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Peter.',
#       'family': 'Njoroge',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'National Museums of Kenya.',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Nature Kenya.', 'sequence': 'additional', 'affiliation': []}],
#     'member': '3444',
#     'deposited': {'date-parts': [[2014, 8, 24]],
#      'date-time': '2014-08-24T06:00:31Z',
#      'timestamp': 1408860031000},
#     'score': 13.457988,
#     'issued': {'date-parts': [[1999]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.5962/bhl.title.87589'},
#    {'indexed': {'date-parts': [[2020, 3, 24]],
#      'date-time': '2020-03-24T22:28:20Z',
#      'timestamp': 1585088900467},
#     'publisher-location': 'Berlin, Boston',
#     'reference-count': 0,
#     'publisher': 'De Gruyter',
#     'isbn-type': [{'value': '9783110826050', 'type': 'electronic'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[1972, 12, 31]]},
#     'DOI': '10.1515/9783110826050-068',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2019, 2, 25]],
#      'date-time': '2019-02-25T09:01:06Z',
#      'timestamp': 1551085266000},
#     'page': '304-305',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya. Jamhuri ya Kenya; Republic of Kenya'],
#     'prefix': '10.1515',
#     'member': '374',
#     'container-title': ['Minerva. Internationales Verzeichnis Wissenschaftlicher Institutionen'],
#     'link': [{'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#       'content-type': 'text/html',
#       'content-version': 'vor',
#       'intended-application': 'text-mining'},
#      {'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2019, 2, 25]],
#      'date-time': '2019-02-25T09:11:29Z',
#      'timestamp': 1551085889000},
#     'score': 13.457988,
#     'editor': [{'given': 'Werner',
#       'family': 'Schuder',
#       'sequence': 'first',
#       'affiliation': []}],
#     'issued': {'date-parts': [[1972, 12, 31]]},
#     'ISBN': ['9783110826050'],
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1515/9783110826050-068'},
#    {'indexed': {'date-parts': [[2020, 3, 30]],
#      'date-time': '2020-03-30T03:56:21Z',
#      'timestamp': 1585540581107},
#     'reference-count': 0,
#     'publisher': 'International Journal Of Advanced Research',
#     'issue': '2',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['IJAR'],
#     'DOI': '10.21474/ijar01/6544',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2018, 3, 30]],
#      'date-time': '2018-03-30T10:49:35Z',
#      'timestamp': 1522406975000},
#     'page': '1195-1203',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['SOCIAL DETERMINANTS INFLUENCING TRANSITION RATE OF GIRLS FROM PRIMARY EDUCATION TO SECONDARY EDUCATION IN KOIBATEK SUB-COUNTY, KENYA.'],
#     'prefix': '10.21474',
#     'volume': '6',
#     'author': [{'given': 'GladysJerono',
#       'family': 'Koech',
#       'sequence': 'first',
#       'affiliation': []},
#      {'name': 'Mount Kenya University, Kenya',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'JoshuaOdhiambo',
#       'family': 'Ogal',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'Rachael',
#       'family': 'Koros',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Mount Kenya University, Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Mount Kenya University, Kenya',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '8913',
#     'published-online': {'date-parts': [[2018, 2, 28]]},
#     'container-title': ['International Journal of Advanced Research'],
#     'deposited': {'date-parts': [[2018, 3, 30]],
#      'date-time': '2018-03-30T10:49:35Z',
#      'timestamp': 1522406975000},
#     'score': 13.454593,
#     'issued': {'date-parts': [[2018, 2, 28]]},
#     'references-count': 0,
#     'journal-issue': {'published-online': {'date-parts': [[2018, 2, 28]]},
#      'issue': '2'},
#     'URL': 'http://dx.doi.org/10.21474/ijar01/6544',
#     'ISSN': ['2320-5407'],
#     'issn-type': [{'value': '2320-5407', 'type': 'electronic'}]},
#    {'indexed': {'date-parts': [[2020, 3, 24]],
#      'date-time': '2020-03-24T04:53:29Z',
#      'timestamp': 1585025609025},
#     'reference-count': 0,
#     'publisher': 'Commonwealth Secretariat',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[1987, 12, 1]]},
#     'DOI': '10.14217/9781848594371-12-en',
#     'type': 'component',
#     'created': {'date-parts': [[2016, 1, 29]],
#      'date-time': '2016-01-29T06:18:13Z',
#      'timestamp': 1454048293000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya: Kenya Law Reform Commission'],
#     'prefix': '10.14217',
#     'author': [{'name': 'Commonwealth Secretariat',
#       'sequence': 'first',
#       'affiliation': []}],
#     'member': '5318',
#     'deposited': {'date-parts': [[2018, 10, 7]],
#      'date-time': '2018-10-07T08:05:04Z',
#      'timestamp': 1538899504000},
#     'score': 13.444708,
#     'issued': {'date-parts': [[1987, 12, 1]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.14217/9781848594371-12-en'},
#    {'indexed': {'date-parts': [[2020, 3, 24]],
#      'date-time': '2020-03-24T04:53:11Z',
#      'timestamp': 1585025591207},
#     'reference-count': 0,
#     'publisher': 'Commonwealth Secretariat',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[1992, 1, 1]]},
#     'DOI': '10.14217/9781848594920-13-en',
#     'type': 'component',
#     'created': {'date-parts': [[2016, 1, 29]],
#      'date-time': '2016-01-29T06:18:13Z',
#      'timestamp': 1454048293000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 1,
#     'title': ['Kenya: Kenya Law Reform Commission'],
#     'prefix': '10.14217',
#     'author': [{'name': 'Commonwealth Secretariat',
#       'sequence': 'first',
#       'affiliation': []}],
#     'member': '5318',
#     'deposited': {'date-parts': [[2018, 10, 8]],
#      'date-time': '2018-10-08T07:55:20Z',
#      'timestamp': 1538985320000},
#     'score': 13.444708,
#     'issued': {'date-parts': [[1992, 1, 1]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.14217/9781848594920-13-en'},
#    {'indexed': {'date-parts': [[2019, 12, 2]],
#      'date-time': '2019-12-02T18:07:57Z',
#      'timestamp': 1575310077028},
#     'reference-count': 0,
#     'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1787/124030037050',
#     'type': 'component',
#     'created': {'date-parts': [[2008, 9, 30]],
#      'date-time': '2008-09-30T12:02:13Z',
#      'timestamp': 1222776133000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya'],
#     'prefix': '10.1787',
#     'member': '1963',
#     'deposited': {'date-parts': [[2014, 5, 27]],
#      'date-time': '2014-05-27T17:04:56Z',
#      'timestamp': 1401210296000},
#     'score': 13.026722,
#     'issued': {'date-parts': [[None]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1787/124030037050'},
#    {'indexed': {'date-parts': [[2019, 12, 2]],
#      'date-time': '2019-12-02T18:07:57Z',
#      'timestamp': 1575310077572},
#     'reference-count': 0,
#     'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1787/270604575355',
#     'type': 'component',
#     'created': {'date-parts': [[2008, 9, 30]],
#      'date-time': '2008-09-30T12:02:13Z',
#      'timestamp': 1222776133000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya'],
#     'prefix': '10.1787',
#     'member': '1963',
#     'deposited': {'date-parts': [[2014, 5, 27]],
#      'date-time': '2014-05-27T17:04:57Z',
#      'timestamp': 1401210297000},
#     'score': 13.026722,
#     'issued': {'date-parts': [[None]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1787/270604575355'},
#    {'indexed': {'date-parts': [[2020, 3, 30]],
#      'date-time': '2020-03-30T05:34:42Z',
#      'timestamp': 1585546482946},
#     'reference-count': 0,
#     'publisher': 'Schweizerbart',
#     'issue': '2',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['phyto'],
#     'published-print': {'date-parts': [[1989, 5, 2]]},
#     'DOI': '10.1127/phyto/17/1989/287',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2014, 1, 29]],
#      'date-time': '2014-01-29T05:09:25Z',
#      'timestamp': 1390972165000},
#     'page': '287-288',
#     'source': 'Crossref',
#     'is-referenced-by-count': 1,
#     'title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#     'prefix': '10.1127',
#     'volume': '17',
#     'author': [{'given': 'H.',
#       'family': 'Rehder',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'E.',
#       'family': 'Beck',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'J. O.',
#       'family': 'Kokwaro',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '181',
#     'container-title': ['Phytocoenologia'],
#     'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#     'language': 'en',
#     'deposited': {'date-parts': [[2017, 4, 11]],
#      'date-time': '2017-04-11T05:00:28Z',
#      'timestamp': 1491886828000},
#     'score': 12.975961,
#     'issued': {'date-parts': [[1989, 5, 2]]},
#     'references-count': 0,
#     'journal-issue': {'published-print': {'date-parts': [[1989, 5, 2]]},
#      'issue': '2'},
#     'URL': 'http://dx.doi.org/10.1127/phyto/17/1989/287',
#     'ISSN': ['0340-269X'],
#     'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#    {'indexed': {'date-parts': [[2020, 3, 24]],
#      'date-time': '2020-03-24T19:41:32Z',
#      'timestamp': 1585078892966},
#     'reference-count': 0,
#     'publisher': 'African Journal of Food, Agriculture, Nutrition and Development',
#     'issue': '01',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['AJFAND'],
#     'DOI': '10.18697/ajfand.84.blfb1017',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2019, 2, 2]],
#      'date-time': '2019-02-02T09:05:42Z',
#      'timestamp': 1549098342000},
#     'page': '14010-14042',
#     'source': 'Crossref',
#     'is-referenced-by-count': 15,
#     'title': ['Climate Change Effects on Crop Production in Kenya: Farmer Perceptions and Adaptation Strategies'],
#     'prefix': '10.18697',
#     'volume': '19',
#     'author': [{'given': 'Beverly',
#       'family': 'Agesa',
#       'sequence': 'first',
#       'affiliation': []},
#      {'name': 'University  of Nairobi, Nairobi, Kenya',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'CM',
#       'family': 'Onyango',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'VM',
#       'family': 'Kathumo',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'RN',
#       'family': 'Onwonga',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'GN',
#       'family': 'Karuku',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'University  of  Nairobi, Nairobi, Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'University  of  Nairobi,  Nairobi, Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'University  of Nairobi, Nairobi, Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Univesity of Nairobi, Nairobi, Kenya',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '8080',
#     'published-online': {'date-parts': [[2019, 2, 1]]},
#     'container-title': ['African Journal of Food, Agriculture, Nutrition and Development'],
#     'link': [{'URL': 'https://www.ajfand.net/Volume19/No1/BLFB1017.pdf',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2019, 2, 2]],
#      'date-time': '2019-02-02T09:05:44Z',
#      'timestamp': 1549098344000},
#     'score': 12.975961,
#     'issued': {'date-parts': [[2019, 2, 1]]},
#     'references-count': 0,
#     'journal-issue': {'published-online': {'date-parts': [[2019, 2, 1]]},
#      'issue': '01'},
#     'URL': 'http://dx.doi.org/10.18697/ajfand.84.blfb1017',
#     'ISSN': ['1684-5374'],
#     'issn-type': [{'value': '1684-5374', 'type': 'electronic'}]},
#    {'indexed': {'date-parts': [[2020, 3, 30]],
#      'date-time': '2020-03-30T05:34:42Z',
#      'timestamp': 1585546482746},
#     'reference-count': 0,
#     'publisher': 'Schweizerbart',
#     'issue': '4',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['phyto'],
#     'published-print': {'date-parts': [[1988, 12, 7]]},
#     'DOI': '10.1127/phyto/16/1988/433',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2014, 1, 29]],
#      'date-time': '2014-01-29T10:09:25Z',
#      'timestamp': 1390990165000},
#     'page': '433-463',
#     'source': 'Crossref',
#     'is-referenced-by-count': 9,
#     'title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#     'prefix': '10.1127',
#     'volume': '16',
#     'author': [{'given': 'H.',
#       'family': 'Rehder',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'E.',
#       'family': 'Beck',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'J. O.',
#       'family': 'Kokwaro',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '181',
#     'container-title': ['Phytocoenologia'],
#     'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#     'language': 'en',
#     'deposited': {'date-parts': [[2017, 4, 11]],
#      'date-time': '2017-04-11T10:26:22Z',
#      'timestamp': 1491906382000},
#     'score': 12.843469,
#     'issued': {'date-parts': [[1988, 12, 7]]},
#     'references-count': 0,
#     'journal-issue': {'published-print': {'date-parts': [[1988, 12, 7]]},
#      'issue': '4'},
#     'URL': 'http://dx.doi.org/10.1127/phyto/16/1988/433',
#     'ISSN': ['0340-269X'],
#     'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#    {'indexed': {'date-parts': [[2020, 3, 30]],
#      'date-time': '2020-03-30T05:35:03Z',
#      'timestamp': 1585546503509},
#     'reference-count': 0,
#     'publisher': 'Schweizerbart',
#     'issue': '4',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['phyto'],
#     'published-print': {'date-parts': [[1995, 12, 14]]},
#     'DOI': '10.1127/phyto/25/1995/467',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2014, 1, 29]],
#      'date-time': '2014-01-29T11:02:59Z',
#      'timestamp': 1390993379000},
#     'page': '467-560',
#     'source': 'Crossref',
#     'is-referenced-by-count': 9,
#     'title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#     'prefix': '10.1127',
#     'volume': '25',
#     'author': [{'given': 'Rainer W.',
#       'family': 'Bussmann',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Erwin',
#       'family': 'Beck',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '181',
#     'container-title': ['Phytocoenologia'],
#     'original-title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#     'language': 'en',
#     'deposited': {'date-parts': [[2017, 4, 11]],
#      'date-time': '2017-04-11T09:04:27Z',
#      'timestamp': 1491901467000},
#     'score': 12.843469,
#     'issued': {'date-parts': [[1995, 12, 14]]},
#     'references-count': 0,
#     'journal-issue': {'published-print': {'date-parts': [[1995, 12, 14]]},
#      'issue': '4'},
#     'URL': 'http://dx.doi.org/10.1127/phyto/25/1995/467',
#     'ISSN': ['0340-269X'],
#     'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#    {'indexed': {'date-parts': [[2020, 3, 26]],
#      'date-time': '2020-03-26T05:06:29Z',
#      'timestamp': 1585199189664},
#     'reference-count': 0,
#     'publisher': 'Manchester University Press',
#     'isbn-type': [{'value': '9781526105813', 'type': 'print'},
#      {'value': '9781526135988', 'type': 'electronic'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[2019, 3, 1]]},
#     'abstract': '<p>Since the 1998 bombing of the US Embassy in Nairobi, the Government of Kenya’s response to terrorism has been multifaceted. Government efforts have primarily relied on civil authorities and the military, thus privileging the use of force over subtler means. The Kenyan Police have employed measures such as profiling, detention, and prosecution. The Kenyan military has conducted operations in Kenya and Somalia. These strategies have contributed to the apprehension of some terrorist suspects and checked Shabaab’s advance in Somalia. Yet, Kenya’s counterterrorism efforts have been hampered by limited coordination among agencies, the use of heavy-handed tactics, and insufficient engagement with civil society organizations. Two defining features of Kenyan counterterrorism efforts have emerged. First, counterterrorism in Kenya has clear sociocultural dimensions. Security forces have responded to the threat of terrorism by focusing intently on Kenya’s alienated Muslim communities both in the Somali-majority north and at the Swahili-speaking coast. As a result, the Government of Kenya’s response to terrorism reflects communal divisions and animosity within Kenyan society that precede contemporary counterterrorism. Second, Kenya’s invasion of neighboring Somalia created and blurred two fronts: one within Kenya and the other in southern Somalia. The actions of Kenyan policy-makers and al Shabaab therefore contributed to a more complete integration of the conflict in Somalia and internal tensions in Kenya..</p>',
#     'DOI': '10.7228/manchester/9781526105813.003.0016',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2019, 5, 23]],
#      'date-time': '2019-05-23T09:38:00Z',
#      'timestamp': 1558604280000},
#     'page': '386-409',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#     'prefix': '10.7228',
#     'author': [{'given': 'Jeremy',
#       'family': 'Prestholdt',
#       'sequence': 'first',
#       'affiliation': []}],
#     'member': '4230',
#     'published-online': {'date-parts': [[2019, 5, 23]]},
#     'container-title': ['Non-Western responses to terrorism'],
#     'original-title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#     'deposited': {'date-parts': [[2019, 5, 23]],
#      'date-time': '2019-05-23T09:38:00Z',
#      'timestamp': 1558604280000},
#     'score': 12.843469,
#     'issued': {'date-parts': [[2019, 3, 1]]},
#     'ISBN': ['9781526105813', '9781526135988'],
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.7228/manchester/9781526105813.003.0016'},
#    {'indexed': {'date-parts': [[2019, 12, 4]],
#      'date-time': '2019-12-04T05:53:32Z',
#      'timestamp': 1575438812997},
#     'publisher-location': 'London',
#     'reference-count': 0,
#     'publisher': 'Palgrave Macmillan UK',
#     'isbn-type': [{'value': '9781349958382', 'type': 'print'},
#      {'value': '9781349958399', 'type': 'electronic'}],
#     'license': [{'URL': 'http://www.springer.com/tdm',
#       'start': {'date-parts': [[2019, 1, 1]],
#        'date-time': '2019-01-01T00:00:00Z',
#        'timestamp': 1546300800000},
#       'delay-in-days': 0,
#       'content-version': 'tdm'}],
#     'content-domain': {'domain': ['link.springer.com'],
#      'crossmark-restriction': False},
#     'published-print': {'date-parts': [[2019]]},
#     'DOI': '10.1057/978-1-349-95839-9_1403',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2019, 4, 17]],
#      'date-time': '2019-04-17T10:48:42Z',
#      'timestamp': 1555498122000},
#     'page': '714-715',
#     'update-policy': 'http://dx.doi.org/10.1007/springer_crossmark_policy',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya'],
#     'prefix': '10.1057',
#     'member': '297',
#     'published-online': {'date-parts': [[2019, 4, 2]]},
#     'container-title': ['The Statesman’s Yearbook Companion'],
#     'link': [{'URL': 'http://link.springer.com/content/pdf/10.1057/978-1-349-95839-9_1403',
#       'content-type': 'unspecified',
#       'content-version': 'vor',
#       'intended-application': 'similarity-checking'}],
#     'deposited': {'date-parts': [[2019, 4, 17]],
#      'date-time': '2019-04-17T10:57:59Z',
#      'timestamp': 1555498679000},
#     'score': 12.79614,
#     'subtitle': ['Jamhuri ya Kenya (Republic of Kenya)'],
#     'issued': {'date-parts': [[2019]]},
#     'ISBN': ['9781349958382', '9781349958399'],
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1057/978-1-349-95839-9_1403',
#     'assertion': [{'value': '2 April 2019',
#       'order': 1,
#       'name': 'first_online',
#       'label': 'First Online',
#       'group': {'name': 'ChapterHistory', 'label': 'Chapter History'}}]},
#    {'indexed': {'date-parts': [[2020, 3, 25]],
#      'date-time': '2020-03-25T20:58:24Z',
#      'timestamp': 1585169904857},
#     'reference-count': 0,
#     'publisher': 'Bloomsbury Publishing',
#     'isbn-type': [{'value': '9781408122549', 'type': 'print'},
#      {'value': '9781408189931', 'type': 'electronic'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.5040/9781472926944.0150',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2016, 6, 24]],
#      'date-time': '2016-06-24T17:27:36Z',
#      'timestamp': 1466789256000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Surdisorex polulus Mount Kenya Mole-shrew : Fr. Musaraigne du Mont Kenya; Ger. Mount Kenya Wühlspitzmaus'],
#     'prefix': '10.5040',
#     'member': '2984',
#     'container-title': ['Mammals of Africa : Hedgehogs, Shrews and Bats'],
#     'deposited': {'date-parts': [[2016, 7, 4]],
#      'date-time': '2016-07-04T13:54:23Z',
#      'timestamp': 1467640463000},
#     'score': 12.79614,
#     'issued': {'date-parts': [[None]]},
#     'ISBN': ['9781472926944', '9781408189931', '9781408122549'],
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.5040/9781472926944.0150'},
#    {'indexed': {'date-parts': [[2020, 3, 25]],
#      'date-time': '2020-03-25T19:00:30Z',
#      'timestamp': 1585162830294},
#     'reference-count': 0,
#     'publisher': 'Kenya Meteorological Society',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'short-container-title': ['J. Meteorol. Related. Sci'],
#     'published-print': {'date-parts': [[2007, 9, 19]]},
#     'DOI': '10.20987/jmrs.08.2012.603',
#     'type': 'journal-article',
#     'created': {'date-parts': [[2016, 5, 31]],
#      'date-time': '2016-05-31T07:04:14Z',
#      'timestamp': 1464678254000},
#     'page': '26-35',
#     'source': 'Crossref',
#     'is-referenced-by-count': 2,
#     'title': ['Use of Aquacrop Model to Predict Maize Yields under varying Rainfall and Temperature in a Semi-Arid Environment in Kenya'],
#     'prefix': '10.20987',
#     'volume': '6',
#     'author': [{'given': 'Joab',
#       'family': 'Wamari',
#       'sequence': 'first',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#       'sequence': 'first',
#       'affiliation': []},
#      {'given': 'Sijali',
#       'family': 'Isaya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'Lee',
#       'family': 'Kheng',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'Joseph',
#       'family': 'Miriti',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'given': 'Esilaba',
#       'family': 'Obutiati',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Soil and Water management and Crop Nutrition Section',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'National Agricultural Research Centre -Kenya',
#       'sequence': 'additional',
#       'affiliation': []},
#      {'name': 'Kenya Agricultural Research institute',
#       'sequence': 'additional',
#       'affiliation': []}],
#     'member': '8610',
#     'container-title': ['Journal of Meteorology and Related Sciences'],
#     'deposited': {'date-parts': [[2017, 7, 26]],
#      'date-time': '2017-07-26T21:59:54Z',
#      'timestamp': 1501106394000},
#     'score': 12.722612,
#     'issued': {'date-parts': [[2007, 9, 19]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.20987/jmrs.08.2012.603',
#     'ISSN': ['1995-9834', '2412-3781'],
#     'issn-type': [{'value': '1995-9834', 'type': 'print'},
#      {'value': '2412-3781', 'type': 'electronic'}]},
#    {'institution': {'name': 'Koninklijke Brill NV',
#      'place': ['-'],
#      'acronym': ['BRILL']},
#     'indexed': {'date-parts': [[2019, 11, 23]],
#      'date-time': '2019-11-23T19:38:50Z',
#      'timestamp': 1574537930164},
#     'reference-count': 0,
#     'publisher': 'Brill',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1163/_afco_asc_3100',
#     'type': 'dataset',
#     'created': {'date-parts': [[2014, 8, 8]],
#      'date-time': '2014-08-08T12:35:44Z',
#      'timestamp': 1407501344000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya International Film Festival (Nairobi et al., Kenya)'],
#     'prefix': '10.1163',
#     'member': '50',
#     'container-title': ['African Studies Companion Online'],
#     'deposited': {'date-parts': [[2018, 11, 21]],
#      'date-time': '2018-11-21T06:03:11Z',
#      'timestamp': 1542780191000},
#     'score': 12.69376,
#     'issued': {'date-parts': [[None]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1163/_afco_asc_3100'},
#    {'institution': {'name': 'Koninklijke Brill NV',
#      'place': ['-'],
#      'acronym': ['BRILL']},
#     'indexed': {'date-parts': [[2019, 11, 23]],
#      'date-time': '2019-11-23T19:38:11Z',
#      'timestamp': 1574537891045},
#     'reference-count': 0,
#     'publisher': 'Brill',
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1163/1872-9037_afco_asc_3100',
#     'type': 'dataset',
#     'created': {'date-parts': [[2014, 8, 8]],
#      'date-time': '2014-08-08T12:35:44Z',
#      'timestamp': 1407501344000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Kenya International Film Festival (Nairobi et al., Kenya)'],
#     'prefix': '10.1163',
#     'member': '50',
#     'container-title': ['African Studies Companion Online'],
#     'deposited': {'date-parts': [[2018, 11, 21]],
#      'date-time': '2018-11-21T06:03:09Z',
#      'timestamp': 1542780189000},
#     'score': 12.69376,
#     'issued': {'date-parts': [[None]]},
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1163/1872-9037_afco_asc_3100'},
#    {'indexed': {'date-parts': [[2019, 11, 25]],
#      'date-time': '2019-11-25T18:49:56Z',
#      'timestamp': 1574707796806},
#     'reference-count': 0,
#     'publisher': 'Palgrave Macmillan',
#     'isbn-type': [{'value': '9781137440532', 'type': 'print'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'DOI': '10.1057/9781137440532.0010',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2015, 6, 30]],
#      'date-time': '2015-06-30T13:16:24Z',
#      'timestamp': 1435670184000},
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Indian Private Doctors in Kenya'],
#     'prefix': '10.1057',
#     'member': '297',
#     'container-title': ['Indian Doctors in Kenya, 1895-1940'],
#     'deposited': {'date-parts': [[2015, 6, 30]],
#      'date-time': '2015-06-30T13:37:59Z',
#      'timestamp': 1435671479000},
#     'score': 12.69376,
#     'issued': {'date-parts': [[None]]},
#     'ISBN': ['9781137440532'],
#     'references-count': 0,
#     'URL': 'http://dx.doi.org/10.1057/9781137440532.0010'},
#    {'indexed': {'date-parts': [[2019, 11, 24]],
#      'date-time': '2019-11-24T08:14:12Z',
#      'timestamp': 1574583252861},
#     'publisher-location': 'UK and Ireland',
#     'reference-count': 0,
#     'publisher': 'Oxfam Publishing',
#     'isbn-type': [{'value': '9780855983826', 'type': 'print'},
#      {'value': '9780855987800', 'type': 'electronic'}],
#     'content-domain': {'domain': [], 'crossmark-restriction': False},
#     'published-print': {'date-parts': [[1998, 1]]},
#     'DOI': '10.3362/9780855987800.000',
#     'type': 'book-chapter',
#     'created': {'date-parts': [[2015, 2, 19]],
#      'date-time': '2015-02-19T02:07:57Z',
#      'timestamp': 1424311677000},
#     'page': '1-3',
#     'source': 'Crossref',
#     'is-referenced-by-count': 0,
#     'title': ['Prelims - Kenya'],
#     'prefix': '10.3362',
#     'author': [{'given': 'Geoff',
#       'family': 'Sayer',
#       'sequence': 'first',
#       'affiliation': []}],
#     'member': '1928',
#     'published-online': {'date-parts': [[2015, 2, 18]]},
#     'container-title': ['Kenya'],
#     'deposited': {'date-parts': [[2018, 8, 9]],
#      'date-time': '2018-08-09T20:31:31Z',
#      'timestamp': 1533846691000},
#     'score': 12.69376,
#     'issued': {'date-parts': [[1998, 1]]},
#     'ISBN': ['9780855983826', '9780855987800'],
#     'references-count': 0,
#     'alternative-id': ['10.3362/9780855987800.000', '10.3362/9780855987800'],
#     'URL': 'http://dx.doi.org/10.3362/9780855987800.000'}],
#   'items-per-page': 20,
#   'query': {'start-index': 0, 'search-terms': 'kenya'}}}

# %% [markdown]
# In the cell below, try creating your own query for a different search term. Make sure to save it to a variable! For now, limit your search term to a single word.

# %%
# your query here
query = cr.works(query = "...")

# %%
# example
query = cr.works(query='berkeley')

# %% [markdown]
#  # 2.4 Keys, Indexes, Metadata <a id = '2.4'></a>
#  A dictionary is a type of data structure that is indexed by keys. A dictionary contains key-value pairs, and we can access the values by calling on the keys. In our `kenya` dictionary, we can inspect the keys and take a look at the values that it contains.

# %%
list(kenya.keys())
# Out:
# ['status', 'message-type', 'message-version', 'message']

# %% [markdown]
# Above, we can see that there are 4 different keys in our `kenya` dictionary. Let's see what the values are for each of the keys. In the cells below, we are accessing the values by *indexing* into the dictionary by the given keys.

# %%
kenya['status']
# Out:
# 'ok'

# %%
kenya['message-type']
# Out:
# 'work-list'

# %%
kenya['message-version']
# Out:
# '1.0.0'

# %%
kenya['message']
# Out:
# {'facets': {},
#  'total-results': 42232,
#  'items': [{'indexed': {'date-parts': [[2019, 11, 24]],
#     'date-time': '2019-11-24T10:48:27Z',
#     'timestamp': 1574592507823},
#    'reference-count': 0,
#    'publisher': 'Centro Internacional de Agricultura Tropical',
#    'issue': '1',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['Trop Grass - Forr Trop'],
#    'DOI': '10.17138/tgft(2)100-102',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2015, 4, 1]],
#     'date-time': '2015-04-01T20:32:16Z',
#     'timestamp': 1427920336000},
#    'page': '100',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Production of giant Panicum in semi-arid Kenya'],
#    'prefix': '10.17138',
#    'volume': '2',
#    'author': [{'given': 'Donald M.G.',
#      'family': 'Njarui',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'Mwangi',
#      'family': 'Gatheru',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'David M.',
#      'family': 'Mwangi',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'George A.',
#      'family': 'Keya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '6578',
#    'published-online': {'date-parts': [[2014]]},
#    'container-title': ['Tropical Grasslands - Forrajes Tropicales'],
#    'language': 'en',
#    'deposited': {'date-parts': [[2015, 4, 1]],
#     'date-time': '2015-04-01T20:32:45Z',
#     'timestamp': 1427920365000},
#    'score': 13.5145,
#    'issued': {'date-parts': [[2014]]},
#    'references-count': 0,
#    'journal-issue': {'published-online': {'date-parts': [[2014]]},
#     'issue': '1'},
#    'alternative-id': ['136/84'],
#    'URL': 'http://dx.doi.org/10.17138/tgft(2)100-102',
#    'ISSN': ['2346-3775'],
#    'issn-type': [{'value': '2346-3775', 'type': 'electronic'}]},
#   {'indexed': {'date-parts': [[2019, 11, 23]],
#     'date-time': '2019-11-23T20:37:06Z',
#     'timestamp': 1574541426012},
#    'publisher-location': 'Nairobi :',
#    'reference-count': 0,
#    'publisher': 'Nature Kenya, East Africa Natural History Society,',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[1999]]},
#    'DOI': '10.5962/bhl.title.87589',
#    'type': 'monograph',
#    'created': {'date-parts': [[2014, 8, 24]],
#     'date-time': '2014-08-24T06:00:31Z',
#     'timestamp': 1408860031000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 74,
#    'title': ['Important bird areas in Kenya /'],
#    'prefix': '10.5962',
#    'author': [{'given': 'Leon A.',
#      'family': 'Bennun',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'Peter.',
#      'family': 'Njoroge',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'National Museums of Kenya.',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Nature Kenya.', 'sequence': 'additional', 'affiliation': []}],
#    'member': '3444',
#    'deposited': {'date-parts': [[2014, 8, 24]],
#     'date-time': '2014-08-24T06:00:31Z',
#     'timestamp': 1408860031000},
#    'score': 13.457988,
#    'issued': {'date-parts': [[1999]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.5962/bhl.title.87589'},
#   {'indexed': {'date-parts': [[2020, 3, 24]],
#     'date-time': '2020-03-24T22:28:20Z',
#     'timestamp': 1585088900467},
#    'publisher-location': 'Berlin, Boston',
#    'reference-count': 0,
#    'publisher': 'De Gruyter',
#    'isbn-type': [{'value': '9783110826050', 'type': 'electronic'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[1972, 12, 31]]},
#    'DOI': '10.1515/9783110826050-068',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2019, 2, 25]],
#     'date-time': '2019-02-25T09:01:06Z',
#     'timestamp': 1551085266000},
#    'page': '304-305',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya. Jamhuri ya Kenya; Republic of Kenya'],
#    'prefix': '10.1515',
#    'member': '374',
#    'container-title': ['Minerva. Internationales Verzeichnis Wissenschaftlicher Institutionen'],
#    'link': [{'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#      'content-type': 'text/html',
#      'content-version': 'vor',
#      'intended-application': 'text-mining'},
#     {'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#      'content-type': 'unspecified',
#      'content-version': 'vor',
#      'intended-application': 'similarity-checking'}],
#    'deposited': {'date-parts': [[2019, 2, 25]],
#     'date-time': '2019-02-25T09:11:29Z',
#     'timestamp': 1551085889000},
#    'score': 13.457988,
#    'editor': [{'given': 'Werner',
#      'family': 'Schuder',
#      'sequence': 'first',
#      'affiliation': []}],
#    'issued': {'date-parts': [[1972, 12, 31]]},
#    'ISBN': ['9783110826050'],
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1515/9783110826050-068'},
#   {'indexed': {'date-parts': [[2020, 3, 30]],
#     'date-time': '2020-03-30T03:56:21Z',
#     'timestamp': 1585540581107},
#    'reference-count': 0,
#    'publisher': 'International Journal Of Advanced Research',
#    'issue': '2',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['IJAR'],
#    'DOI': '10.21474/ijar01/6544',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2018, 3, 30]],
#     'date-time': '2018-03-30T10:49:35Z',
#     'timestamp': 1522406975000},
#    'page': '1195-1203',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['SOCIAL DETERMINANTS INFLUENCING TRANSITION RATE OF GIRLS FROM PRIMARY EDUCATION TO SECONDARY EDUCATION IN KOIBATEK SUB-COUNTY, KENYA.'],
#    'prefix': '10.21474',
#    'volume': '6',
#    'author': [{'given': 'GladysJerono',
#      'family': 'Koech',
#      'sequence': 'first',
#      'affiliation': []},
#     {'name': 'Mount Kenya University, Kenya',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'JoshuaOdhiambo',
#      'family': 'Ogal',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'Rachael',
#      'family': 'Koros',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Mount Kenya University, Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Mount Kenya University, Kenya',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '8913',
#    'published-online': {'date-parts': [[2018, 2, 28]]},
#    'container-title': ['International Journal of Advanced Research'],
#    'deposited': {'date-parts': [[2018, 3, 30]],
#     'date-time': '2018-03-30T10:49:35Z',
#     'timestamp': 1522406975000},
#    'score': 13.454593,
#    'issued': {'date-parts': [[2018, 2, 28]]},
#    'references-count': 0,
#    'journal-issue': {'published-online': {'date-parts': [[2018, 2, 28]]},
#     'issue': '2'},
#    'URL': 'http://dx.doi.org/10.21474/ijar01/6544',
#    'ISSN': ['2320-5407'],
#    'issn-type': [{'value': '2320-5407', 'type': 'electronic'}]},
#   {'indexed': {'date-parts': [[2020, 3, 24]],
#     'date-time': '2020-03-24T04:53:29Z',
#     'timestamp': 1585025609025},
#    'reference-count': 0,
#    'publisher': 'Commonwealth Secretariat',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[1987, 12, 1]]},
#    'DOI': '10.14217/9781848594371-12-en',
#    'type': 'component',
#    'created': {'date-parts': [[2016, 1, 29]],
#     'date-time': '2016-01-29T06:18:13Z',
#     'timestamp': 1454048293000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya: Kenya Law Reform Commission'],
#    'prefix': '10.14217',
#    'author': [{'name': 'Commonwealth Secretariat',
#      'sequence': 'first',
#      'affiliation': []}],
#    'member': '5318',
#    'deposited': {'date-parts': [[2018, 10, 7]],
#     'date-time': '2018-10-07T08:05:04Z',
#     'timestamp': 1538899504000},
#    'score': 13.444708,
#    'issued': {'date-parts': [[1987, 12, 1]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.14217/9781848594371-12-en'},
#   {'indexed': {'date-parts': [[2020, 3, 24]],
#     'date-time': '2020-03-24T04:53:11Z',
#     'timestamp': 1585025591207},
#    'reference-count': 0,
#    'publisher': 'Commonwealth Secretariat',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[1992, 1, 1]]},
#    'DOI': '10.14217/9781848594920-13-en',
#    'type': 'component',
#    'created': {'date-parts': [[2016, 1, 29]],
#     'date-time': '2016-01-29T06:18:13Z',
#     'timestamp': 1454048293000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 1,
#    'title': ['Kenya: Kenya Law Reform Commission'],
#    'prefix': '10.14217',
#    'author': [{'name': 'Commonwealth Secretariat',
#      'sequence': 'first',
#      'affiliation': []}],
#    'member': '5318',
#    'deposited': {'date-parts': [[2018, 10, 8]],
#     'date-time': '2018-10-08T07:55:20Z',
#     'timestamp': 1538985320000},
#    'score': 13.444708,
#    'issued': {'date-parts': [[1992, 1, 1]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.14217/9781848594920-13-en'},
#   {'indexed': {'date-parts': [[2019, 12, 2]],
#     'date-time': '2019-12-02T18:07:57Z',
#     'timestamp': 1575310077028},
#    'reference-count': 0,
#    'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1787/124030037050',
#    'type': 'component',
#    'created': {'date-parts': [[2008, 9, 30]],
#     'date-time': '2008-09-30T12:02:13Z',
#     'timestamp': 1222776133000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya'],
#    'prefix': '10.1787',
#    'member': '1963',
#    'deposited': {'date-parts': [[2014, 5, 27]],
#     'date-time': '2014-05-27T17:04:56Z',
#     'timestamp': 1401210296000},
#    'score': 13.026722,
#    'issued': {'date-parts': [[None]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1787/124030037050'},
#   {'indexed': {'date-parts': [[2019, 12, 2]],
#     'date-time': '2019-12-02T18:07:57Z',
#     'timestamp': 1575310077572},
#    'reference-count': 0,
#    'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1787/270604575355',
#    'type': 'component',
#    'created': {'date-parts': [[2008, 9, 30]],
#     'date-time': '2008-09-30T12:02:13Z',
#     'timestamp': 1222776133000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya'],
#    'prefix': '10.1787',
#    'member': '1963',
#    'deposited': {'date-parts': [[2014, 5, 27]],
#     'date-time': '2014-05-27T17:04:57Z',
#     'timestamp': 1401210297000},
#    'score': 13.026722,
#    'issued': {'date-parts': [[None]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1787/270604575355'},
#   {'indexed': {'date-parts': [[2020, 3, 30]],
#     'date-time': '2020-03-30T05:34:42Z',
#     'timestamp': 1585546482946},
#    'reference-count': 0,
#    'publisher': 'Schweizerbart',
#    'issue': '2',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['phyto'],
#    'published-print': {'date-parts': [[1989, 5, 2]]},
#    'DOI': '10.1127/phyto/17/1989/287',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2014, 1, 29]],
#     'date-time': '2014-01-29T05:09:25Z',
#     'timestamp': 1390972165000},
#    'page': '287-288',
#    'source': 'Crossref',
#    'is-referenced-by-count': 1,
#    'title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#    'prefix': '10.1127',
#    'volume': '17',
#    'author': [{'given': 'H.',
#      'family': 'Rehder',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'E.',
#      'family': 'Beck',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'J. O.',
#      'family': 'Kokwaro',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '181',
#    'container-title': ['Phytocoenologia'],
#    'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#    'language': 'en',
#    'deposited': {'date-parts': [[2017, 4, 11]],
#     'date-time': '2017-04-11T05:00:28Z',
#     'timestamp': 1491886828000},
#    'score': 12.975961,
#    'issued': {'date-parts': [[1989, 5, 2]]},
#    'references-count': 0,
#    'journal-issue': {'published-print': {'date-parts': [[1989, 5, 2]]},
#     'issue': '2'},
#    'URL': 'http://dx.doi.org/10.1127/phyto/17/1989/287',
#    'ISSN': ['0340-269X'],
#    'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#   {'indexed': {'date-parts': [[2020, 3, 24]],
#     'date-time': '2020-03-24T19:41:32Z',
#     'timestamp': 1585078892966},
#    'reference-count': 0,
#    'publisher': 'African Journal of Food, Agriculture, Nutrition and Development',
#    'issue': '01',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['AJFAND'],
#    'DOI': '10.18697/ajfand.84.blfb1017',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2019, 2, 2]],
#     'date-time': '2019-02-02T09:05:42Z',
#     'timestamp': 1549098342000},
#    'page': '14010-14042',
#    'source': 'Crossref',
#    'is-referenced-by-count': 15,
#    'title': ['Climate Change Effects on Crop Production in Kenya: Farmer Perceptions and Adaptation Strategies'],
#    'prefix': '10.18697',
#    'volume': '19',
#    'author': [{'given': 'Beverly',
#      'family': 'Agesa',
#      'sequence': 'first',
#      'affiliation': []},
#     {'name': 'University  of Nairobi, Nairobi, Kenya',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'CM',
#      'family': 'Onyango',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'VM',
#      'family': 'Kathumo',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'RN',
#      'family': 'Onwonga',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'GN',
#      'family': 'Karuku',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'University  of  Nairobi, Nairobi, Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'University  of  Nairobi,  Nairobi, Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'University  of Nairobi, Nairobi, Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Univesity of Nairobi, Nairobi, Kenya',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '8080',
#    'published-online': {'date-parts': [[2019, 2, 1]]},
#    'container-title': ['African Journal of Food, Agriculture, Nutrition and Development'],
#    'link': [{'URL': 'https://www.ajfand.net/Volume19/No1/BLFB1017.pdf',
#      'content-type': 'unspecified',
#      'content-version': 'vor',
#      'intended-application': 'similarity-checking'}],
#    'deposited': {'date-parts': [[2019, 2, 2]],
#     'date-time': '2019-02-02T09:05:44Z',
#     'timestamp': 1549098344000},
#    'score': 12.975961,
#    'issued': {'date-parts': [[2019, 2, 1]]},
#    'references-count': 0,
#    'journal-issue': {'published-online': {'date-parts': [[2019, 2, 1]]},
#     'issue': '01'},
#    'URL': 'http://dx.doi.org/10.18697/ajfand.84.blfb1017',
#    'ISSN': ['1684-5374'],
#    'issn-type': [{'value': '1684-5374', 'type': 'electronic'}]},
#   {'indexed': {'date-parts': [[2020, 3, 30]],
#     'date-time': '2020-03-30T05:34:42Z',
#     'timestamp': 1585546482746},
#    'reference-count': 0,
#    'publisher': 'Schweizerbart',
#    'issue': '4',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['phyto'],
#    'published-print': {'date-parts': [[1988, 12, 7]]},
#    'DOI': '10.1127/phyto/16/1988/433',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2014, 1, 29]],
#     'date-time': '2014-01-29T10:09:25Z',
#     'timestamp': 1390990165000},
#    'page': '433-463',
#    'source': 'Crossref',
#    'is-referenced-by-count': 9,
#    'title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#    'prefix': '10.1127',
#    'volume': '16',
#    'author': [{'given': 'H.',
#      'family': 'Rehder',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'E.',
#      'family': 'Beck',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'J. O.',
#      'family': 'Kokwaro',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '181',
#    'container-title': ['Phytocoenologia'],
#    'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#    'language': 'en',
#    'deposited': {'date-parts': [[2017, 4, 11]],
#     'date-time': '2017-04-11T10:26:22Z',
#     'timestamp': 1491906382000},
#    'score': 12.843469,
#    'issued': {'date-parts': [[1988, 12, 7]]},
#    'references-count': 0,
#    'journal-issue': {'published-print': {'date-parts': [[1988, 12, 7]]},
#     'issue': '4'},
#    'URL': 'http://dx.doi.org/10.1127/phyto/16/1988/433',
#    'ISSN': ['0340-269X'],
#    'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#   {'indexed': {'date-parts': [[2020, 3, 30]],
#     'date-time': '2020-03-30T05:35:03Z',
#     'timestamp': 1585546503509},
#    'reference-count': 0,
#    'publisher': 'Schweizerbart',
#    'issue': '4',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['phyto'],
#    'published-print': {'date-parts': [[1995, 12, 14]]},
#    'DOI': '10.1127/phyto/25/1995/467',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2014, 1, 29]],
#     'date-time': '2014-01-29T11:02:59Z',
#     'timestamp': 1390993379000},
#    'page': '467-560',
#    'source': 'Crossref',
#    'is-referenced-by-count': 9,
#    'title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#    'prefix': '10.1127',
#    'volume': '25',
#    'author': [{'given': 'Rainer W.',
#      'family': 'Bussmann',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'Erwin',
#      'family': 'Beck',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '181',
#    'container-title': ['Phytocoenologia'],
#    'original-title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#    'language': 'en',
#    'deposited': {'date-parts': [[2017, 4, 11]],
#     'date-time': '2017-04-11T09:04:27Z',
#     'timestamp': 1491901467000},
#    'score': 12.843469,
#    'issued': {'date-parts': [[1995, 12, 14]]},
#    'references-count': 0,
#    'journal-issue': {'published-print': {'date-parts': [[1995, 12, 14]]},
#     'issue': '4'},
#    'URL': 'http://dx.doi.org/10.1127/phyto/25/1995/467',
#    'ISSN': ['0340-269X'],
#    'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#   {'indexed': {'date-parts': [[2020, 3, 26]],
#     'date-time': '2020-03-26T05:06:29Z',
#     'timestamp': 1585199189664},
#    'reference-count': 0,
#    'publisher': 'Manchester University Press',
#    'isbn-type': [{'value': '9781526105813', 'type': 'print'},
#     {'value': '9781526135988', 'type': 'electronic'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[2019, 3, 1]]},
#    'abstract': '<p>Since the 1998 bombing of the US Embassy in Nairobi, the Government of Kenya’s response to terrorism has been multifaceted. Government efforts have primarily relied on civil authorities and the military, thus privileging the use of force over subtler means. The Kenyan Police have employed measures such as profiling, detention, and prosecution. The Kenyan military has conducted operations in Kenya and Somalia. These strategies have contributed to the apprehension of some terrorist suspects and checked Shabaab’s advance in Somalia. Yet, Kenya’s counterterrorism efforts have been hampered by limited coordination among agencies, the use of heavy-handed tactics, and insufficient engagement with civil society organizations. Two defining features of Kenyan counterterrorism efforts have emerged. First, counterterrorism in Kenya has clear sociocultural dimensions. Security forces have responded to the threat of terrorism by focusing intently on Kenya’s alienated Muslim communities both in the Somali-majority north and at the Swahili-speaking coast. As a result, the Government of Kenya’s response to terrorism reflects communal divisions and animosity within Kenyan society that precede contemporary counterterrorism. Second, Kenya’s invasion of neighboring Somalia created and blurred two fronts: one within Kenya and the other in southern Somalia. The actions of Kenyan policy-makers and al Shabaab therefore contributed to a more complete integration of the conflict in Somalia and internal tensions in Kenya..</p>',
#    'DOI': '10.7228/manchester/9781526105813.003.0016',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2019, 5, 23]],
#     'date-time': '2019-05-23T09:38:00Z',
#     'timestamp': 1558604280000},
#    'page': '386-409',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#    'prefix': '10.7228',
#    'author': [{'given': 'Jeremy',
#      'family': 'Prestholdt',
#      'sequence': 'first',
#      'affiliation': []}],
#    'member': '4230',
#    'published-online': {'date-parts': [[2019, 5, 23]]},
#    'container-title': ['Non-Western responses to terrorism'],
#    'original-title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#    'deposited': {'date-parts': [[2019, 5, 23]],
#     'date-time': '2019-05-23T09:38:00Z',
#     'timestamp': 1558604280000},
#    'score': 12.843469,
#    'issued': {'date-parts': [[2019, 3, 1]]},
#    'ISBN': ['9781526105813', '9781526135988'],
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.7228/manchester/9781526105813.003.0016'},
#   {'indexed': {'date-parts': [[2019, 12, 4]],
#     'date-time': '2019-12-04T05:53:32Z',
#     'timestamp': 1575438812997},
#    'publisher-location': 'London',
#    'reference-count': 0,
#    'publisher': 'Palgrave Macmillan UK',
#    'isbn-type': [{'value': '9781349958382', 'type': 'print'},
#     {'value': '9781349958399', 'type': 'electronic'}],
#    'license': [{'URL': 'http://www.springer.com/tdm',
#      'start': {'date-parts': [[2019, 1, 1]],
#       'date-time': '2019-01-01T00:00:00Z',
#       'timestamp': 1546300800000},
#      'delay-in-days': 0,
#      'content-version': 'tdm'}],
#    'content-domain': {'domain': ['link.springer.com'],
#     'crossmark-restriction': False},
#    'published-print': {'date-parts': [[2019]]},
#    'DOI': '10.1057/978-1-349-95839-9_1403',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2019, 4, 17]],
#     'date-time': '2019-04-17T10:48:42Z',
#     'timestamp': 1555498122000},
#    'page': '714-715',
#    'update-policy': 'http://dx.doi.org/10.1007/springer_crossmark_policy',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya'],
#    'prefix': '10.1057',
#    'member': '297',
#    'published-online': {'date-parts': [[2019, 4, 2]]},
#    'container-title': ['The Statesman’s Yearbook Companion'],
#    'link': [{'URL': 'http://link.springer.com/content/pdf/10.1057/978-1-349-95839-9_1403',
#      'content-type': 'unspecified',
#      'content-version': 'vor',
#      'intended-application': 'similarity-checking'}],
#    'deposited': {'date-parts': [[2019, 4, 17]],
#     'date-time': '2019-04-17T10:57:59Z',
#     'timestamp': 1555498679000},
#    'score': 12.79614,
#    'subtitle': ['Jamhuri ya Kenya (Republic of Kenya)'],
#    'issued': {'date-parts': [[2019]]},
#    'ISBN': ['9781349958382', '9781349958399'],
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1057/978-1-349-95839-9_1403',
#    'assertion': [{'value': '2 April 2019',
#      'order': 1,
#      'name': 'first_online',
#      'label': 'First Online',
#      'group': {'name': 'ChapterHistory', 'label': 'Chapter History'}}]},
#   {'indexed': {'date-parts': [[2020, 3, 25]],
#     'date-time': '2020-03-25T20:58:24Z',
#     'timestamp': 1585169904857},
#    'reference-count': 0,
#    'publisher': 'Bloomsbury Publishing',
#    'isbn-type': [{'value': '9781408122549', 'type': 'print'},
#     {'value': '9781408189931', 'type': 'electronic'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.5040/9781472926944.0150',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2016, 6, 24]],
#     'date-time': '2016-06-24T17:27:36Z',
#     'timestamp': 1466789256000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Surdisorex polulus Mount Kenya Mole-shrew : Fr. Musaraigne du Mont Kenya; Ger. Mount Kenya Wühlspitzmaus'],
#    'prefix': '10.5040',
#    'member': '2984',
#    'container-title': ['Mammals of Africa : Hedgehogs, Shrews and Bats'],
#    'deposited': {'date-parts': [[2016, 7, 4]],
#     'date-time': '2016-07-04T13:54:23Z',
#     'timestamp': 1467640463000},
#    'score': 12.79614,
#    'issued': {'date-parts': [[None]]},
#    'ISBN': ['9781472926944', '9781408189931', '9781408122549'],
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.5040/9781472926944.0150'},
#   {'indexed': {'date-parts': [[2020, 3, 25]],
#     'date-time': '2020-03-25T19:00:30Z',
#     'timestamp': 1585162830294},
#    'reference-count': 0,
#    'publisher': 'Kenya Meteorological Society',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': ['J. Meteorol. Related. Sci'],
#    'published-print': {'date-parts': [[2007, 9, 19]]},
#    'DOI': '10.20987/jmrs.08.2012.603',
#    'type': 'journal-article',
#    'created': {'date-parts': [[2016, 5, 31]],
#     'date-time': '2016-05-31T07:04:14Z',
#     'timestamp': 1464678254000},
#    'page': '26-35',
#    'source': 'Crossref',
#    'is-referenced-by-count': 2,
#    'title': ['Use of Aquacrop Model to Predict Maize Yields under varying Rainfall and Temperature in a Semi-Arid Environment in Kenya'],
#    'prefix': '10.20987',
#    'volume': '6',
#    'author': [{'given': 'Joab',
#      'family': 'Wamari',
#      'sequence': 'first',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#      'sequence': 'first',
#      'affiliation': []},
#     {'given': 'Sijali',
#      'family': 'Isaya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'Lee',
#      'family': 'Kheng',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'Joseph',
#      'family': 'Miriti',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'given': 'Esilaba',
#      'family': 'Obutiati',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Soil and Water management and Crop Nutrition Section',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'National Agricultural Research Centre -Kenya',
#      'sequence': 'additional',
#      'affiliation': []},
#     {'name': 'Kenya Agricultural Research institute',
#      'sequence': 'additional',
#      'affiliation': []}],
#    'member': '8610',
#    'container-title': ['Journal of Meteorology and Related Sciences'],
#    'deposited': {'date-parts': [[2017, 7, 26]],
#     'date-time': '2017-07-26T21:59:54Z',
#     'timestamp': 1501106394000},
#    'score': 12.722612,
#    'issued': {'date-parts': [[2007, 9, 19]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.20987/jmrs.08.2012.603',
#    'ISSN': ['1995-9834', '2412-3781'],
#    'issn-type': [{'value': '1995-9834', 'type': 'print'},
#     {'value': '2412-3781', 'type': 'electronic'}]},
#   {'institution': {'name': 'Koninklijke Brill NV',
#     'place': ['-'],
#     'acronym': ['BRILL']},
#    'indexed': {'date-parts': [[2019, 11, 23]],
#     'date-time': '2019-11-23T19:38:50Z',
#     'timestamp': 1574537930164},
#    'reference-count': 0,
#    'publisher': 'Brill',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1163/_afco_asc_3100',
#    'type': 'dataset',
#    'created': {'date-parts': [[2014, 8, 8]],
#     'date-time': '2014-08-08T12:35:44Z',
#     'timestamp': 1407501344000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya International Film Festival (Nairobi et al., Kenya)'],
#    'prefix': '10.1163',
#    'member': '50',
#    'container-title': ['African Studies Companion Online'],
#    'deposited': {'date-parts': [[2018, 11, 21]],
#     'date-time': '2018-11-21T06:03:11Z',
#     'timestamp': 1542780191000},
#    'score': 12.69376,
#    'issued': {'date-parts': [[None]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1163/_afco_asc_3100'},
#   {'institution': {'name': 'Koninklijke Brill NV',
#     'place': ['-'],
#     'acronym': ['BRILL']},
#    'indexed': {'date-parts': [[2019, 11, 23]],
#     'date-time': '2019-11-23T19:38:11Z',
#     'timestamp': 1574537891045},
#    'reference-count': 0,
#    'publisher': 'Brill',
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1163/1872-9037_afco_asc_3100',
#    'type': 'dataset',
#    'created': {'date-parts': [[2014, 8, 8]],
#     'date-time': '2014-08-08T12:35:44Z',
#     'timestamp': 1407501344000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Kenya International Film Festival (Nairobi et al., Kenya)'],
#    'prefix': '10.1163',
#    'member': '50',
#    'container-title': ['African Studies Companion Online'],
#    'deposited': {'date-parts': [[2018, 11, 21]],
#     'date-time': '2018-11-21T06:03:09Z',
#     'timestamp': 1542780189000},
#    'score': 12.69376,
#    'issued': {'date-parts': [[None]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1163/1872-9037_afco_asc_3100'},
#   {'indexed': {'date-parts': [[2019, 11, 25]],
#     'date-time': '2019-11-25T18:49:56Z',
#     'timestamp': 1574707796806},
#    'reference-count': 0,
#    'publisher': 'Palgrave Macmillan',
#    'isbn-type': [{'value': '9781137440532', 'type': 'print'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'DOI': '10.1057/9781137440532.0010',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2015, 6, 30]],
#     'date-time': '2015-06-30T13:16:24Z',
#     'timestamp': 1435670184000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Indian Private Doctors in Kenya'],
#    'prefix': '10.1057',
#    'member': '297',
#    'container-title': ['Indian Doctors in Kenya, 1895-1940'],
#    'deposited': {'date-parts': [[2015, 6, 30]],
#     'date-time': '2015-06-30T13:37:59Z',
#     'timestamp': 1435671479000},
#    'score': 12.69376,
#    'issued': {'date-parts': [[None]]},
#    'ISBN': ['9781137440532'],
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.1057/9781137440532.0010'},
#   {'indexed': {'date-parts': [[2019, 11, 24]],
#     'date-time': '2019-11-24T08:14:12Z',
#     'timestamp': 1574583252861},
#    'publisher-location': 'UK and Ireland',
#    'reference-count': 0,
#    'publisher': 'Oxfam Publishing',
#    'isbn-type': [{'value': '9780855983826', 'type': 'print'},
#     {'value': '9780855987800', 'type': 'electronic'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'published-print': {'date-parts': [[1998, 1]]},
#    'DOI': '10.3362/9780855987800.000',
#    'type': 'book-chapter',
#    'created': {'date-parts': [[2015, 2, 19]],
#     'date-time': '2015-02-19T02:07:57Z',
#     'timestamp': 1424311677000},
#    'page': '1-3',
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Prelims - Kenya'],
#    'prefix': '10.3362',
#    'author': [{'given': 'Geoff',
#      'family': 'Sayer',
#      'sequence': 'first',
#      'affiliation': []}],
#    'member': '1928',
#    'published-online': {'date-parts': [[2015, 2, 18]]},
#    'container-title': ['Kenya'],
#    'deposited': {'date-parts': [[2018, 8, 9]],
#     'date-time': '2018-08-09T20:31:31Z',
#     'timestamp': 1533846691000},
#    'score': 12.69376,
#    'issued': {'date-parts': [[1998, 1]]},
#    'ISBN': ['9780855983826', '9780855987800'],
#    'references-count': 0,
#    'alternative-id': ['10.3362/9780855987800.000', '10.3362/9780855987800'],
#    'URL': 'http://dx.doi.org/10.3362/9780855987800.000'}],
#  'items-per-page': 20,
#  'query': {'start-index': 0, 'search-terms': 'kenya'}}

# %% [markdown]
# This dictionary is nested, meaning that we can have keys that lead to values which are more dictionaries. It seems like the `message` contains most of the information we're interested in. Below, take a look at the keys of the `message` component of the `kenya` dictionary.

# %%
list(kenya['message'].keys()) # keys of the kenya message dictionary
# Out:
# ['facets', 'total-results', 'items', 'items-per-page', 'query']

# %% [markdown]
# Just as we did before, we can inspect what information is contained for each key of the dictionary.

# %%
kenya['message']['facets'] # there are no facets; it's an empty set
# Out:
# {}

# %%
# This tells us the total number of results from our query
kenya['message']['total-results']
# Out:
# 42232

# %%
kenya['message']['items-per-page'] # tells us how many items per page
# Out:
# 20

# %%
kenya['message']['query'] # details about our query
# Out:
# {'start-index': 0, 'search-terms': 'kenya'}

# %%
kenya['message']['items'] # the items of our query
# Out:
# [{'indexed': {'date-parts': [[2019, 11, 24]],
#    'date-time': '2019-11-24T10:48:27Z',
#    'timestamp': 1574592507823},
#   'reference-count': 0,
#   'publisher': 'Centro Internacional de Agricultura Tropical',
#   'issue': '1',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['Trop Grass - Forr Trop'],
#   'DOI': '10.17138/tgft(2)100-102',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2015, 4, 1]],
#    'date-time': '2015-04-01T20:32:16Z',
#    'timestamp': 1427920336000},
#   'page': '100',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Production of giant Panicum in semi-arid Kenya'],
#   'prefix': '10.17138',
#   'volume': '2',
#   'author': [{'given': 'Donald M.G.',
#     'family': 'Njarui',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Mwangi',
#     'family': 'Gatheru',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'David M.',
#     'family': 'Mwangi',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'George A.',
#     'family': 'Keya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Institute (KARI), Katumani Research Centre, Machakos, Kenya. www.kari.org/KARI_katumani',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Institute (KARI), Headquarters, Nairobi, Kenya. www.kari.org',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '6578',
#   'published-online': {'date-parts': [[2014]]},
#   'container-title': ['Tropical Grasslands - Forrajes Tropicales'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2015, 4, 1]],
#    'date-time': '2015-04-01T20:32:45Z',
#    'timestamp': 1427920365000},
#   'score': 13.5145,
#   'issued': {'date-parts': [[2014]]},
#   'references-count': 0,
#   'journal-issue': {'published-online': {'date-parts': [[2014]]},
#    'issue': '1'},
#   'alternative-id': ['136/84'],
#   'URL': 'http://dx.doi.org/10.17138/tgft(2)100-102',
#   'ISSN': ['2346-3775'],
#   'issn-type': [{'value': '2346-3775', 'type': 'electronic'}]},
#  {'indexed': {'date-parts': [[2019, 11, 23]],
#    'date-time': '2019-11-23T20:37:06Z',
#    'timestamp': 1574541426012},
#   'publisher-location': 'Nairobi :',
#   'reference-count': 0,
#   'publisher': 'Nature Kenya, East Africa Natural History Society,',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[1999]]},
#   'DOI': '10.5962/bhl.title.87589',
#   'type': 'monograph',
#   'created': {'date-parts': [[2014, 8, 24]],
#    'date-time': '2014-08-24T06:00:31Z',
#    'timestamp': 1408860031000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 74,
#   'title': ['Important bird areas in Kenya /'],
#   'prefix': '10.5962',
#   'author': [{'given': 'Leon A.',
#     'family': 'Bennun',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Peter.',
#     'family': 'Njoroge',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'National Museums of Kenya.',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Nature Kenya.', 'sequence': 'additional', 'affiliation': []}],
#   'member': '3444',
#   'deposited': {'date-parts': [[2014, 8, 24]],
#    'date-time': '2014-08-24T06:00:31Z',
#    'timestamp': 1408860031000},
#   'score': 13.457988,
#   'issued': {'date-parts': [[1999]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.5962/bhl.title.87589'},
#  {'indexed': {'date-parts': [[2020, 3, 24]],
#    'date-time': '2020-03-24T22:28:20Z',
#    'timestamp': 1585088900467},
#   'publisher-location': 'Berlin, Boston',
#   'reference-count': 0,
#   'publisher': 'De Gruyter',
#   'isbn-type': [{'value': '9783110826050', 'type': 'electronic'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[1972, 12, 31]]},
#   'DOI': '10.1515/9783110826050-068',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2019, 2, 25]],
#    'date-time': '2019-02-25T09:01:06Z',
#    'timestamp': 1551085266000},
#   'page': '304-305',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya. Jamhuri ya Kenya; Republic of Kenya'],
#   'prefix': '10.1515',
#   'member': '374',
#   'container-title': ['Minerva. Internationales Verzeichnis Wissenschaftlicher Institutionen'],
#   'link': [{'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#     'content-type': 'text/html',
#     'content-version': 'vor',
#     'intended-application': 'text-mining'},
#    {'URL': 'http://www.degruyter.com/view/books/9783110826050/9783110826050-068/9783110826050-068.xml',
#     'content-type': 'unspecified',
#     'content-version': 'vor',
#     'intended-application': 'similarity-checking'}],
#   'deposited': {'date-parts': [[2019, 2, 25]],
#    'date-time': '2019-02-25T09:11:29Z',
#    'timestamp': 1551085889000},
#   'score': 13.457988,
#   'editor': [{'given': 'Werner',
#     'family': 'Schuder',
#     'sequence': 'first',
#     'affiliation': []}],
#   'issued': {'date-parts': [[1972, 12, 31]]},
#   'ISBN': ['9783110826050'],
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1515/9783110826050-068'},
#  {'indexed': {'date-parts': [[2020, 3, 30]],
#    'date-time': '2020-03-30T03:56:21Z',
#    'timestamp': 1585540581107},
#   'reference-count': 0,
#   'publisher': 'International Journal Of Advanced Research',
#   'issue': '2',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['IJAR'],
#   'DOI': '10.21474/ijar01/6544',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2018, 3, 30]],
#    'date-time': '2018-03-30T10:49:35Z',
#    'timestamp': 1522406975000},
#   'page': '1195-1203',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['SOCIAL DETERMINANTS INFLUENCING TRANSITION RATE OF GIRLS FROM PRIMARY EDUCATION TO SECONDARY EDUCATION IN KOIBATEK SUB-COUNTY, KENYA.'],
#   'prefix': '10.21474',
#   'volume': '6',
#   'author': [{'given': 'GladysJerono',
#     'family': 'Koech',
#     'sequence': 'first',
#     'affiliation': []},
#    {'name': 'Mount Kenya University, Kenya',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'JoshuaOdhiambo',
#     'family': 'Ogal',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Rachael',
#     'family': 'Koros',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Mount Kenya University, Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Mount Kenya University, Kenya',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '8913',
#   'published-online': {'date-parts': [[2018, 2, 28]]},
#   'container-title': ['International Journal of Advanced Research'],
#   'deposited': {'date-parts': [[2018, 3, 30]],
#    'date-time': '2018-03-30T10:49:35Z',
#    'timestamp': 1522406975000},
#   'score': 13.454593,
#   'issued': {'date-parts': [[2018, 2, 28]]},
#   'references-count': 0,
#   'journal-issue': {'published-online': {'date-parts': [[2018, 2, 28]]},
#    'issue': '2'},
#   'URL': 'http://dx.doi.org/10.21474/ijar01/6544',
#   'ISSN': ['2320-5407'],
#   'issn-type': [{'value': '2320-5407', 'type': 'electronic'}]},
#  {'indexed': {'date-parts': [[2020, 3, 24]],
#    'date-time': '2020-03-24T04:53:29Z',
#    'timestamp': 1585025609025},
#   'reference-count': 0,
#   'publisher': 'Commonwealth Secretariat',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[1987, 12, 1]]},
#   'DOI': '10.14217/9781848594371-12-en',
#   'type': 'component',
#   'created': {'date-parts': [[2016, 1, 29]],
#    'date-time': '2016-01-29T06:18:13Z',
#    'timestamp': 1454048293000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya: Kenya Law Reform Commission'],
#   'prefix': '10.14217',
#   'author': [{'name': 'Commonwealth Secretariat',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '5318',
#   'deposited': {'date-parts': [[2018, 10, 7]],
#    'date-time': '2018-10-07T08:05:04Z',
#    'timestamp': 1538899504000},
#   'score': 13.444708,
#   'issued': {'date-parts': [[1987, 12, 1]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.14217/9781848594371-12-en'},
#  {'indexed': {'date-parts': [[2020, 3, 24]],
#    'date-time': '2020-03-24T04:53:11Z',
#    'timestamp': 1585025591207},
#   'reference-count': 0,
#   'publisher': 'Commonwealth Secretariat',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[1992, 1, 1]]},
#   'DOI': '10.14217/9781848594920-13-en',
#   'type': 'component',
#   'created': {'date-parts': [[2016, 1, 29]],
#    'date-time': '2016-01-29T06:18:13Z',
#    'timestamp': 1454048293000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['Kenya: Kenya Law Reform Commission'],
#   'prefix': '10.14217',
#   'author': [{'name': 'Commonwealth Secretariat',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '5318',
#   'deposited': {'date-parts': [[2018, 10, 8]],
#    'date-time': '2018-10-08T07:55:20Z',
#    'timestamp': 1538985320000},
#   'score': 13.444708,
#   'issued': {'date-parts': [[1992, 1, 1]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.14217/9781848594920-13-en'},
#  {'indexed': {'date-parts': [[2019, 12, 2]],
#    'date-time': '2019-12-02T18:07:57Z',
#    'timestamp': 1575310077028},
#   'reference-count': 0,
#   'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1787/124030037050',
#   'type': 'component',
#   'created': {'date-parts': [[2008, 9, 30]],
#    'date-time': '2008-09-30T12:02:13Z',
#    'timestamp': 1222776133000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya'],
#   'prefix': '10.1787',
#   'member': '1963',
#   'deposited': {'date-parts': [[2014, 5, 27]],
#    'date-time': '2014-05-27T17:04:56Z',
#    'timestamp': 1401210296000},
#   'score': 13.026722,
#   'issued': {'date-parts': [[None]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1787/124030037050'},
#  {'indexed': {'date-parts': [[2019, 12, 2]],
#    'date-time': '2019-12-02T18:07:57Z',
#    'timestamp': 1575310077572},
#   'reference-count': 0,
#   'publisher': 'Organisation for Economic Co-Operation and Development  (OECD)',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1787/270604575355',
#   'type': 'component',
#   'created': {'date-parts': [[2008, 9, 30]],
#    'date-time': '2008-09-30T12:02:13Z',
#    'timestamp': 1222776133000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya'],
#   'prefix': '10.1787',
#   'member': '1963',
#   'deposited': {'date-parts': [[2014, 5, 27]],
#    'date-time': '2014-05-27T17:04:57Z',
#    'timestamp': 1401210297000},
#   'score': 13.026722,
#   'issued': {'date-parts': [[None]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1787/270604575355'},
#  {'indexed': {'date-parts': [[2020, 3, 30]],
#    'date-time': '2020-03-30T05:34:42Z',
#    'timestamp': 1585546482946},
#   'reference-count': 0,
#   'publisher': 'Schweizerbart',
#   'issue': '2',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['phyto'],
#   'published-print': {'date-parts': [[1989, 5, 2]]},
#   'DOI': '10.1127/phyto/17/1989/287',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2014, 1, 29]],
#    'date-time': '2014-01-29T05:09:25Z',
#    'timestamp': 1390972165000},
#   'page': '287-288',
#   'source': 'Crossref',
#   'is-referenced-by-count': 1,
#   'title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#   'prefix': '10.1127',
#   'volume': '17',
#   'author': [{'given': 'H.',
#     'family': 'Rehder',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'E.',
#     'family': 'Beck',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'J. O.',
#     'family': 'Kokwaro',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '181',
#   'container-title': ['Phytocoenologia'],
#   'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya) Comment on the Vegetation Map of Mt. Kenya'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2017, 4, 11]],
#    'date-time': '2017-04-11T05:00:28Z',
#    'timestamp': 1491886828000},
#   'score': 12.975961,
#   'issued': {'date-parts': [[1989, 5, 2]]},
#   'references-count': 0,
#   'journal-issue': {'published-print': {'date-parts': [[1989, 5, 2]]},
#    'issue': '2'},
#   'URL': 'http://dx.doi.org/10.1127/phyto/17/1989/287',
#   'ISSN': ['0340-269X'],
#   'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#  {'indexed': {'date-parts': [[2020, 3, 24]],
#    'date-time': '2020-03-24T19:41:32Z',
#    'timestamp': 1585078892966},
#   'reference-count': 0,
#   'publisher': 'African Journal of Food, Agriculture, Nutrition and Development',
#   'issue': '01',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['AJFAND'],
#   'DOI': '10.18697/ajfand.84.blfb1017',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2019, 2, 2]],
#    'date-time': '2019-02-02T09:05:42Z',
#    'timestamp': 1549098342000},
#   'page': '14010-14042',
#   'source': 'Crossref',
#   'is-referenced-by-count': 15,
#   'title': ['Climate Change Effects on Crop Production in Kenya: Farmer Perceptions and Adaptation Strategies'],
#   'prefix': '10.18697',
#   'volume': '19',
#   'author': [{'given': 'Beverly',
#     'family': 'Agesa',
#     'sequence': 'first',
#     'affiliation': []},
#    {'name': 'University  of Nairobi, Nairobi, Kenya',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'CM',
#     'family': 'Onyango',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'VM',
#     'family': 'Kathumo',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'RN',
#     'family': 'Onwonga',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'GN',
#     'family': 'Karuku',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'University  of  Nairobi, Nairobi, Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'University  of  Nairobi,  Nairobi, Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'University  of Nairobi, Nairobi, Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Univesity of Nairobi, Nairobi, Kenya',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '8080',
#   'published-online': {'date-parts': [[2019, 2, 1]]},
#   'container-title': ['African Journal of Food, Agriculture, Nutrition and Development'],
#   'link': [{'URL': 'https://www.ajfand.net/Volume19/No1/BLFB1017.pdf',
#     'content-type': 'unspecified',
#     'content-version': 'vor',
#     'intended-application': 'similarity-checking'}],
#   'deposited': {'date-parts': [[2019, 2, 2]],
#    'date-time': '2019-02-02T09:05:44Z',
#    'timestamp': 1549098344000},
#   'score': 12.975961,
#   'issued': {'date-parts': [[2019, 2, 1]]},
#   'references-count': 0,
#   'journal-issue': {'published-online': {'date-parts': [[2019, 2, 1]]},
#    'issue': '01'},
#   'URL': 'http://dx.doi.org/10.18697/ajfand.84.blfb1017',
#   'ISSN': ['1684-5374'],
#   'issn-type': [{'value': '1684-5374', 'type': 'electronic'}]},
#  {'indexed': {'date-parts': [[2020, 3, 30]],
#    'date-time': '2020-03-30T05:34:42Z',
#    'timestamp': 1585546482746},
#   'reference-count': 0,
#   'publisher': 'Schweizerbart',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['phyto'],
#   'published-print': {'date-parts': [[1988, 12, 7]]},
#   'DOI': '10.1127/phyto/16/1988/433',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2014, 1, 29]],
#    'date-time': '2014-01-29T10:09:25Z',
#    'timestamp': 1390990165000},
#   'page': '433-463',
#   'source': 'Crossref',
#   'is-referenced-by-count': 9,
#   'title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#   'prefix': '10.1127',
#   'volume': '16',
#   'author': [{'given': 'H.',
#     'family': 'Rehder',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'E.',
#     'family': 'Beck',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'J. O.',
#     'family': 'Kokwaro',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '181',
#   'container-title': ['Phytocoenologia'],
#   'original-title': ['The afroalpine plant communities of Mt. Kenya (Kenya)'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2017, 4, 11]],
#    'date-time': '2017-04-11T10:26:22Z',
#    'timestamp': 1491906382000},
#   'score': 12.843469,
#   'issued': {'date-parts': [[1988, 12, 7]]},
#   'references-count': 0,
#   'journal-issue': {'published-print': {'date-parts': [[1988, 12, 7]]},
#    'issue': '4'},
#   'URL': 'http://dx.doi.org/10.1127/phyto/16/1988/433',
#   'ISSN': ['0340-269X'],
#   'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#  {'indexed': {'date-parts': [[2020, 3, 30]],
#    'date-time': '2020-03-30T05:35:03Z',
#    'timestamp': 1585546503509},
#   'reference-count': 0,
#   'publisher': 'Schweizerbart',
#   'issue': '4',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['phyto'],
#   'published-print': {'date-parts': [[1995, 12, 14]]},
#   'DOI': '10.1127/phyto/25/1995/467',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2014, 1, 29]],
#    'date-time': '2014-01-29T11:02:59Z',
#    'timestamp': 1390993379000},
#   'page': '467-560',
#   'source': 'Crossref',
#   'is-referenced-by-count': 9,
#   'title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#   'prefix': '10.1127',
#   'volume': '25',
#   'author': [{'given': 'Rainer W.',
#     'family': 'Bussmann',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Erwin',
#     'family': 'Beck',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '181',
#   'container-title': ['Phytocoenologia'],
#   'original-title': ['The forests of Mt. Kenya (Kenya), a phytosociological synopsis'],
#   'language': 'en',
#   'deposited': {'date-parts': [[2017, 4, 11]],
#    'date-time': '2017-04-11T09:04:27Z',
#    'timestamp': 1491901467000},
#   'score': 12.843469,
#   'issued': {'date-parts': [[1995, 12, 14]]},
#   'references-count': 0,
#   'journal-issue': {'published-print': {'date-parts': [[1995, 12, 14]]},
#    'issue': '4'},
#   'URL': 'http://dx.doi.org/10.1127/phyto/25/1995/467',
#   'ISSN': ['0340-269X'],
#   'issn-type': [{'value': '0340-269X', 'type': 'print'}]},
#  {'indexed': {'date-parts': [[2020, 3, 26]],
#    'date-time': '2020-03-26T05:06:29Z',
#    'timestamp': 1585199189664},
#   'reference-count': 0,
#   'publisher': 'Manchester University Press',
#   'isbn-type': [{'value': '9781526105813', 'type': 'print'},
#    {'value': '9781526135988', 'type': 'electronic'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[2019, 3, 1]]},
#   'abstract': '<p>Since the 1998 bombing of the US Embassy in Nairobi, the Government of Kenya’s response to terrorism has been multifaceted. Government efforts have primarily relied on civil authorities and the military, thus privileging the use of force over subtler means. The Kenyan Police have employed measures such as profiling, detention, and prosecution. The Kenyan military has conducted operations in Kenya and Somalia. These strategies have contributed to the apprehension of some terrorist suspects and checked Shabaab’s advance in Somalia. Yet, Kenya’s counterterrorism efforts have been hampered by limited coordination among agencies, the use of heavy-handed tactics, and insufficient engagement with civil society organizations. Two defining features of Kenyan counterterrorism efforts have emerged. First, counterterrorism in Kenya has clear sociocultural dimensions. Security forces have responded to the threat of terrorism by focusing intently on Kenya’s alienated Muslim communities both in the Somali-majority north and at the Swahili-speaking coast. As a result, the Government of Kenya’s response to terrorism reflects communal divisions and animosity within Kenyan society that precede contemporary counterterrorism. Second, Kenya’s invasion of neighboring Somalia created and blurred two fronts: one within Kenya and the other in southern Somalia. The actions of Kenyan policy-makers and al Shabaab therefore contributed to a more complete integration of the conflict in Somalia and internal tensions in Kenya..</p>',
#   'DOI': '10.7228/manchester/9781526105813.003.0016',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2019, 5, 23]],
#    'date-time': '2019-05-23T09:38:00Z',
#    'timestamp': 1558604280000},
#   'page': '386-409',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#   'prefix': '10.7228',
#   'author': [{'given': 'Jeremy',
#     'family': 'Prestholdt',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '4230',
#   'published-online': {'date-parts': [[2019, 5, 23]]},
#   'container-title': ['Non-Western responses to terrorism'],
#   'original-title': ['Kenya: Counterterrorism in Kenya: Security aid, impunity and Muslim alienation'],
#   'deposited': {'date-parts': [[2019, 5, 23]],
#    'date-time': '2019-05-23T09:38:00Z',
#    'timestamp': 1558604280000},
#   'score': 12.843469,
#   'issued': {'date-parts': [[2019, 3, 1]]},
#   'ISBN': ['9781526105813', '9781526135988'],
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.7228/manchester/9781526105813.003.0016'},
#  {'indexed': {'date-parts': [[2019, 12, 4]],
#    'date-time': '2019-12-04T05:53:32Z',
#    'timestamp': 1575438812997},
#   'publisher-location': 'London',
#   'reference-count': 0,
#   'publisher': 'Palgrave Macmillan UK',
#   'isbn-type': [{'value': '9781349958382', 'type': 'print'},
#    {'value': '9781349958399', 'type': 'electronic'}],
#   'license': [{'URL': 'http://www.springer.com/tdm',
#     'start': {'date-parts': [[2019, 1, 1]],
#      'date-time': '2019-01-01T00:00:00Z',
#      'timestamp': 1546300800000},
#     'delay-in-days': 0,
#     'content-version': 'tdm'}],
#   'content-domain': {'domain': ['link.springer.com'],
#    'crossmark-restriction': False},
#   'published-print': {'date-parts': [[2019]]},
#   'DOI': '10.1057/978-1-349-95839-9_1403',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2019, 4, 17]],
#    'date-time': '2019-04-17T10:48:42Z',
#    'timestamp': 1555498122000},
#   'page': '714-715',
#   'update-policy': 'http://dx.doi.org/10.1007/springer_crossmark_policy',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya'],
#   'prefix': '10.1057',
#   'member': '297',
#   'published-online': {'date-parts': [[2019, 4, 2]]},
#   'container-title': ['The Statesman’s Yearbook Companion'],
#   'link': [{'URL': 'http://link.springer.com/content/pdf/10.1057/978-1-349-95839-9_1403',
#     'content-type': 'unspecified',
#     'content-version': 'vor',
#     'intended-application': 'similarity-checking'}],
#   'deposited': {'date-parts': [[2019, 4, 17]],
#    'date-time': '2019-04-17T10:57:59Z',
#    'timestamp': 1555498679000},
#   'score': 12.79614,
#   'subtitle': ['Jamhuri ya Kenya (Republic of Kenya)'],
#   'issued': {'date-parts': [[2019]]},
#   'ISBN': ['9781349958382', '9781349958399'],
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1057/978-1-349-95839-9_1403',
#   'assertion': [{'value': '2 April 2019',
#     'order': 1,
#     'name': 'first_online',
#     'label': 'First Online',
#     'group': {'name': 'ChapterHistory', 'label': 'Chapter History'}}]},
#  {'indexed': {'date-parts': [[2020, 3, 25]],
#    'date-time': '2020-03-25T20:58:24Z',
#    'timestamp': 1585169904857},
#   'reference-count': 0,
#   'publisher': 'Bloomsbury Publishing',
#   'isbn-type': [{'value': '9781408122549', 'type': 'print'},
#    {'value': '9781408189931', 'type': 'electronic'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.5040/9781472926944.0150',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2016, 6, 24]],
#    'date-time': '2016-06-24T17:27:36Z',
#    'timestamp': 1466789256000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Surdisorex polulus Mount Kenya Mole-shrew : Fr. Musaraigne du Mont Kenya; Ger. Mount Kenya Wühlspitzmaus'],
#   'prefix': '10.5040',
#   'member': '2984',
#   'container-title': ['Mammals of Africa : Hedgehogs, Shrews and Bats'],
#   'deposited': {'date-parts': [[2016, 7, 4]],
#    'date-time': '2016-07-04T13:54:23Z',
#    'timestamp': 1467640463000},
#   'score': 12.79614,
#   'issued': {'date-parts': [[None]]},
#   'ISBN': ['9781472926944', '9781408189931', '9781408122549'],
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.5040/9781472926944.0150'},
#  {'indexed': {'date-parts': [[2020, 3, 25]],
#    'date-time': '2020-03-25T19:00:30Z',
#    'timestamp': 1585162830294},
#   'reference-count': 0,
#   'publisher': 'Kenya Meteorological Society',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'short-container-title': ['J. Meteorol. Related. Sci'],
#   'published-print': {'date-parts': [[2007, 9, 19]]},
#   'DOI': '10.20987/jmrs.08.2012.603',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2016, 5, 31]],
#    'date-time': '2016-05-31T07:04:14Z',
#    'timestamp': 1464678254000},
#   'page': '26-35',
#   'source': 'Crossref',
#   'is-referenced-by-count': 2,
#   'title': ['Use of Aquacrop Model to Predict Maize Yields under varying Rainfall and Temperature in a Semi-Arid Environment in Kenya'],
#   'prefix': '10.20987',
#   'volume': '6',
#   'author': [{'given': 'Joab',
#     'family': 'Wamari',
#     'sequence': 'first',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#     'sequence': 'first',
#     'affiliation': []},
#    {'given': 'Sijali',
#     'family': 'Isaya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Lee',
#     'family': 'Kheng',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Joseph',
#     'family': 'Miriti',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'given': 'Esilaba',
#     'family': 'Obutiati',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research Laboratories-Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Soil and Water management and Crop Nutrition Section',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'National Agricultural Research Centre -Kenya',
#     'sequence': 'additional',
#     'affiliation': []},
#    {'name': 'Kenya Agricultural Research institute',
#     'sequence': 'additional',
#     'affiliation': []}],
#   'member': '8610',
#   'container-title': ['Journal of Meteorology and Related Sciences'],
#   'deposited': {'date-parts': [[2017, 7, 26]],
#    'date-time': '2017-07-26T21:59:54Z',
#    'timestamp': 1501106394000},
#   'score': 12.722612,
#   'issued': {'date-parts': [[2007, 9, 19]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.20987/jmrs.08.2012.603',
#   'ISSN': ['1995-9834', '2412-3781'],
#   'issn-type': [{'value': '1995-9834', 'type': 'print'},
#    {'value': '2412-3781', 'type': 'electronic'}]},
#  {'institution': {'name': 'Koninklijke Brill NV',
#    'place': ['-'],
#    'acronym': ['BRILL']},
#   'indexed': {'date-parts': [[2019, 11, 23]],
#    'date-time': '2019-11-23T19:38:50Z',
#    'timestamp': 1574537930164},
#   'reference-count': 0,
#   'publisher': 'Brill',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1163/_afco_asc_3100',
#   'type': 'dataset',
#   'created': {'date-parts': [[2014, 8, 8]],
#    'date-time': '2014-08-08T12:35:44Z',
#    'timestamp': 1407501344000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya International Film Festival (Nairobi et al., Kenya)'],
#   'prefix': '10.1163',
#   'member': '50',
#   'container-title': ['African Studies Companion Online'],
#   'deposited': {'date-parts': [[2018, 11, 21]],
#    'date-time': '2018-11-21T06:03:11Z',
#    'timestamp': 1542780191000},
#   'score': 12.69376,
#   'issued': {'date-parts': [[None]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1163/_afco_asc_3100'},
#  {'institution': {'name': 'Koninklijke Brill NV',
#    'place': ['-'],
#    'acronym': ['BRILL']},
#   'indexed': {'date-parts': [[2019, 11, 23]],
#    'date-time': '2019-11-23T19:38:11Z',
#    'timestamp': 1574537891045},
#   'reference-count': 0,
#   'publisher': 'Brill',
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1163/1872-9037_afco_asc_3100',
#   'type': 'dataset',
#   'created': {'date-parts': [[2014, 8, 8]],
#    'date-time': '2014-08-08T12:35:44Z',
#    'timestamp': 1407501344000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Kenya International Film Festival (Nairobi et al., Kenya)'],
#   'prefix': '10.1163',
#   'member': '50',
#   'container-title': ['African Studies Companion Online'],
#   'deposited': {'date-parts': [[2018, 11, 21]],
#    'date-time': '2018-11-21T06:03:09Z',
#    'timestamp': 1542780189000},
#   'score': 12.69376,
#   'issued': {'date-parts': [[None]]},
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1163/1872-9037_afco_asc_3100'},
#  {'indexed': {'date-parts': [[2019, 11, 25]],
#    'date-time': '2019-11-25T18:49:56Z',
#    'timestamp': 1574707796806},
#   'reference-count': 0,
#   'publisher': 'Palgrave Macmillan',
#   'isbn-type': [{'value': '9781137440532', 'type': 'print'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'DOI': '10.1057/9781137440532.0010',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2015, 6, 30]],
#    'date-time': '2015-06-30T13:16:24Z',
#    'timestamp': 1435670184000},
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Indian Private Doctors in Kenya'],
#   'prefix': '10.1057',
#   'member': '297',
#   'container-title': ['Indian Doctors in Kenya, 1895-1940'],
#   'deposited': {'date-parts': [[2015, 6, 30]],
#    'date-time': '2015-06-30T13:37:59Z',
#    'timestamp': 1435671479000},
#   'score': 12.69376,
#   'issued': {'date-parts': [[None]]},
#   'ISBN': ['9781137440532'],
#   'references-count': 0,
#   'URL': 'http://dx.doi.org/10.1057/9781137440532.0010'},
#  {'indexed': {'date-parts': [[2019, 11, 24]],
#    'date-time': '2019-11-24T08:14:12Z',
#    'timestamp': 1574583252861},
#   'publisher-location': 'UK and Ireland',
#   'reference-count': 0,
#   'publisher': 'Oxfam Publishing',
#   'isbn-type': [{'value': '9780855983826', 'type': 'print'},
#    {'value': '9780855987800', 'type': 'electronic'}],
#   'content-domain': {'domain': [], 'crossmark-restriction': False},
#   'published-print': {'date-parts': [[1998, 1]]},
#   'DOI': '10.3362/9780855987800.000',
#   'type': 'book-chapter',
#   'created': {'date-parts': [[2015, 2, 19]],
#    'date-time': '2015-02-19T02:07:57Z',
#    'timestamp': 1424311677000},
#   'page': '1-3',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Prelims - Kenya'],
#   'prefix': '10.3362',
#   'author': [{'given': 'Geoff',
#     'family': 'Sayer',
#     'sequence': 'first',
#     'affiliation': []}],
#   'member': '1928',
#   'published-online': {'date-parts': [[2015, 2, 18]]},
#   'container-title': ['Kenya'],
#   'deposited': {'date-parts': [[2018, 8, 9]],
#    'date-time': '2018-08-09T20:31:31Z',
#    'timestamp': 1533846691000},
#   'score': 12.69376,
#   'issued': {'date-parts': [[1998, 1]]},
#   'ISBN': ['9780855983826', '9780855987800'],
#   'references-count': 0,
#   'alternative-id': ['10.3362/9780855987800.000', '10.3362/9780855987800'],
#   'URL': 'http://dx.doi.org/10.3362/9780855987800.000'}]

# %% [markdown]
# Above, we can see that the `items` contains the majority of information about our query on Kenya. It contains a list of all of the results - we can check this with the `type` command we used earlier. Since we only are looking at the first page, our items list has only 20 items in it.

# %%
type(kenya['message']['items'])
# Out:
# list

# %%
len(kenya['message']['items'])
# Out:
# 20

# %% [markdown]
# # 2.5 Creating Tables <a id = '2.5'></a>
# When our data exists in dictionaries, it's a little hard to explore and manipulate. In order to tackle this, we'll create a dataframe of the information so that we can access it more easily.

# %%
df_kenya = pd.DataFrame(kenya['message']['items'])
df_kenya.head() # show the first 5 rows
# Out:
#                                              indexed  reference-count  \
# 0  {'date-parts': [[2019, 11, 24]], 'date-time': ...                0
# 1  {'date-parts': [[2019, 11, 23]], 'date-time': ...                0
# 2  {'date-parts': [[2020, 3, 24]], 'date-time': '...                0
# 3  {'date-parts': [[2020, 3, 30]], 'date-time': '...                0
# 4  {'date-parts': [[2020, 3, 24]], 'date-time': '...                0
#
#                                            publisher issue  \
# 0       Centro Internacional de Agricultura Tropical     1
# 1  Nature Kenya, East Africa Natural History Soci...   NaN
# 2                                         De Gruyter   NaN
# 3         International Journal Of Advanced Research     2
# 4                           Commonwealth Secretariat   NaN
#
#                                    content-domain     short-container-title  \
# 0  {'domain': [], 'crossmark-restriction': False}  [Trop Grass - Forr Trop]
# 1  {'domain': [], 'crossmark-restriction': False}                       NaN
# 2  {'domain': [], 'crossmark-restriction': False}                       NaN
# 3  {'domain': [], 'crossmark-restriction': False}                    [IJAR]
# 4  {'domain': [], 'crossmark-restriction': False}                       NaN
#
#                             DOI             type  \
# 0       10.17138/tgft(2)100-102  journal-article
# 1       10.5962/bhl.title.87589        monograph
# 2     10.1515/9783110826050-068     book-chapter
# 3          10.21474/ijar01/6544  journal-article
# 4  10.14217/9781848594371-12-en        component
#
#                                              created       page  ...  \
# 0  {'date-parts': [[2015, 4, 1]], 'date-time': '2...        100  ...
# 1  {'date-parts': [[2014, 8, 24]], 'date-time': '...        NaN  ...
# 2  {'date-parts': [[2019, 2, 25]], 'date-time': '...    304-305  ...
# 3  {'date-parts': [[2018, 3, 30]], 'date-time': '...  1195-1203  ...
# 4  {'date-parts': [[2016, 1, 29]], 'date-time': '...        NaN  ...
#
#                                                 link  \
# 0                                                NaN
# 1                                                NaN
# 2  [{'URL': 'http://www.degruyter.com/view/books/...
# 3                                                NaN
# 4                                                NaN
#
#                                               editor             ISBN  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2  [{'given': 'Werner', 'family': 'Schuder', 'seq...  [9783110826050]
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#   original-title abstract license update-policy subtitle assertion institution
# 0            NaN      NaN     NaN           NaN      NaN       NaN         NaN
# 1            NaN      NaN     NaN           NaN      NaN       NaN         NaN
# 2            NaN      NaN     NaN           NaN      NaN       NaN         NaN
# 3            NaN      NaN     NaN           NaN      NaN       NaN         NaN
# 4            NaN      NaN     NaN           NaN      NaN       NaN         NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# There are a bunch of columns in our table, and we can't see all of them by scrolling. Below, we can look at a list of the columns instead.

# %%
df_kenya.columns
# Out:
# Index(['indexed', 'reference-count', 'publisher', 'issue', 'content-domain',
#        'short-container-title', 'DOI', 'type', 'created', 'page', 'source',
#        'is-referenced-by-count', 'title', 'prefix', 'volume', 'author',
#        'member', 'published-online', 'container-title', 'language',
#        'deposited', 'score', 'issued', 'references-count', 'journal-issue',
#        'alternative-id', 'URL', 'ISSN', 'issn-type', 'publisher-location',
#        'published-print', 'isbn-type', 'link', 'editor', 'ISBN',
#        'original-title', 'abstract', 'license', 'update-policy', 'subtitle',
#        'assertion', 'institution'],
#       dtype='object')

# %% [markdown]
# We want to be able to retrieve more data from CrossRef. A single CrossRef query can return up to 1,000 results, and since our query has over 42,000 total results, we'd need to make 43 queries. Remember at the beginning, we only had 20 results since we only grabbed the first page. The CrossRef API permits fetching results from multiple pages, so by setting `cursor` to `*` and `cursor_max` to 1000 we can grab 1000 queries at once. Querying all 42,000 results would take a long time, so for the purposes of this demonstration we are only using 1000. If you have more time, you could query more results, but be aware that it will take a long time.

# %%
# this cell will take a while to run
cr_kenya = cr.works(query="kenya", cursor = "*", cursor_max = 1000, progress_bar = True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 49/49 [00:49<00:00,  1.01s/it]

# %% [markdown]
# We can check that we have the 1,000 messages, and indeed we do.

# %%
sum([len(k['message']['items']) for k in cr_kenya])
# Out:
# 1000

# %% [markdown]
# Remember before, when you created your own search query? Here, we'll go through a few steps to get more results for your query. First, we'll check how many total results your query has. Run the cell below to find out.

# %%
query['message']['total-results']
# Out:
# 27552

# %% [markdown]
# If there are fewer than 1000 results, then set `cursor_max` to the number of results. If there are more than 1000 results, set `cursor_max` to 1000 so that the code won't take too long to run. Be sure to fill in `query` with the same search term you used earlier.

# %%
cr_query = cr.works(query="...", cursor = "*", cursor_max = 1000, progress_bar = True)

# %%
# example
cr_query = cr.works(query="berkeley", cursor = "*", cursor_max = 1000, progress_bar = True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 49/49 [00:51<00:00,  1.06s/it]

# %% [markdown]
# In order to get all of the different results from our Kenya query, we need to extract them from `cr_kenya`. Below, we create a list where each element is one result. `cr_kenya` is a list consisting of pages, where we have 20 results per page. So `cr_kenya` has 50 pages of 20 results each, giving us our 1000 results. In order to extract the info and have a list with each element be one results, we need to do some data manipulation.

# %%
len(cr_kenya)
# Out:
# 50

# %% [markdown]
# In the cell below, we have 2 list comprehensions to get the results from our query. The first one creates a length 50 list that contains only the items instead of the entire dictionary, for each of the 50 pages. The second list comprehension extracts all of the items from the nested lists so that we have a single 1000 item list where each element is one result.

# %%
kenya_items = [k['message']['items'] for k in cr_kenya] # get items for all pages
kenya_items = [item for sublist in kenya_items for item in sublist] # restructure list

# %% [markdown]
# We'll do the same for your query results so that you can have some fun plotting later in the notebook. Just run the cell below.

# %%
query_items = [k['message']['items'] for k in cr_query] # get items for all pages
query_items = [item for sublist in query_items for item in sublist] # restructure list

# %% [markdown]
# # 2.6 Searches <a id = '2.6'></a>
# You may be curious about the `cr.works` function that we've been using to get our data. This is the function that processes your topical "search". There are different arguments, and we've seen how changing these arguments can help us get more search results than just the first 20.
#
# Also, before we asked you to limit your search term to a single word. This is not a hard restriction - we simply did this for simplicity. You can query terms that are more specific and include more words - try it out below! Keep in mind that the more specifc your search query, the fewer results you may see. Feel free to play around with it.

# %%
query2 = cr.works(query = 'labrador retriever')
query2['message']['total-results']
# Out:
# 7948

# %% [markdown]
# # 3. Visualization <a id = '3'></a>
# Visualization is an important part of data analysis. Rather than looking at dictionaries and dataframes, we can see a visual summary of our data. We'll start by looking at the publishers. But first we need to do some wrangling to get the data in a form that's useful for us.

# %% [markdown]
# # 3.1 Journal Title <a id = '3.1'></a>
# We will first create a bar chart that shows the number of articles published by different journals / publishers. In order to accomplish this, first we need to get that data.

# %%
kenya_publishers = np.array([k['publisher'] for k in kenya_items]) # get the publisher for each article
kenya_publishers
# Out:
# array(['Elsevier BV', 'Informa UK Limited',
#        'Springer Science and Business Media LLC', 'Wiley', 'Wiley',
#        'Elsevier BV', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Wiley', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Informa UK Limited',
#        'Informa UK Limited', 'Informa UK Limited', 'Informa UK Limited',
#        'Elsevier BV', 'Elsevier BV', 'Cambridge University Press (CUP)',
#        'Elsevier BV', 'Wiley',
#        'International Heart Journal (Japanese Heart Journal)',
#        'Mineralogical Society', 'Wiley', 'Elsevier BV', 'Elsevier BV',
#        'Informa UK Limited', 'Informa UK Limited', 'Wiley',
#        'Informa UK Limited', 'Informa UK Limited', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Wiley', 'Wiley',
#        'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'S. Karger AG',
#        'Informa UK Limited', 'Elsevier BV', 'ACM Press',
#        'American Geophysical Union (AGU)',
#        'American Geophysical Union (AGU)',
#        'American Geophysical Union (AGU)',
#        'American Geophysical Union (AGU)',
#        'American Geophysical Union (AGU)',
#        'Springer Science and Business Media LLC', 'AIP Publishing',
#        'The Haworth Press', 'American Geophysical Union (AGU)',
#        'Elsevier BV', 'SAGE Publications', 'Wiley', 'Wiley',
#        'Cambridge University Press (CUP)',
#        'Oxford University Press (OUP)', 'Elsevier BV', 'Elsevier BV',
#        'Wiley', 'Elsevier BV', 'University of Chicago Press',
#        'University of Chicago Press',
#        'American Medical Association (AMA)',
#        'University of Chicago Press', 'University of Chicago Press',
#        'University of Chicago Press', 'University of Chicago Press',
#        'University of Chicago Press', 'University of Chicago Press',
#        'University of Chicago Press',
#        'Ovid Technologies (Wolters Kluwer Health)',
#        'Cambridge University Press (CUP)',
#        'Cambridge University Press (CUP)',
#        'Cambridge University Press (CUP)',
#        'Springer Science and Business Media LLC', 'SPIE',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)',
#        'Cambridge University Press (CUP)',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'American Medical Association (AMA)',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Royal Society of Chemistry (RSC)', 'Wiley', 'Elsevier BV',
#        'Elsevier BV', 'Royal Society of Chemistry (RSC)', 'Wiley',
#        'American Society for Biochemistry & Molecular Biology (ASBMB)',
#        'Wiley', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Informa UK Limited', 'Springer Science and Business Media LLC',
#        'Elsevier BV', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Wiley', 'Wiley',
#        'AIP Publishing', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Wiley', 'Elsevier BV', 'Wiley',
#        'Wiley', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Elsevier BV',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Elsevier BV',
#        'Oxford University Press (OUP)', 'Elsevier BV',
#        'Oxford University Press (OUP)', 'Elsevier BV', 'Elsevier BV',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Elsevier BV', 'Elsevier BV',
#        'Royal Society of Chemistry (RSC)',
#        'Royal Society of Chemistry (RSC)', 'Wiley', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Wiley', 'Wiley', 'Wiley',
#        'Informa UK Limited', 'ASME International', 'Informa UK Limited',
#        'Elsevier BV', 'Elsevier BV', 'Oxford University Press (OUP)',
#        'Informa UK Limited', 'Springer Science and Business Media LLC',
#        'Wiley', 'Elsevier BV', 'Informa UK Limited',
#        'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Emerald', 'Elsevier BV', 'Wiley', 'Wiley', 'Elsevier BV',
#        'Cambridge University Press (CUP)', 'Elsevier BV',
#        'Informa UK Limited', 'Wiley', 'Elsevier BV', 'Elsevier BV',
#        'Wiley', 'Elsevier BV', 'Wiley', 'Wiley', 'Wiley', 'Elsevier BV',
#        'Elsevier BV', 'Oxford University Press (OUP)', 'Elsevier BV',
#        'Wiley', 'Elsevier BV', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Elsevier BV', 'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Elsevier BV', 'Elsevier BV', 'SAGE Publications', 'Wiley',
#        'Wiley', 'Elsevier BV', 'Elsevier BV', 'SAGE Publications',
#        'Wiley', 'Cambridge University Press (CUP)', 'Informa UK Limited',
#        'American Medical Association (AMA)',
#        'Oxford University Press (OUP)', 'SAGE Publications', 'Wiley',
#        'Oxford University Press (OUP)', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Oxford University Press (OUP)', 'Elsevier BV', 'Elsevier BV',
#        'Oxford University Press (OUP)', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Akademiai Kiado Zrt.',
#        'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Ovid Technologies (Wolters Kluwer Health)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Informa UK Limited', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Wiley',
#        'American Geophysical Union (AGU)', 'Wiley',
#        'American Society for Microbiology',
#        'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)', 'Informa UK Limited',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Ovid Technologies (Wolters Kluwer Health)',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Ovid Technologies (Wolters Kluwer Health)',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'International Heart Journal (Japanese Heart Journal)',
#        'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)', 'Wiley', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Wiley',
#        'Oxford University Press (OUP)', 'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Elsevier BV', 'Emerald', 'Emerald',
#        'Oxford University Press (OUP)', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)', 'Emerald',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'SPIE',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV', 'Wiley',
#        'Ovid Technologies (Wolters Kluwer Health)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Elsevier BV', 'Elsevier BV', 'Mary Ann Liebert Inc',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Wiley',
#        'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Informa UK Limited', 'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Cambridge University Press (CUP)', 'Elsevier BV',
#        'Informa UK Limited', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Oxford University Press (OUP)',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Elsevier BV', 'Oxford University Press (OUP)', 'SPIE',
#        'Springer Science and Business Media LLC',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Elsevier BV', 'Elsevier BV', 'Wiley',
#        'Springer Science and Business Media LLC', 'Wiley', 'IEEE', 'IEEE',
#        'Elsevier BV', 'Wiley', 'Wiley', 'Wiley', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Elsevier BV', 'Elsevier BV',
#        'American Society of Civil Engineers',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Test accounts',
#        'Test accounts', 'Test accounts', 'Test accounts',
#        'American Association of Petroleum Geologists AAPG/Datapages',
#        'Springer Science and Business Media LLC', 'Test accounts',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Test accounts',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Test accounts',
#        'Springer Science and Business Media LLC',
#        'American Association of Petroleum Geologists AAPG/Datapages',
#        'American Association of Petroleum Geologists AAPG/Datapages',
#        'Test accounts', 'Springer Science and Business Media LLC',
#        'Test accounts', 'Elsevier BV', 'Test accounts', 'Test accounts',
#        'Wiley',
#        'American Association of Petroleum Geologists AAPG/Datapages',
#        'IEEE', 'Test accounts', 'Test accounts', 'Emerald', 'Wiley',
#        'Emerald', 'Elsevier BV', 'Wiley', 'Elsevier BV',
#        'Informa UK Limited', 'Informa UK Limited', 'Informa UK Limited',
#        'Wiley', 'Springer Science and Business Media LLC',
#        'Japan Society of Physiological Anthropology',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Society for Sedimentary Geology',
#        'Society for Sedimentary Geology',
#        'Society for Sedimentary Geology',
#        'Society for Sedimentary Geology',
#        'Society for Sedimentary Geology',
#        'Society for Sedimentary Geology', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley', 'IEEE', 'Wiley',
#        'IEEE & Marine Technol. Soc', 'IEEE & Marine Technol. Soc',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Oxford University Press (OUP)',
#        'Oxford University Press (OUP)', 'Wiley', 'Wiley', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'Elsevier BV', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Cambridge University Press (CUP)', 'Elsevier BV',
#        'Geological Society of America',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'BMJ', 'BMJ',
#        'Elsevier BV', 'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Cambridge University Press (CUP)',
#        'Cambridge University Press (CUP)',
#        'Cambridge University Press (CUP)',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Bioscientifica',
#        'Informa UK Limited', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'BMJ', 'Elsevier BV',
#        'SAGE Publications', 'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Cambridge University Press (CUP)', 'Elsevier BV', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Oxford University Press (OUP)',
#        'Cambridge University Press (CUP)',
#        'Cambridge University Press (CUP)', 'AIP',
#        'Ovid Technologies (Wolters Kluwer Health)',
#        'Ovid Technologies (Wolters Kluwer Health)', 'SAGE Publications',
#        'SAGE Publications', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley', 'Elsevier BV', 'Wiley', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Informa UK Limited',
#        'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'American Medical Association (AMA)', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'SAGE Publications',
#        'American Medical Association (AMA)', 'Wiley', 'Wiley',
#        'American Medical Association (AMA)', 'Elsevier BV', 'Elsevier BV',
#        'American Medical Association (AMA)',
#        'American Medical Association (AMA)',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'American Medical Association (AMA)',
#        'American Medical Association (AMA)', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Wiley', 'Wiley',
#        'Wiley', 'Wiley', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Elsevier BV', 'IEEE', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'Wiley', 'Wiley',
#        'Elsevier BV', 'Informa UK Limited', 'Elsevier BV',
#        'Oxford University Press', 'Elsevier BV',
#        'Oxford University Press', 'Oxford University Press',
#        'Oxford University Press', 'Elsevier BV', 'Wiley', 'Elsevier BV',
#        'Wiley', 'Wiley', 'Springer Science and Business Media LLC',
#        'Elsevier BV', 'Springer Science and Business Media LLC', 'Wiley',
#        'Wiley', 'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Wiley',
#        'Springer Science and Business Media LLC', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'American Physical Society (APS)', 'Elsevier BV', 'Elsevier BV',
#        'Wiley', 'Wiley', 'Wiley', 'BMJ', 'Elsevier BV', 'Elsevier BV',
#        'Elsevier BV', 'Springer Science and Business Media LLC',
#        'Japanese Society of Hypertension', 'SAGE Publications',
#        'Springer Science and Business Media LLC',
#        'The Chemical Society of Japan', 'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Informa UK Limited', 'Wiley', 'Pharmaceutical Society of Japan',
#        'Wiley', 'Wiley', 'Wiley', 'Elsevier BV',
#        'American Society for Microbiology', 'Wiley', 'Wiley', 'Wiley',
#        'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'Wiley',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Inderscience Publishers',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'The World Bank',
#        'The World Bank', 'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC',
#        'American Chemical Society (ACS)',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Informa UK Limited', 'Springer Science and Business Media LLC',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Cambridge University Press (CUP)', 'Informa UK Limited',
#        'Informa UK Limited', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Inderscience Publishers', 'Informa UK Limited', 'The World Bank',
#        'The World Bank', 'Wiley', 'Wiley', 'Wiley', 'The World Bank',
#        'SPIE', 'Wiley', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Springer Science and Business Media LLC', 'Informa UK Limited',
#        'Wiley', 'Wiley', 'Springer Science and Business Media LLC',
#        'Springer Science and Business Media LLC', 'Emerald', 'Wiley',
#        'Elsevier BV', 'Elsevier BV', 'Elsevier BV', 'Elsevier BV',
#        'Wiley', 'Wiley', 'American Physiological Society', 'Elsevier BV',
#        'Springer Science and Business Media LLC',
#        'Cambridge University Press (CUP)',
#        'Cambridge University Press (CUP)'], dtype='<U61')

# %% [markdown]
# The above is a long list with a lot of repeats. In order to visualize the number of articles published by each journal, we need to count up the number of times each journal appears in the list. The code in the cell below does this using numpy, and then puts that information in a dataframe for easy access.

# %%
unique_elements_kenya, counts_elements_kenya = np.unique(kenya_publishers, return_counts=True) # get counts

# put counts in dataframe
df_publish_kenya = pd.DataFrame({'publisher': unique_elements_kenya, 
                                 'count': counts_elements_kenya}).sort_values(by='count', ascending=False)
df_publish_kenya.head() # show first 5 rows
# Out:
#                                   publisher  count
# 17                              Elsevier BV    239
# 38  Springer Science and Business Media LLC    213
# 44                                    Wiley    190
# 31            Oxford University Press (OUP)    169
# 23                       Informa UK Limited     43

# %% [markdown]
# In the cells below, try to replicate the table of publishers for your search query. We've provided some skeleton code, and you can refer to the code above for guidance.

# %%
# create a list of publishers
query_publishers = np.array([k['publisher'] for k in ...]) # get the publisher for each article
query_publishers

# %%
# create a dataframe with publisher counts
unique_elements_query, counts_elements_query = np.unique(..., return_counts=True) # get counts

# put counts in dataframe
df_publish_query = pd.DataFrame({'publisher': ..., 
                                 'count': ...}).sort_values(by='count', ascending=False)
df_publish_query.head() # show first 5 rows

# %% [markdown]
# Now that we have a dataframe containing the names of the publishers and the number of articles they've published, we can create a bar graph to visualize this.

# %%
plt.figure(figsize=(20,8)) # set figure size
plt.bar(df_publish_kenya['publisher'], df_publish_kenya['count']) # create bar plot with publishers and counts
plt.xticks(df_publish_kenya['publisher'], rotation='vertical', fontsize = 20) # rotate publisher names for readability
plt.title('Publishers for Kenya Articles', fontsize = 20) # set title
plt.xlabel('Publisher', fontsize = 20) # set x label
plt.ylabel('Number of articles', fontsize = 20); # set y label

# %% [markdown]
# Wow, that's a lot of publishers. However, it seems like there are a lot of publishers that published only a few articles. Let's see if we can look at only the major publishers more closely. We will create a version of the publishers table where the count of articles published is greater than or equal to 10, and plot this instead.

# %%
more_than_10 = df_publish_kenya[df_publish_kenya['count'] >= 10] 
 
plt.bar(more_than_10['publisher'], more_than_10['count'])
plt.xticks(more_than_10['publisher'], rotation='vertical')
plt.title('Publishers with 10+ Kenya Articles')
plt.xlabel('Publisher')
plt.ylabel('Number of articles');

# %% [markdown]
# That's a lot better. We can focus on the publishers with the most articles on the topic of Kenya, and better see the differences between the different publishers. Now, in the cell below, create a visualization for your query, based on the `df_publish_query` you made above. Be sure to give it an appropriate title.

# %%
# your code here

plt.figure(figsize=(20,8)) # set figure size
plt.bar(..., ...) # create bar plot with publishers and counts
plt.xticks(df_publish_kenya['publisher'], rotation='vertical', fontsize = 20) # rotate publisher names for readability
plt.title('...', fontsize = 20) # set title
plt.xlabel('Publisher', fontsize = 20) # set x label
plt.ylabel('Number of articles', fontsize = 20); # set y label

# %% [markdown]
# # 3.2 Publisher Topics <a id = '3.2'></a>

# %% [markdown]
# There are different types of articles that can be published. Let's look at the different types and their counts.

# %%
#Count types
types = np.array([k['type'] for k in items])
unique_elements_type, counts_elements_type = np.unique(types, return_counts=True)
type_df = pd.DataFrame({'type': unique_elements_type, 'count': counts_elements_type}).sort_values(by='count', ascending=False)
type_df
# Out:
#                   type  count
# 3      journal-article   4885
# 1         book-chapter     58
# 5  proceedings-article     33
# 0                 book      9
# 2         dissertation      7
# 6       reference-book      4
# 7               report      3
# 4            monograph      1

# %%
# plt.figure(figsize=(30,10)) 
plt.bar(type_df['type'], type_df['count'])
plt.xticks(type_df['type'], rotation='vertical')
plt.title('Publishing Types')
plt.xlabel('Type')
plt.ylabel('Count');

# %% [markdown]
# # 3.3 Grouping and Sorting by Journal <a id = '3.3'></a>

# %% [markdown]
# It looks like journal articles are the main items published, and the amount of books, reference books, and monographs pales in comparison. Let's try putting together what we know about the types of articles and the publishers to see how individual publishers differ in the types of articles they publish.

# %%
publisher_types = pd.DataFrame({'publisher':publishers, 'type':types})
publisher_types
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8219051a861b> in <module>
# ----> 1 publisher_types = pd.DataFrame({'publisher':publishers, 'type':types})
#       2 publisher_types
#
# NameError: name 'pd' is not defined

# %%
journal_articles = publisher_types[publisher_types['type']=='journal-article']
journal_articles = journal_articles.groupby(by='publisher').count().reset_index().sort_values(by='type', ascending = False)
journal_articles = journal_articles[journal_articles['type']>10]


plt.bar(journal_articles['publisher'], journal_articles['type'])
plt.xticks(journal_articles['publisher'], rotation='vertical')
plt.title('Publishers of Journal Articles')
plt.xlabel('Publisher')
plt.ylabel('Number of articles');

# %% [markdown]
# This looks pretty similar to our graph before looking at the publishers of all types of articles. Fill in the cell below to look at the publishers of book chapters. Replace the `...` in the cell below so that we select only the types that are `book-chapter`.

# %%
book_chapters = publisher_types[publisher_types['type']== ...]
book_chapters = book_chapters.groupby(by='publisher').count().reset_index().sort_values(by='type', ascending = False)


plt.bar(book_chapters['publisher'], book_chapters['type'])
plt.xticks(book_chapters['publisher'], rotation='vertical')
plt.title('Publishers of Book Chapters')
plt.xlabel('Publisher')
plt.ylabel('Number of Book Chapters');

# %% [markdown]
# **What do you notice about the biggest publishers of book chapters versus the biggest publishers of journal articles?**

# %% [markdown]
# *Double click this cell to begin typing your answer*

# %% [markdown]
# # 3.4 Citations <a id = '3.4'></a>

# %% [markdown]
# We can also look a the number of references a journal article has. The cell below generates a histogram to display the number of references in each article.

# %%
reference_counts = [items[i]['reference-count'] for i in range(len(items))]
plt.hist(reference_counts)
plt.axvline(np.mean(reference_counts), color = 'red', 
            label = 'Average number of references: ' + str(np.round(np.mean(reference_counts), 2)))

plt.title('Number of References for each article')
plt.xlabel('Number of References')
plt.ylabel('Count')
plt.legend();

# %% [markdown]
# # 3.5 Queries Over Time <a id = '3.5'></a>

# %%
years = [items[i]['created']['date-parts'][0][0] for i in range(len(items))]
d = dict(Counter(years))
plt.plot(list(d.keys()),list(d.values()))
plt.xticks(np.arange(2002, 2010))
plt.title('Number of articles published by year')
plt.xlabel('Year')
plt.ylabel('Count');

# %% [markdown]
# # Bibliography <a id = '4'></a>
# - Paul Oldham - Adapted CrossRef R guide to Python. https://poldham.github.io/abs/crossref.html#introduction
#
# ---

# %% [markdown]
# Notebook developed by: Anjali Unnithan, Keilyn Yuzuki
#
# Data Science Modules: http://data.berkeley.edu/education/modules
#
# Data Science Offerings at Berkeley: https://data.berkeley.edu/academics/undergraduate-programs/data-science-offerings
